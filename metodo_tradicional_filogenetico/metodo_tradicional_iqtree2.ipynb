# %% [markdown]
# # Tempo de Processamento da Filogenia

# %%
import os
import subprocess
import time

# %%
# Diretório principal onde você possui várias pastas
diretorio_principal = '/home/m_souza/tcc/dataset/00_new_dataset_vagner/5tipos/output'

# Iterar sobre as pastas no diretório principal
for pasta in os.listdir(diretorio_principal):
    pasta_path = os.path.join(diretorio_principal, pasta)

    # Verificar se é um diretório
    if os.path.isdir(pasta_path):
        # Procurar pelo arquivo sequencias_treinamento.fasta na pasta
        arquivo_sequencias = os.path.join(pasta_path, 'sequencias_treinamento.fasta')

        # Verificar se o arquivo existe
        if os.path.exists(arquivo_sequencias):
            print(f'Analisando sequências em {pasta}')

            # Comando a ser executado
            comando = f"iqtree2 -s {arquivo_sequencias} -fast -m GTR+G4+F -alrt 1000 -nt AUTO"

            # Início da contagem do tempo
            start_time = time.time()

            # Executar o comando usando subprocess
            process = subprocess.Popen(comando, shell=True)
            process.communicate()  # Aguardar a conclusão do processo

            # Fim da contagem do tempo
            end_time = time.time()

            # Calcular o tempo de execução
            execution_time = end_time - start_time

            # Exibir o tempo de execução
            print(f"Tempo de execução em {pasta}: {execution_time} segundos")

            # Salvar as informações em um arquivo tempo_de_execucao.txt
            arquivo_tempo_execucao = os.path.join(pasta_path, 'tempo_de_execucao.txt')
            with open(arquivo_tempo_execucao, "w") as file:
                file.write(f"Tempo de execução: {execution_time} segundos")

print('Concluído!')
# Out:
# Analisando sequências em 300_por_tipo
# IQ-TREE multicore version 2.0.7 for Linux 64-bit built Jan 21 2022
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    administrador-B650M-AORUS-ELITE (AVX512, FMA3, 30 GB RAM)
# Command: iqtree2 -s /home/m_souza/tcc/dataset/00_new_dataset_vagner/5tipos/output/300_por_tipo/sequencias_treinamento.fasta -fast -m GTR+G4+F -alrt 1000 -nt AUTO
# Seed:    703936 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Sat Nov 25 14:01:36 2023
# Kernel:  AVX+FMA - auto-detect threads (24 CPU cores detected)
#
# Reading alignment file /home/m_souza/tcc/dataset/00_new_dataset_vagner/5tipos/output/300_por_tipo/sequencias_treinamento.fasta ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 1500 sequences with 3822 columns, 1642 distinct patterns
# 329 parsimony-informative, 354 singleton sites, 3139 constant sites
# ...

# %%
# Path das Sequências
path_sequencias = '/home/m_souza/tcc/dataset/dataset_agua/iqtree/iqtree_teste_tempo/teste/sequencias_treinamento.fasta'
# Comando a ser executado
comando = f"iqtree2 -s {path_sequencias} -fast -m GTR+G4+F -alrt 1000 -nt AUTO"

# Início da contagem do tempo
start_time = time.time()

# Executar o comando usando subprocess
process = subprocess.Popen(comando, shell=True)
process.communicate()  # Aguardar a conclusão do processo

# Fim da contagem do tempo
end_time = time.time()

# Calcular o tempo de execução
execution_time = end_time - start_time

# Exibir o tempo de execução
print(f"Tempo de execução: {execution_time} segundos")

# # Salvar as informações em um arquivo
# with open("tempo_de_execucao.txt", "w") as file:
#     file.write(f"Tempo de execução: {execution_time} segundos")
# Out:
# /home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/metodo_tradicional_filogenetico
# IQ-TREE multicore version 2.0.7 for Linux 64-bit built Jan 21 2022
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    administrador-B650M-AORUS-ELITE (AVX512, FMA3, 30 GB RAM)
# Command: iqtree2 -s /home/m_souza/tcc/dataset/dataset_agua/iqtree/iqtree_teste_tempo/teste/sequencias_treinamento.fasta -fast -m GTR+G4+F -alrt 1000 -nt AUTO
# Seed:    440580 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Fri Nov 24 19:22:56 2023
# Kernel:  AVX+FMA - auto-detect threads (24 CPU cores detected)
#
# Reading alignment file /home/m_souza/tcc/dataset/dataset_agua/iqtree/iqtree_teste_tempo/teste/sequencias_treinamento.fasta ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 500 sequences with 3822 columns, 813 distinct patterns
# ...
