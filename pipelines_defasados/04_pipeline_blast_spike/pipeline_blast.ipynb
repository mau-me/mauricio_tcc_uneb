# %%
import time

start_time = time.time()

# %% [markdown]
# ### Importações das Bibs Necessárias

# %%
from Bio.Blast.Applications import NcbiblastnCommandline
from Bio.Blast import NCBIXML
from Bio import SeqIO
from Bio.Application import ApplicationError
import tempfile
import os
from io import StringIO

# %% [markdown]
# ### Leitura das Sequências
#
# Recebe o path do arquivo fasta e retorna array com sequências

# %%
def read_genome_sequences(file_genome_sequences):
    multiple_genomes = []

    with open(file_genome_sequences) as handle:
        for values in SeqIO.FastaIO.SimpleFastaParser(handle):
            # Converta a sequência para letras minúsculas
            sequence_id, sequence = values
            sequence = sequence.lower()
            multiple_genomes.append((sequence_id, sequence))

    return multiple_genomes

# %% [markdown]
# ### Método para Encontrar as Posições do Gene no Genoma

# %%
def fetch_gene_position(gene_path, genome_path):
    try:
        # Executar o BLAST para buscar a posição do gene no genoma
        comando_blast = NcbiblastnCommandline(
            query=gene_path, subject=genome_path, outfmt=5)
        stdout, stderr = comando_blast()

        # Analisar o resultado XML do BLAST
        resultado_blast = NCBIXML.read(StringIO(stdout))
        if len(resultado_blast.alignments) == 0:
            print('O gene não foi encontrado no genoma.')
            return

        alinhamento = resultado_blast.alignments[0]
        hsp = alinhamento.hsps[0]

        gene_positions = []
        gene_positions.append(hsp.sbjct_start - 1)
        gene_positions.append(hsp.sbjct_end - 1)

        return gene_positions
    
    except ApplicationError as e:
        print('Ocorreu um erro durante a busca da posição do gene:')
        # print(e)
        return None
    
    except TypeError:
        print('Ocorreu um erro de tipo durante a busca da posição do gene.')
        return None

# %% [markdown]
# ### Main

# %%
# Sequência do gene spike
reference_gene_file_path = '/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/04_pipeline_blast_spike/refSpike.fasta'
# Path do Dataset dos Genomas
root_directory = '/home/m_souza/tcc/dataset/teste'
# root_directory = '/home/maume/UnEB/TCC/Dataset/sequencias_teste'
# Nome do arquivo de saída com Genes Spike
gene_file_name = 'sequences_spike_alignment.fasta'

# Variáveis para acompanhar o número de arquivos, sequencias e genes não processados
files_processed = 0
sequences_processed = 0
genes_not_found = 0

# Percorrer todas as pastas e arquivos
for root_folder, folders, files in os.walk(root_directory):
    for file in files:
        genome_file_path = os.path.join(root_folder, file)
        if genome_file_path.endswith('sequencias_alinhadas.fasta'):
        # if genome_file_path.endswith('_unique_sequences.fasta'):
            files_processed += 1
            print(f'Processando {files_processed}º arquivo: {genome_file_path}')
            genome_sequences = read_genome_sequences(genome_file_path)

            for genome_sequence in genome_sequences:

                sequences_processed += 1

              # Criar um arquivo temporário para armazenar a sequência de DNA do genoma
                temp_file = tempfile.NamedTemporaryFile(mode='w', delete=False)
                temp_file.write(f'>{genome_sequence[0]}\n{genome_sequence[1]}')

                # Caminho para o arquivo temporário do genoma
                genoma_temp_file = temp_file.name

                # Pega as Posições Inicial e Final do Gene no Genoma e Pega a Substring
                positions = fetch_gene_position(
                    reference_gene_file_path, genoma_temp_file)
                
                if positions is not None:
                    gene_start_position, gene_final_position = positions
                    gene_sequence = genome_sequence[1][gene_start_position:gene_final_position + 1]
                    gene_file_path = os.path.join(root_folder, gene_file_name)

                    with open(gene_file_path, 'a') as gene_file:
                        gene_file.write(
                            f'>spike(pos.ini:{gene_start_position} pos.fin:{gene_final_position}){genome_sequence[0]}\n{gene_sequence}\n')

                    # Remover o arquivo temporário
                    os.remove(genoma_temp_file)

                    temp_file.close()
                else:
                    genes_not_found += 1
                    print(f'Sequência não processada: {genome_sequence[0]}')

print('Busca Completa Concluída.')
# Out:
# Processando 1º arquivo: /home/m_souza/tcc/dataset/teste/A.1/sequencias_alinhadas.fasta
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT632542
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT683396
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT419810
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT419812
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT419816
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT419834
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT419836
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW485419
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW485422
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW485425
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW485424
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW485427
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW485428
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT791882
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT798143
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT810508
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT810552
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT810553
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT810556
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT810560
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT810565
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT810941
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT811164
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT811187
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT811205
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT811271
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT821583
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT827816
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT827817
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT827818
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT827821
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT827841
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886303
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886337
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886338
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886341
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886357
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886363
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886367
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886371
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886381
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT163720
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT246458
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT246463
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT246472
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT246473
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT246479
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT246485
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT251977
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252681
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252683
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252684
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252685
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252686
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252689
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252691
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252693
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252699
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252701
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252703
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252704
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252708
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252709
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252720
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252721
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252725
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252730
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252737
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252749
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252758
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252760
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252771
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252775
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252778
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252787
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252788
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252801
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252803
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252809
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252811
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252812
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252815
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252816
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252818
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252822
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT252823
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259241
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259245
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259247
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259253
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259262
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259268
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259274
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259280
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259284
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259287
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263383
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263388
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263412
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263414
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263422
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263423
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263434
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263441
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263448
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263449
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263451
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263453
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263455
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263456
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263457
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263462
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293158
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293163
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293168
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293169
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293170
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293184
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293185
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293188
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293190
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293194
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293199
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT293206
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326034
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326039
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326041
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326044
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326053
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326085
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326094
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326102
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326110
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326111
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326121
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326123
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326124
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326135
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326138
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326144
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326147
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326148
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326151
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326155
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326165
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326166
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326168
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT326181
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT345800
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT345822
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT345842
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT375457
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT375476
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT375477
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT412241
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT412323
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT520450
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT520468
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW030206
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT627239
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW286692
# Processando 2º arquivo: /home/m_souza/tcc/dataset/teste/A.2/sequencias_alinhadas.fasta
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|LR883095
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|LR883133
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|LR883453
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ785372
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|OA967002
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|OA976810
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT757004
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT811322
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW030208
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW030228
# Processando 3º arquivo: /home/m_souza/tcc/dataset/teste/A/sequencias_alinhadas.fasta
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT134008
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT126746
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT134007
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT134010
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|ON303200
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT764177
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|ON924330
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|ON924329
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|ON924332
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|ON924334
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|ON924333
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|ON924335
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT811569
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886316
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT886336
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ433205
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ433206
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ433207
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ433210
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ433212
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ433211
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ363509
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ519407
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MZ519408
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT259252
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT263384
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MT291826
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW206483
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|LR794408
# Ocorreu um erro durante a busca da posição do gene:
# Sequência não processada: accn|MW008581
# Busca Completa Concluída.

# %%
from datetime import datetime

end_time = time.time()

elapsed_time = end_time - start_time
current_datetime = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ### Salvando Informações Sobra a Execução

# %%
import platform
import psutil

machine_info = platform.uname()
memory_info = psutil.virtual_memory()

path_directory = '/home/m_souza/TCC/Tcc_Implementacao/Mauricio_TCC_UnEB/03_pipeline_blast'

content = '============================================================\n'
content += 'Informações Sobre a Última Execução:\n\n'
content += f'- Quantidade de Variantes Analisadas: {files_processed}\n'
content += f'- Quantidade de Genomas Analisados: {sequences_processed}\n'
content += f'- Quantidade de Genomas em que o Gene não foi Encontrado: {genes_not_found}\n'
content += f'- Data e Hora da Execução: {current_datetime}\n'
content += f'- Tempo Total de Execução: {round(elapsed_time, 2)} Segundos\n'
content += f'- Caminho do Dataset Utilizado: {root_directory}\n'
content += f'\nInformações Sobre a Máquina Utilizada\n\n'
content += f'- S.O.: Ubuntu 22.04.2 LTS x86_64\n'
content += f'- Kernel: {machine_info.release}\n'
content += f'- CPU: Intel i7-6500U (4) @ 3.100GHz {machine_info.processor}\n'
content += f'- Total de Memória: {round(memory_info.total / (1024 ** 3), 2)}GB\n'


output_file_name = 'execution_information.txt'
output_file_path = os.path.join(path_directory, output_file_name)

with open(output_file_path, 'a') as output_file:
    output_file.write(content)

print(f'Information saved to file: {output_file_path}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/04_pipeline_blast_spike/pipeline_blast.ipynb Célula 12 line 2
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/04_pipeline_blast_spike/pipeline_blast.ipynb#X14sZmlsZQ%3D%3D?line=23'>24</a> output_file_name = 'execution_information.txt'
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/04_pipeline_blast_spike/pipeline_blast.ipynb#X14sZmlsZQ%3D%3D?line=24'>25</a> output_file_path = os.path.join(path_directory, output_file_name)
# ---> <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/04_pipeline_blast_spike/pipeline_blast.ipynb#X14sZmlsZQ%3D%3D?line=26'>27</a> with open(output_file_path, 'a') as output_file:
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/04_pipeline_blast_spike/pipeline_blast.ipynb#X14sZmlsZQ%3D%3D?line=27'>28</a>     output_file.write(content)
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/04_pipeline_blast_spike/pipeline_blast.ipynb#X14sZmlsZQ%3D%3D?line=29'>30</a> print(f'Information saved to file: {output_file_path}')
#
# File ~/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/.bioEnv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/m_souza/TCC/Tcc_Implementacao/Mauricio_TCC_UnEB/03_pipeline_blast/execution_information.txt'
