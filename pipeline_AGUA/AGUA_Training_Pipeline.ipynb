# %% [markdown]
# # AGUA : Ad hoc Genotyping with Unsupervised
# # Algorithm / Analysis / Approach / Advisor
# ## training pipeline Python script
# ### Diego Frias, 23.10.2022

# %%
# %pip install seaborn

# %%
#import our three important packages
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import os
import sys
import Bio as Bio
from Bio import SeqIO
from Bio import AlignIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import Phylo
import seaborn as sns
import time as time
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform

import pandas as pd
import random 

import dill

import re

# %% [markdown]
# # FASE 1 - PREPROCESSAMENTO
# ## LEITURA DO DATASET DE TREINAMENTO & IDENTIFICAÇÃO/CODIFICAÇÃO DE CLASSES PRIMÁRIAS

# %%
base = [16, 4, 1]

nucleotides = {
"A": 0,
"G": 1,
"C": 2,
"T": 3,
"a": 0,
"g": 1,
"c": 2,
"t": 3,
"-": 4,
"N": 5,
"n": 5
}
    
stops=["TAA","TAG","TGA"]
    
stopnmb=[]

for triplet in stops:
    codonNumber = 0 # 0 to 63
    for p in range(3):
          codonNumber += base[p] * nucleotides[triplet[p]]
    stopnmb.append(codonNumber)

print("stop codon ordinals ",stopnmb)
# Out:
# stop codon ordinals  [48, 49, 52]

# %%
#import the sequences we will use. These are 16s sequences from GenBank
#example: https://www.ncbi.nlm.nih.gov/nuccore/FJ039971.1?report=genbank 
fname = "/home/m_souza/tcc/dataset/teste/A/sequencias_spike_filtradas.fasta"
# fname = "/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/spike_alignment.fas"
# t1 = SeqIO.read("sequence1.fasta", "fasta")
# t2 = SeqIO.read("sequence2.fasta", "fasta")
# t3 = SeqIO.read("sequence3.fasta", "fasta")
# t4 = SeqIO.read("sequence4.fasta", "fasta")
# t5 = SeqIO.read("sequence5.fasta", "fasta")
# t6 = SeqIO.read("sequence6.fasta", "fasta")
# t7 = SeqIO.read("sequence7.fasta", "fasta")

t=[]
with open(fname) as handle:
    for values in SeqIO.FastaIO.SimpleFastaParser(handle):
        t.append(values)
        print(t[-1][0])
        
Nseq=len(t)

print("number of sequences in file ",fname," = ",Nseq)
# Out:
# spike(pos.ini:21562 pos.fin:25384)accn|MT630423
# spike(pos.ini:21562 pos.fin:25384)accn|MW309830
# spike(pos.ini:21562 pos.fin:25384)accn|MT632776
# spike(pos.ini:21562 pos.fin:25384)accn|MW056081
# spike(pos.ini:21562 pos.fin:25384)accn|MW064329
# spike(pos.ini:21562 pos.fin:25384)accn|MW064332
# spike(pos.ini:21562 pos.fin:25384)accn|MW064338
# spike(pos.ini:21562 pos.fin:25384)accn|MW064351
# spike(pos.ini:21562 pos.fin:25384)accn|MW064354
# spike(pos.ini:21562 pos.fin:25384)accn|MT635409
# spike(pos.ini:21562 pos.fin:25384)accn|LR884173
# spike(pos.ini:21562 pos.fin:25384)accn|MW064586
# spike(pos.ini:21562 pos.fin:25384)accn|MW064588
# spike(pos.ini:21562 pos.fin:25384)accn|MW064589
# spike(pos.ini:21562 pos.fin:25384)accn|MW064594
# spike(pos.ini:21562 pos.fin:25384)accn|MT641662
# spike(pos.ini:21562 pos.fin:25384)accn|MW064634
# spike(pos.ini:21562 pos.fin:25384)accn|MW064659
# spike(pos.ini:21562 pos.fin:25384)accn|MT641740
# spike(pos.ini:21562 pos.fin:25384)accn|MW064715
# spike(pos.ini:21562 pos.fin:25384)accn|MW064719
# spike(pos.ini:21562 pos.fin:25384)accn|MW064720
# spike(pos.ini:21562 pos.fin:25384)accn|MW064732
# spike(pos.ini:21562 pos.fin:25384)accn|MZ344995
# spike(pos.ini:21562 pos.fin:25384)accn|MW064818
# spike(pos.ini:21562 pos.fin:25384)accn|MW064821
# spike(pos.ini:21562 pos.fin:25384)accn|MW064841
# spike(pos.ini:21562 pos.fin:25384)accn|MW064846
# spike(pos.ini:21562 pos.fin:25384)accn|MW064902
# spike(pos.ini:21562 pos.fin:25384)accn|MW064907
# spike(pos.ini:21562 pos.fin:25384)accn|MW064983
# spike(pos.ini:21562 pos.fin:25384)accn|MW065006
# spike(pos.ini:21562 pos.fin:25384)accn|MW065031
# spike(pos.ini:21562 pos.fin:25384)accn|MT644268
# spike(pos.ini:21562 pos.fin:25384)accn|MT664197
# spike(pos.ini:21562 pos.fin:25384)accn|MT670015
# spike(pos.ini:21562 pos.fin:25384)accn|MW065259
# spike(pos.ini:21562 pos.fin:25384)accn|MW065319
# spike(pos.ini:21562 pos.fin:25384)accn|MT678839
# spike(pos.ini:21562 pos.fin:25384)accn|MW065384
# spike(pos.ini:21562 pos.fin:25384)accn|MW340787
# spike(pos.ini:21562 pos.fin:25384)accn|MW340788
# spike(pos.ini:21562 pos.fin:25384)accn|MW340789
# spike(pos.ini:21562 pos.fin:25384)accn|MW340790
# spike(pos.ini:21562 pos.fin:25384)accn|MW340791
# spike(pos.ini:21562 pos.fin:25384)accn|MW340794
# spike(pos.ini:21562 pos.fin:25384)accn|MW340795
# spike(pos.ini:21562 pos.fin:25384)accn|MW340796
# spike(pos.ini:21562 pos.fin:25384)accn|MW340797
# spike(pos.ini:21562 pos.fin:25384)accn|MW340798
# spike(pos.ini:21562 pos.fin:25384)accn|MW340799
# spike(pos.ini:21562 pos.fin:25384)accn|MW065429
# spike(pos.ini:21562 pos.fin:25384)accn|MW065473
# spike(pos.ini:21562 pos.fin:25384)accn|OU170350
# spike(pos.ini:21562 pos.fin:25384)accn|MT704030
# spike(pos.ini:21562 pos.fin:25384)accn|MT704033
# spike(pos.ini:21562 pos.fin:25384)accn|MT704045
# spike(pos.ini:21562 pos.fin:25384)accn|MT704130
# spike(pos.ini:21562 pos.fin:25384)accn|MT706149
# spike(pos.ini:21562 pos.fin:25384)accn|MT706168
# spike(pos.ini:21562 pos.fin:25384)accn|MT706294
# spike(pos.ini:21562 pos.fin:25384)accn|MT706317
# spike(pos.ini:21562 pos.fin:25384)accn|MT706363
# spike(pos.ini:21562 pos.fin:25384)accn|MT706373
# spike(pos.ini:21562 pos.fin:25384)accn|MT739451
# spike(pos.ini:21562 pos.fin:25384)accn|MT740923
# spike(pos.ini:21562 pos.fin:25384)accn|MT653078
# spike(pos.ini:21562 pos.fin:25384)accn|MT653079
# spike(pos.ini:21562 pos.fin:25384)accn|MT653080
# spike(pos.ini:21562 pos.fin:25384)accn|MT653081
# spike(pos.ini:21562 pos.fin:25384)accn|MW543043
# spike(pos.ini:21562 pos.fin:25384)accn|MZ331876
# spike(pos.ini:21562 pos.fin:25384)accn|MZ331894
# spike(pos.ini:21562 pos.fin:25384)accn|MW190770
# spike(pos.ini:21562 pos.fin:25384)accn|MW191482
# spike(pos.ini:21562 pos.fin:25384)accn|MW368439
# spike(pos.ini:21562 pos.fin:25384)accn|LR883557
# spike(pos.ini:21562 pos.fin:25384)accn|MW590344
# spike(pos.ini:21562 pos.fin:25384)accn|MW548228
# spike(pos.ini:21562 pos.fin:25384)accn|MZ363487
# spike(pos.ini:21562 pos.fin:25384)accn|MZ363512
# spike(pos.ini:21562 pos.fin:25384)accn|OU097617
# spike(pos.ini:21562 pos.fin:25384)accn|MW521480
# spike(pos.ini:21562 pos.fin:25384)accn|MW521483
# spike(pos.ini:21562 pos.fin:25384)accn|MW593327
# spike(pos.ini:21562 pos.fin:25384)accn|MW593336
# spike(pos.ini:21562 pos.fin:25384)accn|MW550607
# spike(pos.ini:21562 pos.fin:25384)accn|MW523409
# spike(pos.ini:21562 pos.fin:25384)accn|MW593811
# spike(pos.ini:21562 pos.fin:25384)accn|MT412134
# spike(pos.ini:21562 pos.fin:25384)accn|MT412160
# spike(pos.ini:21562 pos.fin:25384)accn|MT412167
# spike(pos.ini:21562 pos.fin:25384)accn|MT412177
# spike(pos.ini:21562 pos.fin:25384)accn|MT412183
# spike(pos.ini:21562 pos.fin:25384)accn|MT451116
# spike(pos.ini:21562 pos.fin:25384)accn|MT451241
# spike(pos.ini:21562 pos.fin:25384)accn|MT451448
# spike(pos.ini:21562 pos.fin:25384)accn|MT451584
# spike(pos.ini:21562 pos.fin:25384)accn|MZ664556
# spike(pos.ini:21562 pos.fin:25384)accn|MZ747235
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824620
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824621
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824639
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824640
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824642
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824643
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824645
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824646
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824648
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824649
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824650
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824651
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824652
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824653
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824654
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824655
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824658
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824661
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824662
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824663
# spike(pos.ini:21562 pos.fin:25384)accn|MZ824664
# spike(pos.ini:21562 pos.fin:25384)accn|MZ906034
# spike(pos.ini:21562 pos.fin:25384)accn|MZ906091
# spike(pos.ini:21562 pos.fin:25384)accn|MZ908070
# spike(pos.ini:21562 pos.fin:25384)accn|MZ905656
# spike(pos.ini:21562 pos.fin:25384)accn|MZ905663
# spike(pos.ini:21562 pos.fin:25384)accn|MZ905704
# spike(pos.ini:21562 pos.fin:25384)accn|MZ905733
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930250
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930251
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930252
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930392
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930393
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930396
# spike(pos.ini:21562 pos.fin:25384)accn|OU471698
# spike(pos.ini:21562 pos.fin:25384)accn|OU471727
# spike(pos.ini:21562 pos.fin:25384)accn|OK449075
# spike(pos.ini:21562 pos.fin:25384)accn|OK449076
# spike(pos.ini:21562 pos.fin:25384)accn|MT862537
# spike(pos.ini:21562 pos.fin:25384)accn|MZ995184
# spike(pos.ini:21562 pos.fin:25384)accn|MZ995185
# spike(pos.ini:21562 pos.fin:25384)accn|MZ995186
# spike(pos.ini:21562 pos.fin:25384)accn|OK041127
# spike(pos.ini:21562 pos.fin:25384)accn|OK041128
# spike(pos.ini:21562 pos.fin:25384)accn|OK041129
# spike(pos.ini:21562 pos.fin:25384)accn|OK041130
# spike(pos.ini:21562 pos.fin:25384)accn|OK041131
# spike(pos.ini:21562 pos.fin:25384)accn|OK041132
# spike(pos.ini:21562 pos.fin:25384)accn|OK041133
# spike(pos.ini:21562 pos.fin:25384)accn|OK091601
# spike(pos.ini:21562 pos.fin:25384)accn|OK474795
# spike(pos.ini:21562 pos.fin:25384)accn|OL411674
# spike(pos.ini:21562 pos.fin:25384)accn|OL549088
# spike(pos.ini:21562 pos.fin:25384)accn|OL601556
# spike(pos.ini:21562 pos.fin:25384)accn|OL601649
# spike(pos.ini:21562 pos.fin:25384)accn|OU994357
# spike(pos.ini:21562 pos.fin:25384)accn|OU995756
# spike(pos.ini:21562 pos.fin:25384)accn|OV005913
# spike(pos.ini:21562 pos.fin:25384)accn|OV005946
# spike(pos.ini:21562 pos.fin:25384)accn|OU995973
# spike(pos.ini:21562 pos.fin:25384)accn|OV006243
# spike(pos.ini:21562 pos.fin:25384)accn|OV006248
# spike(pos.ini:21562 pos.fin:25384)accn|OV027171
# spike(pos.ini:21562 pos.fin:25384)accn|OV027559
# spike(pos.ini:21562 pos.fin:25384)accn|OU998653
# spike(pos.ini:21562 pos.fin:25384)accn|OV029549
# spike(pos.ini:21562 pos.fin:25384)accn|OV029573
# spike(pos.ini:21562 pos.fin:25384)accn|OU999664
# spike(pos.ini:21562 pos.fin:25384)accn|OU990151
# spike(pos.ini:21562 pos.fin:25384)accn|OU990167
# spike(pos.ini:21562 pos.fin:25384)accn|OU990230
# spike(pos.ini:21562 pos.fin:25384)accn|OU990262
# spike(pos.ini:21562 pos.fin:25384)accn|OV039252
# spike(pos.ini:21562 pos.fin:25384)accn|OV039283
# spike(pos.ini:21562 pos.fin:25384)accn|OV039278
# spike(pos.ini:21562 pos.fin:25384)accn|OV039304
# spike(pos.ini:21562 pos.fin:25384)accn|OV089971
# spike(pos.ini:21562 pos.fin:25384)accn|OL756168
# spike(pos.ini:21562 pos.fin:25384)accn|OL756181
# spike(pos.ini:21562 pos.fin:25384)accn|OL756213
# spike(pos.ini:21562 pos.fin:25384)accn|OL756281
# spike(pos.ini:21562 pos.fin:25384)accn|OL756401
# spike(pos.ini:21562 pos.fin:25384)accn|OL756420
# spike(pos.ini:21562 pos.fin:25384)accn|OL756429
# spike(pos.ini:21562 pos.fin:25384)accn|OL756440
# spike(pos.ini:21562 pos.fin:25384)accn|OL756587
# spike(pos.ini:21562 pos.fin:25384)accn|OL756605
# spike(pos.ini:21562 pos.fin:25384)accn|OL756909
# spike(pos.ini:21562 pos.fin:25384)accn|OL756973
# spike(pos.ini:21562 pos.fin:25384)accn|MW635193
# spike(pos.ini:21562 pos.fin:25384)accn|OV043501
# spike(pos.ini:21562 pos.fin:25384)accn|OV044690
# spike(pos.ini:21562 pos.fin:25384)accn|OV044717
# spike(pos.ini:21562 pos.fin:25384)accn|OV044719
# spike(pos.ini:21562 pos.fin:25384)accn|OV044757
# spike(pos.ini:21562 pos.fin:25384)accn|OL816602
# spike(pos.ini:21562 pos.fin:25384)accn|OL816735
# spike(pos.ini:21562 pos.fin:25384)accn|OL816777
# spike(pos.ini:21562 pos.fin:25384)accn|OL816794
# spike(pos.ini:21562 pos.fin:25384)accn|OL816908
# spike(pos.ini:21562 pos.fin:25384)accn|OV047307
# spike(pos.ini:21562 pos.fin:25384)accn|OV047308
# spike(pos.ini:21562 pos.fin:25384)accn|OV064953
# spike(pos.ini:21562 pos.fin:25384)accn|OV064963
# spike(pos.ini:21562 pos.fin:25384)accn|OV065031
# spike(pos.ini:21562 pos.fin:25384)accn|OV091138
# spike(pos.ini:21562 pos.fin:25384)accn|OU007909
# spike(pos.ini:21562 pos.fin:25384)accn|OL840814
# spike(pos.ini:21562 pos.fin:25384)accn|OU011231
# spike(pos.ini:21562 pos.fin:25384)accn|OU011245
# spike(pos.ini:21562 pos.fin:25384)accn|OU011556
# spike(pos.ini:21562 pos.fin:25384)accn|OL890791
# spike(pos.ini:21562 pos.fin:25384)accn|OL891043
# spike(pos.ini:21562 pos.fin:25384)accn|OL891230
# spike(pos.ini:21562 pos.fin:25384)accn|MW751146
# spike(pos.ini:21562 pos.fin:25384)accn|MW751308
# spike(pos.ini:21562 pos.fin:25384)accn|FR998379
# spike(pos.ini:21562 pos.fin:25384)accn|FR998472
# spike(pos.ini:21562 pos.fin:25384)accn|HG998648
# spike(pos.ini:21562 pos.fin:25384)accn|MW772455
# spike(pos.ini:21562 pos.fin:25384)accn|OM065341
# spike(pos.ini:21562 pos.fin:25384)accn|OM065344
# spike(pos.ini:21562 pos.fin:25384)accn|OM065345
# spike(pos.ini:21562 pos.fin:25384)accn|OM065348
# spike(pos.ini:21562 pos.fin:25384)accn|OM065350
# spike(pos.ini:21562 pos.fin:25384)accn|OM065362
# spike(pos.ini:21562 pos.fin:25384)accn|OM065379
# spike(pos.ini:21562 pos.fin:25384)accn|OM065387
# spike(pos.ini:21562 pos.fin:25384)accn|MT134008
# spike(pos.ini:21562 pos.fin:25384)accn|MT126746
# spike(pos.ini:21562 pos.fin:25384)accn|MT134007
# spike(pos.ini:21562 pos.fin:25384)accn|MT020782
# spike(pos.ini:21562 pos.fin:25384)accn|MT134010
# spike(pos.ini:21562 pos.fin:25384)accn|MT730116
# spike(pos.ini:21562 pos.fin:25384)accn|MT730117
# spike(pos.ini:21562 pos.fin:25384)accn|MW422000
# spike(pos.ini:21562 pos.fin:25384)accn|OL980269
# spike(pos.ini:21562 pos.fin:25384)accn|OM095210
# spike(pos.ini:21562 pos.fin:25384)accn|OM095213
# spike(pos.ini:21562 pos.fin:25384)accn|OM301683
# spike(pos.ini:21562 pos.fin:25384)accn|OM301684
# spike(pos.ini:21562 pos.fin:25384)accn|OM319524
# spike(pos.ini:21562 pos.fin:25384)accn|OM319525
# spike(pos.ini:21562 pos.fin:25384)accn|MW811435
# spike(pos.ini:21562 pos.fin:25384)accn|MT318829
# spike(pos.ini:21562 pos.fin:25384)accn|MT318828
# spike(pos.ini:21562 pos.fin:25384)accn|OM403303
# spike(pos.ini:21562 pos.fin:25384)accn|OM403304
# spike(pos.ini:21562 pos.fin:25384)accn|MW828340
# spike(pos.ini:21562 pos.fin:25384)accn|OM418389
# spike(pos.ini:21562 pos.fin:25384)accn|OM692350
# spike(pos.ini:21562 pos.fin:25384)accn|MW925130
# spike(pos.ini:21562 pos.fin:25384)accn|MW883297
# spike(pos.ini:21562 pos.fin:25384)accn|MW941059
# spike(pos.ini:21562 pos.fin:25384)accn|OM389139
# spike(pos.ini:21562 pos.fin:25384)accn|OM389137
# spike(pos.ini:21562 pos.fin:25384)accn|OM389144
# spike(pos.ini:21562 pos.fin:25384)accn|OM389146
# spike(pos.ini:21562 pos.fin:25384)accn|OM389143
# spike(pos.ini:21562 pos.fin:25384)accn|OM739099
# spike(pos.ini:21562 pos.fin:25384)accn|MW972743
# spike(pos.ini:21562 pos.fin:25384)accn|MW973251
# spike(pos.ini:21562 pos.fin:25384)accn|MW973257
# spike(pos.ini:21562 pos.fin:25384)accn|MZ043009
# spike(pos.ini:21562 pos.fin:25384)accn|MZ043008
# spike(pos.ini:21562 pos.fin:25384)accn|MZ043007
# spike(pos.ini:21562 pos.fin:25384)accn|ON303200
# spike(pos.ini:21562 pos.fin:25384)accn|MW837147
# spike(pos.ini:21562 pos.fin:25384)accn|ON311289
# spike(pos.ini:21562 pos.fin:25384)accn|MZ093196
# spike(pos.ini:21562 pos.fin:25384)accn|MZ093197
# spike(pos.ini:21562 pos.fin:25384)accn|MZ093198
# spike(pos.ini:21562 pos.fin:25384)accn|ON394272
# spike(pos.ini:21562 pos.fin:25384)accn|OW426683
# spike(pos.ini:21562 pos.fin:25384)accn|OW407447
# spike(pos.ini:21562 pos.fin:25384)accn|OW433979
# spike(pos.ini:21562 pos.fin:25384)accn|OW479331
# spike(pos.ini:21562 pos.fin:25384)accn|OW522335
# spike(pos.ini:21562 pos.fin:25384)accn|ON532638
# spike(pos.ini:21562 pos.fin:25384)accn|ON532639
# spike(pos.ini:21562 pos.fin:25384)accn|ON532644
# spike(pos.ini:21562 pos.fin:25384)accn|ON532642
# spike(pos.ini:21562 pos.fin:25384)accn|ON532643
# spike(pos.ini:21562 pos.fin:25384)accn|ON532650
# spike(pos.ini:21562 pos.fin:25384)accn|ON532653
# spike(pos.ini:21562 pos.fin:25384)accn|ON532661
# spike(pos.ini:21562 pos.fin:25384)accn|ON532656
# spike(pos.ini:21562 pos.fin:25384)accn|ON532657
# spike(pos.ini:21562 pos.fin:25384)accn|ON532658
# spike(pos.ini:21562 pos.fin:25384)accn|ON532659
# spike(pos.ini:21562 pos.fin:25384)accn|ON532664
# spike(pos.ini:21562 pos.fin:25384)accn|ON532662
# spike(pos.ini:21562 pos.fin:25384)accn|ON532663
# spike(pos.ini:21562 pos.fin:25384)accn|ON532673
# spike(pos.ini:21562 pos.fin:25384)accn|ON532668
# spike(pos.ini:21562 pos.fin:25384)accn|ON532670
# spike(pos.ini:21562 pos.fin:25384)accn|ON532669
# spike(pos.ini:21562 pos.fin:25384)accn|OA966241
# spike(pos.ini:21562 pos.fin:25384)accn|MW504778
# spike(pos.ini:21562 pos.fin:25384)accn|ON653597
# spike(pos.ini:21562 pos.fin:25384)accn|OA971955
# spike(pos.ini:21562 pos.fin:25384)accn|OA972178
# spike(pos.ini:21562 pos.fin:25384)accn|MT232662
# spike(pos.ini:21562 pos.fin:25384)accn|OA975893
# spike(pos.ini:21562 pos.fin:25384)accn|OA976891
# spike(pos.ini:21562 pos.fin:25384)accn|OA978154
# spike(pos.ini:21562 pos.fin:25384)accn|OA978534
# spike(pos.ini:21562 pos.fin:25384)accn|LC716263
# spike(pos.ini:21562 pos.fin:25384)accn|MW340792
# spike(pos.ini:21562 pos.fin:25384)accn|MW340793
# spike(pos.ini:21562 pos.fin:25384)accn|MW466792
# spike(pos.ini:21562 pos.fin:25384)accn|MW466791
# spike(pos.ini:21562 pos.fin:25384)accn|MW466793
# spike(pos.ini:21562 pos.fin:25384)accn|MW466794
# spike(pos.ini:21562 pos.fin:25384)accn|MW466796
# spike(pos.ini:21562 pos.fin:25384)accn|ON876210
# spike(pos.ini:21562 pos.fin:25384)accn|MW467478
# spike(pos.ini:21562 pos.fin:25384)accn|ON929925
# spike(pos.ini:21562 pos.fin:25384)accn|MW493719
# spike(pos.ini:21562 pos.fin:25384)accn|MW493757
# spike(pos.ini:21562 pos.fin:25384)accn|OA993433
# spike(pos.ini:21562 pos.fin:25384)accn|OX074292
# spike(pos.ini:21562 pos.fin:25384)accn|MW474741
# spike(pos.ini:21562 pos.fin:25384)accn|OX079154
# spike(pos.ini:21562 pos.fin:25384)accn|OX082901
# spike(pos.ini:21562 pos.fin:25384)accn|OX083418
# spike(pos.ini:21562 pos.fin:25384)accn|OX090565
# spike(pos.ini:21562 pos.fin:25384)accn|OD913810
# spike(pos.ini:21562 pos.fin:25384)accn|MW447618
# spike(pos.ini:21562 pos.fin:25384)accn|MW504605
# spike(pos.ini:21562 pos.fin:25384)accn|OD928542
# spike(pos.ini:21562 pos.fin:25384)accn|MT757064
# spike(pos.ini:21562 pos.fin:25384)accn|MT757066
# spike(pos.ini:21562 pos.fin:25384)accn|MT757078
# spike(pos.ini:21562 pos.fin:25384)accn|MT759714
# spike(pos.ini:21562 pos.fin:25384)accn|MT764172
# spike(pos.ini:21562 pos.fin:25384)accn|MT764173
# spike(pos.ini:21562 pos.fin:25384)accn|MT764174
# spike(pos.ini:21562 pos.fin:25384)accn|MT764175
# spike(pos.ini:21562 pos.fin:25384)accn|MT764176
# spike(pos.ini:21562 pos.fin:25384)accn|MT764177
# spike(pos.ini:21562 pos.fin:25384)accn|MT764179
# spike(pos.ini:21562 pos.fin:25384)accn|MT764183
# spike(pos.ini:21562 pos.fin:25384)accn|MT772271
# spike(pos.ini:21562 pos.fin:25384)accn|MT772293
# spike(pos.ini:21562 pos.fin:25384)accn|OP471797
# spike(pos.ini:21562 pos.fin:25384)accn|OP471800
# spike(pos.ini:21562 pos.fin:25384)accn|OP471809
# spike(pos.ini:21562 pos.fin:25384)accn|MT772554
# spike(pos.ini:21562 pos.fin:25384)accn|MW134531
# spike(pos.ini:21562 pos.fin:25384)accn|MW136841
# spike(pos.ini:21562 pos.fin:25384)accn|MT791848
# spike(pos.ini:21562 pos.fin:25384)accn|MW153064
# spike(pos.ini:21562 pos.fin:25384)accn|MT797768
# spike(pos.ini:21562 pos.fin:25384)accn|MT797765
# spike(pos.ini:21562 pos.fin:25384)accn|MT797769
# spike(pos.ini:21562 pos.fin:25384)accn|MT799991
# spike(pos.ini:21562 pos.fin:25384)accn|ON924330
# spike(pos.ini:21562 pos.fin:25384)accn|ON924329
# spike(pos.ini:21562 pos.fin:25384)accn|ON924332
# spike(pos.ini:21562 pos.fin:25384)accn|ON924334
# spike(pos.ini:21562 pos.fin:25384)accn|ON924333
# spike(pos.ini:21562 pos.fin:25384)accn|ON924335
# spike(pos.ini:21562 pos.fin:25384)accn|MT800010
# spike(pos.ini:21562 pos.fin:25384)accn|MT800016
# spike(pos.ini:21562 pos.fin:25384)accn|OP659019
# spike(pos.ini:21562 pos.fin:25384)accn|OP659018
# spike(pos.ini:21562 pos.fin:25384)accn|MT810119
# spike(pos.ini:21562 pos.fin:25384)accn|OL549281
# spike(pos.ini:21562 pos.fin:25384)accn|OM995890
# spike(pos.ini:21562 pos.fin:25384)accn|OM995891
# spike(pos.ini:21562 pos.fin:25384)accn|OP934235
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050272
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050299
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050325
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050376
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050383
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050409
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050456
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050495
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050499
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050510
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050513
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050560
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050567
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050594
# spike(pos.ini:21562 pos.fin:25384)accn|OQ050792
# spike(pos.ini:21562 pos.fin:25384)accn|ON194114
# spike(pos.ini:21562 pos.fin:25384)accn|ON194134
# spike(pos.ini:21562 pos.fin:25384)accn|ON194284
# spike(pos.ini:21562 pos.fin:25384)accn|MT811569
# spike(pos.ini:21562 pos.fin:25384)accn|MT827233
# spike(pos.ini:21562 pos.fin:25384)accn|MT827239
# spike(pos.ini:21562 pos.fin:25384)accn|MT827245
# spike(pos.ini:21562 pos.fin:25384)accn|OQ334911
# spike(pos.ini:21562 pos.fin:25384)accn|OQ348219
# spike(pos.ini:21562 pos.fin:25384)accn|OD959800
# spike(pos.ini:21562 pos.fin:25384)accn|OD960289
# spike(pos.ini:21562 pos.fin:25384)accn|MZ505927
# spike(pos.ini:21562 pos.fin:25384)accn|MW018428
# spike(pos.ini:21562 pos.fin:25384)accn|MW018429
# spike(pos.ini:21562 pos.fin:25384)accn|MW018430
# spike(pos.ini:21562 pos.fin:25384)accn|MW018431
# spike(pos.ini:21562 pos.fin:25384)accn|MW018432
# spike(pos.ini:21562 pos.fin:25384)accn|MW018434
# spike(pos.ini:21562 pos.fin:25384)accn|MW018437
# spike(pos.ini:21562 pos.fin:25384)accn|MW018436
# spike(pos.ini:21562 pos.fin:25384)accn|MT834632
# spike(pos.ini:21562 pos.fin:25384)accn|MT844034
# spike(pos.ini:21562 pos.fin:25384)accn|MT844088
# spike(pos.ini:21562 pos.fin:25384)accn|MT844089
# spike(pos.ini:21562 pos.fin:25384)accn|MT846444
# spike(pos.ini:21562 pos.fin:25384)accn|MT846476
# spike(pos.ini:21562 pos.fin:25384)accn|MT846623
# spike(pos.ini:21562 pos.fin:25384)accn|MT873878
# spike(pos.ini:21562 pos.fin:25384)accn|MW161259
# spike(pos.ini:21562 pos.fin:25384)accn|MT886316
# spike(pos.ini:21562 pos.fin:25384)accn|MT886336
# spike(pos.ini:21562 pos.fin:25384)accn|MW751133
# spike(pos.ini:21562 pos.fin:25384)accn|MT886404
# spike(pos.ini:21562 pos.fin:25384)accn|MT892984
# spike(pos.ini:21562 pos.fin:25384)accn|MT892986
# spike(pos.ini:21562 pos.fin:25384)accn|MT892994
# spike(pos.ini:21562 pos.fin:25384)accn|MT893002
# spike(pos.ini:21562 pos.fin:25384)accn|MZ278430
# spike(pos.ini:21562 pos.fin:25384)accn|MW181829
# spike(pos.ini:21562 pos.fin:25384)accn|MW181831
# spike(pos.ini:21562 pos.fin:25384)accn|MT919999
# spike(pos.ini:21562 pos.fin:25384)accn|MT920002
# spike(pos.ini:21562 pos.fin:25384)accn|MT920007
# spike(pos.ini:21562 pos.fin:25384)accn|MT920008
# spike(pos.ini:21562 pos.fin:25384)accn|MT920010
# spike(pos.ini:21562 pos.fin:25384)accn|MT920014
# spike(pos.ini:21562 pos.fin:25384)accn|MT920025
# spike(pos.ini:21562 pos.fin:25384)accn|MW018435
# spike(pos.ini:21562 pos.fin:25384)accn|MT940472
# spike(pos.ini:21562 pos.fin:25384)accn|MT940473
# spike(pos.ini:21562 pos.fin:25384)accn|MZ313123
# spike(pos.ini:21562 pos.fin:25384)accn|MT951951
# spike(pos.ini:21562 pos.fin:25384)accn|MT952602
# spike(pos.ini:21562 pos.fin:25384)accn|MT955171
# spike(pos.ini:21562 pos.fin:25384)accn|MT956689
# spike(pos.ini:21562 pos.fin:25384)accn|MT956695
# spike(pos.ini:21562 pos.fin:25384)accn|MZ331924
# spike(pos.ini:21562 pos.fin:25384)accn|MZ433205
# spike(pos.ini:21562 pos.fin:25384)accn|MZ433206
# spike(pos.ini:21562 pos.fin:25384)accn|MZ433207
# spike(pos.ini:21562 pos.fin:25384)accn|MZ433210
# spike(pos.ini:21562 pos.fin:25384)accn|MZ433212
# spike(pos.ini:21562 pos.fin:25384)accn|MZ433211
# spike(pos.ini:21562 pos.fin:25384)accn|MN938384
# spike(pos.ini:21562 pos.fin:25384)accn|MT966110
# spike(pos.ini:21562 pos.fin:25384)accn|MN975262
# spike(pos.ini:21562 pos.fin:25384)accn|MN985325
# spike(pos.ini:21562 pos.fin:25384)accn|MN988713
# spike(pos.ini:21562 pos.fin:25384)accn|MN994467
# spike(pos.ini:21562 pos.fin:25384)accn|MN997409
# spike(pos.ini:21562 pos.fin:25384)accn|MT044257
# spike(pos.ini:21562 pos.fin:25384)accn|MT049951
# spike(pos.ini:21562 pos.fin:25384)accn|MT066175
# spike(pos.ini:21562 pos.fin:25384)accn|MT079848
# spike(pos.ini:21562 pos.fin:25384)accn|MT079849
# spike(pos.ini:21562 pos.fin:25384)accn|MT079851
# spike(pos.ini:21562 pos.fin:25384)accn|MT079852
# spike(pos.ini:21562 pos.fin:25384)accn|MT106052
# spike(pos.ini:21562 pos.fin:25384)accn|MT106054
# spike(pos.ini:21562 pos.fin:25384)accn|MT135041
# spike(pos.ini:21562 pos.fin:25384)accn|MT135043
# spike(pos.ini:21562 pos.fin:25384)accn|MT226610
# spike(pos.ini:21562 pos.fin:25384)accn|MT230904
# spike(pos.ini:21562 pos.fin:25384)accn|MT233526
# spike(pos.ini:21562 pos.fin:25384)accn|MZ363509
# spike(pos.ini:21562 pos.fin:25384)accn|MZ363510
# spike(pos.ini:21562 pos.fin:25384)accn|MZ331895
# spike(pos.ini:21562 pos.fin:25384)accn|MZ468053
# spike(pos.ini:21562 pos.fin:25384)accn|MZ433886
# spike(pos.ini:21562 pos.fin:25384)accn|MT246667
# spike(pos.ini:21562 pos.fin:25384)accn|MT252731
# spike(pos.ini:21562 pos.fin:25384)accn|MZ519410
# spike(pos.ini:21562 pos.fin:25384)accn|MZ519415
# spike(pos.ini:21562 pos.fin:25384)accn|MZ519417
# spike(pos.ini:21562 pos.fin:25384)accn|MT259252
# spike(pos.ini:21562 pos.fin:25384)accn|MT263384
# spike(pos.ini:21562 pos.fin:25384)accn|MT263386
# spike(pos.ini:21562 pos.fin:25384)accn|MW190208
# spike(pos.ini:21562 pos.fin:25384)accn|MW190246
# spike(pos.ini:21562 pos.fin:25384)accn|MW190248
# spike(pos.ini:21562 pos.fin:25384)accn|MT276330
# spike(pos.ini:21562 pos.fin:25384)accn|MT291826
# spike(pos.ini:21562 pos.fin:25384)accn|MT291831
# spike(pos.ini:21562 pos.fin:25384)accn|MT291832
# spike(pos.ini:21562 pos.fin:25384)accn|MT291833
# spike(pos.ini:21562 pos.fin:25384)accn|MT291834
# spike(pos.ini:21562 pos.fin:25384)accn|MT291836
# spike(pos.ini:21562 pos.fin:25384)accn|MW190290
# spike(pos.ini:21562 pos.fin:25384)accn|MW190325
# spike(pos.ini:21562 pos.fin:25384)accn|MT295465
# spike(pos.ini:21562 pos.fin:25384)accn|MT304480
# spike(pos.ini:21562 pos.fin:25384)accn|MT308703
# spike(pos.ini:21562 pos.fin:25384)accn|MT322411
# spike(pos.ini:21562 pos.fin:25384)accn|MT324684
# spike(pos.ini:21562 pos.fin:25384)accn|MT325567
# spike(pos.ini:21562 pos.fin:25384)accn|MT325571
# spike(pos.ini:21562 pos.fin:25384)accn|MT325572
# spike(pos.ini:21562 pos.fin:25384)accn|MT325573
# spike(pos.ini:21562 pos.fin:25384)accn|MT325575
# spike(pos.ini:21562 pos.fin:25384)accn|MW190459
# spike(pos.ini:21562 pos.fin:25384)accn|MW190462
# spike(pos.ini:21562 pos.fin:25384)accn|MT325607
# spike(pos.ini:21562 pos.fin:25384)accn|MT325608
# spike(pos.ini:21562 pos.fin:25384)accn|MW190491
# spike(pos.ini:21562 pos.fin:25384)accn|MT325625
# spike(pos.ini:21562 pos.fin:25384)accn|MT325628
# spike(pos.ini:21562 pos.fin:25384)accn|MW190540
# spike(pos.ini:21562 pos.fin:25384)accn|MW190598
# spike(pos.ini:21562 pos.fin:25384)accn|MW190657
# spike(pos.ini:21562 pos.fin:25384)accn|MW190698
# spike(pos.ini:21562 pos.fin:25384)accn|MW190739
# spike(pos.ini:21562 pos.fin:25384)accn|MW190741
# spike(pos.ini:21562 pos.fin:25384)accn|MW190796
# spike(pos.ini:21562 pos.fin:25384)accn|MW190811
# spike(pos.ini:21562 pos.fin:25384)accn|MW190858
# spike(pos.ini:21562 pos.fin:25384)accn|MW190881
# spike(pos.ini:21562 pos.fin:25384)accn|MW190885
# spike(pos.ini:21562 pos.fin:25384)accn|MW190886
# spike(pos.ini:21562 pos.fin:25384)accn|MW190889
# spike(pos.ini:21562 pos.fin:25384)accn|MW190962
# spike(pos.ini:21562 pos.fin:25384)accn|MW190964
# spike(pos.ini:21562 pos.fin:25384)accn|MW190966
# spike(pos.ini:21562 pos.fin:25384)accn|MW190972
# spike(pos.ini:21562 pos.fin:25384)accn|MW190992
# spike(pos.ini:21562 pos.fin:25384)accn|MW191013
# spike(pos.ini:21562 pos.fin:25384)accn|OU077473
# spike(pos.ini:21562 pos.fin:25384)accn|MW191038
# spike(pos.ini:21562 pos.fin:25384)accn|MW191053
# spike(pos.ini:21562 pos.fin:25384)accn|MT370857
# spike(pos.ini:21562 pos.fin:25384)accn|MW191129
# spike(pos.ini:21562 pos.fin:25384)accn|MW191211
# spike(pos.ini:21562 pos.fin:25384)accn|MW191212
# spike(pos.ini:21562 pos.fin:25384)accn|MW191216
# spike(pos.ini:21562 pos.fin:25384)accn|MT374101
# spike(pos.ini:21562 pos.fin:25384)accn|MW191289
# spike(pos.ini:21562 pos.fin:25384)accn|MW191316
# spike(pos.ini:21562 pos.fin:25384)accn|OU101475
# spike(pos.ini:21562 pos.fin:25384)accn|MT385472
# spike(pos.ini:21562 pos.fin:25384)accn|MW191407
# spike(pos.ini:21562 pos.fin:25384)accn|MW191413
# spike(pos.ini:21562 pos.fin:25384)accn|MW191433
# spike(pos.ini:21562 pos.fin:25384)accn|MT407649
# spike(pos.ini:21562 pos.fin:25384)accn|MT407650
# spike(pos.ini:21562 pos.fin:25384)accn|MT407651
# spike(pos.ini:21562 pos.fin:25384)accn|MT407653
# spike(pos.ini:21562 pos.fin:25384)accn|MT407658
# spike(pos.ini:21562 pos.fin:25384)accn|MW191468
# spike(pos.ini:21562 pos.fin:25384)accn|OU097220
# spike(pos.ini:21562 pos.fin:25384)accn|MT447162
# spike(pos.ini:21562 pos.fin:25384)accn|MT450932
# spike(pos.ini:21562 pos.fin:25384)accn|MT450942
# spike(pos.ini:21562 pos.fin:25384)accn|MT450943
# spike(pos.ini:21562 pos.fin:25384)accn|MT450948
# spike(pos.ini:21562 pos.fin:25384)accn|MT450950
# spike(pos.ini:21562 pos.fin:25384)accn|MT450966
# spike(pos.ini:21562 pos.fin:25384)accn|MT450968
# spike(pos.ini:21562 pos.fin:25384)accn|MT450971
# spike(pos.ini:21562 pos.fin:25384)accn|MT450995
# spike(pos.ini:21562 pos.fin:25384)accn|MT450996
# spike(pos.ini:21562 pos.fin:25384)accn|MT451017
# spike(pos.ini:21562 pos.fin:25384)accn|MT451021
# spike(pos.ini:21562 pos.fin:25384)accn|MT451026
# spike(pos.ini:21562 pos.fin:25384)accn|MW206481
# spike(pos.ini:21562 pos.fin:25384)accn|MW206483
# spike(pos.ini:21562 pos.fin:25384)accn|MW206492
# spike(pos.ini:21562 pos.fin:25384)accn|MT451877
# spike(pos.ini:21562 pos.fin:25384)accn|MW219695
# spike(pos.ini:21562 pos.fin:25384)accn|MW221275
# spike(pos.ini:21562 pos.fin:25384)accn|MT499203
# spike(pos.ini:21562 pos.fin:25384)accn|MT499215
# spike(pos.ini:21562 pos.fin:25384)accn|MT502774
# spike(pos.ini:21562 pos.fin:25384)accn|OU187702
# spike(pos.ini:21562 pos.fin:25384)accn|LC542976
# spike(pos.ini:21562 pos.fin:25384)accn|OU196083
# spike(pos.ini:21562 pos.fin:25384)accn|MT506888
# spike(pos.ini:21562 pos.fin:25384)accn|LC581364
# spike(pos.ini:21562 pos.fin:25384)accn|MT507032
# spike(pos.ini:21562 pos.fin:25384)accn|MT509506
# spike(pos.ini:21562 pos.fin:25384)accn|MT509511
# spike(pos.ini:21562 pos.fin:25384)accn|MT512425
# spike(pos.ini:21562 pos.fin:25384)accn|MT512431
# spike(pos.ini:21562 pos.fin:25384)accn|OU196327
# spike(pos.ini:21562 pos.fin:25384)accn|MT512439
# spike(pos.ini:21562 pos.fin:25384)accn|MT512441
# spike(pos.ini:21562 pos.fin:25384)accn|MT512443
# spike(pos.ini:21562 pos.fin:25384)accn|LR757995
# spike(pos.ini:21562 pos.fin:25384)accn|LR794408
# spike(pos.ini:21562 pos.fin:25384)accn|MT520189
# spike(pos.ini:21562 pos.fin:25384)accn|MT520245
# spike(pos.ini:21562 pos.fin:25384)accn|OU216968
# spike(pos.ini:21562 pos.fin:25384)accn|MT520307
# spike(pos.ini:21562 pos.fin:25384)accn|MT520360
# spike(pos.ini:21562 pos.fin:25384)accn|MT520542
# spike(pos.ini:21562 pos.fin:25384)accn|MT528602
# spike(pos.ini:21562 pos.fin:25384)accn|MT528603
# spike(pos.ini:21562 pos.fin:25384)accn|MT528608
# spike(pos.ini:21562 pos.fin:25384)accn|MT528610
# spike(pos.ini:21562 pos.fin:25384)accn|MT528619
# spike(pos.ini:21562 pos.fin:25384)accn|MT528626
# spike(pos.ini:21562 pos.fin:25384)accn|MT528628
# spike(pos.ini:21562 pos.fin:25384)accn|MT534310
# spike(pos.ini:21562 pos.fin:25384)accn|MT539163
# spike(pos.ini:21562 pos.fin:25384)accn|OU240148
# spike(pos.ini:21562 pos.fin:25384)accn|MT539170
# spike(pos.ini:21562 pos.fin:25384)accn|MT539174
# spike(pos.ini:21562 pos.fin:25384)accn|OU251236
# spike(pos.ini:21562 pos.fin:25384)accn|MT557568
# spike(pos.ini:21562 pos.fin:25384)accn|MT559038
# spike(pos.ini:21562 pos.fin:25384)accn|MT568635
# spike(pos.ini:21562 pos.fin:25384)accn|MT568639
# spike(pos.ini:21562 pos.fin:25384)accn|MT568640
# spike(pos.ini:21562 pos.fin:25384)accn|MT568641
# spike(pos.ini:21562 pos.fin:25384)accn|MT576034
# spike(pos.ini:21562 pos.fin:25384)accn|MT576563
# spike(pos.ini:21562 pos.fin:25384)accn|MW008567
# spike(pos.ini:21562 pos.fin:25384)accn|MW008568
# spike(pos.ini:21562 pos.fin:25384)accn|MW008569
# spike(pos.ini:21562 pos.fin:25384)accn|MW008571
# spike(pos.ini:21562 pos.fin:25384)accn|MW008576
# spike(pos.ini:21562 pos.fin:25384)accn|MT578015
# spike(pos.ini:21562 pos.fin:25384)accn|MW008582
# spike(pos.ini:21562 pos.fin:25384)accn|MW008584
# spike(pos.ini:21562 pos.fin:25384)accn|MW023416
# spike(pos.ini:21562 pos.fin:25384)accn|MW023498
# spike(pos.ini:21562 pos.fin:25384)accn|MT611968
# spike(pos.ini:21562 pos.fin:25384)accn|MW279436
# spike(pos.ini:21562 pos.fin:25384)accn|MW279446
# spike(pos.ini:21562 pos.fin:25384)accn|OU279884
# spike(pos.ini:21562 pos.fin:25384)accn|MT614476
# spike(pos.ini:21562 pos.fin:25384)accn|MT614483
# spike(pos.ini:21562 pos.fin:25384)accn|OU280570
# spike(pos.ini:21562 pos.fin:25384)accn|OU280311
# spike(pos.ini:21562 pos.fin:25384)accn|MT614522
# spike(pos.ini:21562 pos.fin:25384)accn|MT614529
# spike(pos.ini:21562 pos.fin:25384)accn|MT614562
# spike(pos.ini:21562 pos.fin:25384)accn|MT614601
# spike(pos.ini:21562 pos.fin:25384)accn|MT621560
# spike(pos.ini:21562 pos.fin:25384)accn|MT622319
# spike(pos.ini:21562 pos.fin:25384)accn|MT627215
# spike(pos.ini:21562 pos.fin:25384)accn|MW286655
# spike(pos.ini:21562 pos.fin:25384)accn|MW286728
# spike(pos.ini:21562 pos.fin:25384)accn|LR878309
# spike(pos.ini:21562 pos.fin:25384)accn|LR878325
# spike(pos.ini:21562 pos.fin:25384)accn|LR878334
# spike(pos.ini:21562 pos.fin:25384)accn|MW047016
# number of sequences in file  /home/m_souza/tcc/dataset/teste/A/sequencias_spike_filtradas.fasta  =  652

# %%
# # Open the alignment file as a MultipleSeqAlignment object 

# idlst = []
# sequences = []
# labels = []
# ctr = 0

# # Abra o arquivo de alinhamento e leia as sequências como objetos SeqRecord
# with open(fname, "r") as aln:
#     for seq_record in SeqIO.parse(aln, "fasta"):
#         sequences.append(seq_record)

# Nseqs = len(sequences)
# print("Número de sequências no alinhamento:", Nseqs)


# Open the alignment file as a MultipleSeqAlignment object 

with open(fname,"r") as aln: 
    alignment = AlignIO.read(aln,"fasta")

idlst=[]
sequences=[]
labels=[]
ctr=0
for strain in alignment:
#     print(strain.description)
    
    if strain.description not in idlst:
        idlst.append(strain.description)
    else:
        print(ctr, "duplicated description ",strain.description)
        
    labels.append("strain"+str(ctr)) # strain.description # o id só saia cortado e acahava depois que itnha sequncias repetidas
    sequences.append(alignment[ctr].seq)
    ctr+=1
    
Nseqs=len(sequences)
print("number of seqs in the alignment", Nseqs)
# Out:
# number of seqs in the alignment 652

# %%
def nucleotideToCodon(tripleNucleotides):
    
    codonNumber = 0 # 0 to 63

    for p in range(3):
        if ("AGCTagct".find(tripleNucleotides[p]) != -1):
            codonNumber += base[p] * nucleotides[tripleNucleotides[p]]
        else:
            codonNumber = 64 if tripleNucleotides[p] == "-" else 65
            break
    
    #debb
#     if codonNumber in stopnmb:
#         print("codon ",codonNumber," found in sequence")
        
    return codonNumber

def nucleotideSequenceToCodons(sequence):
    tripleNucleotidesList = [sequence[i:i + 3] for i in range(0, len(sequence), 3)]
    return list(map(lambda triple: nucleotideToCodon(triple), tripleNucleotidesList))

# %%
# transformando sequencias de nucleotideos a codons 

print(len(sequences[0]))

sequenceLength = len(sequences[0])

if (sequenceLength % 3 != 0):
    print(sequenceLength)
    print("ERRO: tamanho não Múltiplo de 3")
    exit(1)
elif (next((True for seq in sequences if len(seq) > sequenceLength), False)):
    print("ERRO: as sequências não tem o mesmo tamanho")
else:
    nprm = int(sequenceLength / 3) # comprimento das seqs em codons

print(f"O dataset contem {Nseqs} sequências com {nprm} resíduos.")
print("Transformação das sequências de nucleotídeos em sequências númericas de códons.")

start = time.time()

codonSequences = list(map(lambda seq: nucleotideSequenceToCodons(seq), sequences))

print(f"Transformação concluída em {(time.time() - start) / 60} minutos");
# Out:
# 3822
# O dataset contem 652 sequências com 1274 resíduos.
# Transformação das sequências de nucleotídeos em sequências númericas de códons.
# Transformação concluída em 0.03518389860788981 minutos

# %%
print(np.min(codonSequences[0]),np.max(codonSequences[0]))
# Out:
# 0 63

# %%
# filtrando sequências com stop codons TGA,TAG,TAA
filtered_codonSeqs=[]
filtered_SeqID=[]
ctr=0
laststop=0
for seq in codonSequences:
    stopfound=False
    for stp in stopnmb:
        stoppos=np.where(np.array(seq)==stp)[0]
        if len(stoppos)>0:
            if len(stoppos)==1 and (stoppos[0]==nprm-1): # last stop found
                laststop=1
            else:
                print(" stop codon ",stp," found in frame in sequence ",alignment[ctr].id," at positions ",stoppos[0])  
                stopfound=True
                break
            
    if not stopfound:
        filtered_codonSeqs.append(seq[:-laststop]) #excluindo o ultimo stop se existir
        filtered_SeqID.append(alignment[ctr].id)
   
    ctr+=1

# %%
print(len(codonSequences[0]),len(filtered_codonSeqs[0]))
# Out:
# 1274 1273

# %%
# transformando o dataset em matriz de codons

cdnseq=np.array(filtered_codonSeqs)
print(cdnseq.shape)

# contando número de codons distintos por coluna (sítios)
cdns=[]
V=[]

for pos in range(cdnseq.shape[1]):
    cdnlst=list(set(list(cdnseq[:,pos])))
    V.append(len(cdnlst))
    cdns.append(cdnlst)
# Out:
# (652, 1273)

# %%
V=np.array(V)

# ordeno as colunas de maior a menor variabilidade
# Idx=np.argsort(-V)
# print("Idx",Idx)
# print("V[Idx]",V[Idx])

# seleciono as colunas com variabilidade > 1
var_sites=np.argwhere(V>1)
Var_Sites=[]
for site in var_sites:
    Var_Sites.append(int(site))
    
var=V[var_sites]

# print("var",var)

IDsz=len(var_sites)
print("ID size ",IDsz)

# gero os IDs com os codons de cada seq (lista de listas)

ID=cdnseq[:,var_sites].tolist() # vetor coluna de IDs como vetores linha

strID=[] # lista de IDs como strings
for lst in ID:
    strID.append(str(lst).replace('[','').replace(']',''))
# Out:
# ID size  298
# /tmp/ipykernel_14153/3461033398.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   Var_Sites.append(int(site))

# %%
# check 
print(len(strID),"=",Nseqs)
# Out:
# 652 = 652

# %%
# gero a lista de string IDs das classes primárias - unique
start=time.time()
p=[] # vetor com string das IDs das classes primárias
pvec=[]
for Id in strID:
    if Id not in p:
        p.append(Id)
        pvec.append(np.array(p[-1].split(", ")))

print("check string and vector of chars")
print(p[0])
print(pvec[0])

# numero de classes primarias
P=len(p)
print("there were found ",P," primary classes in the dataset with ",Nseqs," sequences in ",time.time()-start," segundos")
# Out:
# check string and vector of chars
# 47, 40, 47, 42, 43, 24, 50, 11, 62, 50, 58, 35, 35, 27, 12, 35, 30, 59, 21, 10, 3, 23, 11, 63, 30, 63, 19, 11, 17, 4, 1, 2, 31, 31, 0, 63, 61, 23, 31, 51, 34, 0, 0, 7, 13, 62, 59, 7, 25, 3, 3, 54, 11, 63, 16, 51, 30, 43, 47, 18, 20, 0, 3, 62, 15, 63, 0, 1, 3, 29, 39, 19, 33, 23, 57, 27, 60, 15, 35, 19, 59, 56, 23, 53, 8, 27, 23, 27, 24, 23, 19, 47, 18, 43, 46, 11, 62, 11, 16, 0, 30, 32, 4, 24, 2, 27, 30, 11, 63, 1, 55, 51, 63, 11, 15, 4, 23, 19, 16, 30, 4, 32, 14, 40, 21, 32, 11, 20, 1, 15, 27, 19, 51, 3, 51, 0, 60, 40, 19, 19, 63, 59, 47, 1, 31, 23, 23, 51, 45, 4, 26, 23, 16, 63, 32, 32, 42, 3, 32, 35, 24, 40, 24, 11, 0, 17, 0, 1, 15, 27, 11, 63, 33, 19, 8, 15, 39, 24, 22, 55, 60, 35, 2, 18, 27, 51, 33, 11, 33, 11, 3, 59, 43, 37, 37, 24, 39, 7, 28, 27, 56, 31, 50, 59, 3, 59, 8, 10, 40, 29, 56, 39, 60, 20, 40, 12, 40, 6, 1, 44, 2, 24, 14, 51, 27, 24, 32, 1, 63, 2, 22, 47, 11, 31, 61, 45, 25, 8, 59, 10, 27, 32, 22, 59, 20, 0, 32, 27, 2, 47, 6, 58, 56, 47, 18, 29, 8, 22, 4, 47, 32, 11, 14, 56, 20, 58, 56, 35, 62, 43, 15, 14, 18, 23, 31, 43, 43, 40, 19, 56, 31, 28, 2, 15, 32, 0, 16, 15, 46, 1, 14, 46, 23, 13, 29, 46, 54, 46
# ['47' '40' '47' '42' '43' '24' '50' '11' '62' '50' '58' '35' '35' '27'
#  '12' '35' '30' '59' '21' '10' '3' '23' '11' '63' '30' '63' '19' '11' '17'
#  '4' '1' '2' '31' '31' '0' '63' '61' '23' '31' '51' '34' '0' '0' '7' '13'
#  '62' '59' '7' '25' '3' '3' '54' '11' '63' '16' '51' '30' '43' '47' '18'
#  '20' '0' '3' '62' '15' '63' '0' '1' '3' '29' '39' '19' '33' '23' '57'
#  '27' '60' '15' '35' '19' '59' '56' '23' '53' '8' '27' '23' '27' '24' '23'
#  '19' '47' '18' '43' '46' '11' '62' '11' '16' '0' '30' '32' '4' '24' '2'
#  '27' '30' '11' '63' '1' '55' '51' '63' '11' '15' '4' '23' '19' '16' '30'
#  '4' '32' '14' '40' '21' '32' '11' '20' '1' '15' '27' '19' '51' '3' '51'
#  '0' '60' '40' '19' '19' '63' '59' '47' '1' '31' '23' '23' '51' '45' '4'
#  '26' '23' '16' '63' '32' '32' '42' '3' '32' '35' '24' '40' '24' '11' '0'
#  '17' '0' '1' '15' '27' '11' '63' '33' '19' '8' '15' '39' '24' '22' '55'
#  '60' '35' '2' '18' '27' '51' '33' '11' '33' '11' '3' '59' '43' '37' '37'
#  '24' '39' '7' '28' '27' '56' '31' '50' '59' '3' '59' '8' '10' '40' '29'
#  '56' '39' '60' '20' '40' '12' '40' '6' '1' '44' '2' '24' '14' '51' '27'
#  '24' '32' '1' '63' '2' '22' '47' '11' '31' '61' '45' '25' '8' '59' '10'
#  '27' '32' '22' '59' '20' '0' '32' '27' '2' '47' '6' '58' '56' '47' '18'
#  '29' '8' '22' '4' '47' '32' '11' '14' '56' '20' '58' '56' '35' '62' '43'
#  '15' '14' '18' '23' '31' '43' '43' '40' '19' '56' '31' '28' '2' '15' '32'
#  '0' '16' '15' '46' '1' '14' '46' '23' '13' '29' '46' '54' '46']
# there were found  189  primary classes in the dataset with  652  sequences in  0.005249977111816406  segundos

# %%
# salvando os códigos de cada classe primária para agrupamento com CLOPE - ## Entender e colocar na referência ##

# # print to test 
# print(p[:5])

# with open(r'SARS2.txt', 'w') as fp:
#     for item in p:
#         fp.write("{}\n".format(item))

# %%
# check
print(len(pvec),"=",P)
# Out:
# 189 = 189

# %%
# etiqueto as sequencias com a classe primária correspondente e conto o numero de sequencias em cada classe primária
pClass=[]
for Id in strID:
    pClass.append(p.index(Id))

# %%
# criando datafram com o Gene Variant File  

UniqueSeqs=[]
UniqueLabs=[]
UniqueClass=[]

unq, idxunq = np.unique(pClass, return_index=True)

# print(idxunq)

for i, idx in enumerate(idxunq):
    UniqueSeqs.append(sequences[idx])
    UniqueLabs.append(filtered_SeqID[idx])
    UniqueClass.append(unq[i])
#     print(">"+UniqueLabs[-1])
#     print(UniqueSeqs[-1])
#     print(UniqueClass[-1])

gvf = pd.DataFrame({'class':pd.Series(UniqueClass),'accession':pd.Series(UniqueLabs),'fasta_aln':pd.Series(UniqueSeqs)}) #,index=0)

gvf
# Out:
#      class            accession  \
# 0        0  spike(pos.ini:21562
# 1        1  spike(pos.ini:21562
# 2        2  spike(pos.ini:21562
# 3        3  spike(pos.ini:21562
# 4        4  spike(pos.ini:21562
# ..     ...                  ...
# 184    184  spike(pos.ini:21562
# 185    185  spike(pos.ini:21562
# 186    186  spike(pos.ini:21562
# 187    187  spike(pos.ini:21562
# 188    188  spike(pos.ini:21562
#
#                                              fasta_aln
# 0    (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 1    (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 2    (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 3    (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 4    (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# ..                                                 ...
# 184  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 185  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 186  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 187  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 188  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
#
# [189 rows x 3 columns]

# %%
# histograma de frequencia das classes primárias - depende do ordenamento
plt.hist(pClass,P)
plt.show()

# %%
class Model:
    def __init__(self, name = "", rep=2, nmbofclasses=0, nmbofclusters=0):
        
        self.name = name
        self.ListOfVarSites =[] #CBUC
        self.NmbOfClasses = nmbofclasses # CBUC
        self.CodeOfClass = [] # CBUC
        self.GroundTruth = [] # ANNOTATION
        self.NmbOfClusters =  nmbofclusters # CLOPE 
        self.TheClusterOfClass = {} # CLOPE
        self.TheSpeciesOfCluster = {} # CLOPE + ANNOTATION
        self.repulsion = rep # CLOPE 
        self.MinClusterAcc = 0 #  MODEL
        self.Accuracy = 0 # MODEL
        self.ConfusionMatrix =[] # MODEL 
        self.Accession = [] # DATA - GVF -> Tipo de Arquivo Gene Variant File - Importante Variant Call Format VCF

# %%
model = Model("SARS2-spike",nmbofclasses=P)
model.ListOfVarSites = Var_Sites #CBUC

# %% [markdown]
# # FASE 2 - ANÁLISE QUANTITATIVA
#
# ## AGRUPAMENTO
# ## ANOTAÇÃO DAS CLASSES PRIMÁRIAS
# ## CÁLCULO DA ACURÁCIA

# %%
# classes e funções da clusterização com CLOPE

class Cluster:

    def __init__(self, history_count):
       # Histórico do número de transações em clusters
        self.history_count_transact = [0] * history_count
        # Área do histograma
        self.area = 0.0
        # A altura do histograma (no sentido de H=S/W). Esse valor não é calculado explicitamente em nenhum lugar.
         # Armazenado na classe para completar a descrição da classe e nada mais.
        self.height = 0.0
        # Largura do histograma (em termos de número de elementos)
        self.width = 0.0
        # Gradiente (no sentido de G=H/W). Esse valor não é calculado explicitamente em nenhum lugar. 
        # Armazenado na classe para completar a descrição da classe e nada mais.
        self.gradient = 0.0
        # Número de transações
        self.count_transactions = 0
        # Histograma
        self.histogram = {}

    '''
    Adicione uma transação ao cluster. Iterar sobre todos os elementos do histograma, completar o histograma
     parâmetros de entrada:
     transação -- fatia com objetos (transação)
    '''
    def add_transaction(self, transaction):
        # Iterar por todos os elementos do histograma um por um e adicionar à coluna correspondente do histograma. 
        # Se não há elemento em questão, então adicione uma nova coluna ao histograma
        for item in transaction:
            if not (item in self.histogram):
                self.histogram[item] = 1 # adiciona novo elelento ao histograma
            else:
                self.histogram[item] += 1 # incrementa o numero do elemento existente no histograma
        # Calculamos a área total do histograma no sentido de CLOPE (número de transações)
        self.area += float(len(transaction))
        # Calcular a largura do histograma (o número de objetos diferentes)
        self.width = float(len(self.histogram))
        # incrementa o número de transações no cluster
        self.count_transactions += 1

    '''
    Excluir transação do cluster. Passamos por todos os elementos do histograma, removemos todos os elementos da transação de
     histogramas
    
     parâmetros de entrada:
     transação -- fatia com objetos (transação)
     valores retornados:
     valor gradiente G (transação) # sem sentido 
    
     Dentro da classe, não há rastreamento de quais transações são adicionadas, quais são excluídas, portanto, se em
     o processo de modificação excluirá uma transação que não foi adicionada ao cluster correspondente, o algoritmo
     vai dar resultado errado    
     '''
    
    def remove_transaction(self, transaction):
            for item in transaction:
                if self.histogram[item] > 0: # new
                    self.histogram[item] -=1 # new
                if self.histogram[item] == 0:
                    del self.histogram[item]
            self.area -= float(len(transaction))
            self.width = float(len(self.histogram))
            self.count_transactions -= 1
            return # self.gradient # rare 


class CLOPE:

    def __init__(self, print_step=1000, random_seed=None): 
        
        if random_seed is not None:
            self.random_seed = random_seed
        else:
            self.random_seed = random.randint(0, 65536 + 1)
        
        # Lista de clusters
        self.clusters = {}  # CCluster
        # Números de clusters de ruído
        # Este objeto é necessário para não levar em consideração aqueles objetos que foram classificados como ruído
        self.noise_clusters = {}
        # Número de transações adicionadas
        self.count_transactions = 0
        # Número da iteração
        self.iteration = 0
        # inicializa dicionário: número da transação/número do cluster
        self.transaction = {}
        # Número máximo do cluster
        self.max_cluster_number = 0
        self.print_step = print_step

    '''
    A mudança de meta que a função objetivo receberá ao adicionar uma transação ao cluster clusterNumber é calculada.
     O cluster que entrega o valor máximo da função será o cluster desejado (ao qual se deve adicionar a transação)
     parâmetros de entrada:
     transação -- transação (lista de objetos)
     clusterNumber -- número do cluster cujo incremento está sendo calculado
     r -- repulsão no sentido de CLOPE
     valor retornado:
     Retorna o valor de alteração da função objetivo quando uma transação é adicionada ao cluster clusterNumber
    '''
    def get_delta(self, transaction, cluster_number, r):
        
        old_area = self.clusters[cluster_number].area
        old_width = self.clusters[cluster_number].width
        nmb_trans = self.clusters[cluster_number].count_transactions
        
        area = old_area + len(transaction) # calcula a área adicionando os objetos da transação
                                                                    # em análise
        # cálculo da largura do cluster
        width = old_width 
        for item in transaction:
            if not (item in self.clusters[cluster_number].histogram): # histogram tem a lista de objetos no cluster
                width += 1
        
        # calcula delta (variação da função objetivo com a adição da transação ao cluster cluster_number)
        new_delta_value = 0
        if width != 0:
            new_delta_value = area * (nmb_trans + 1) / (width ** r)
            
        # calcula o valor de delta sem a transação
        if old_width != 0:
            old_delta_value = old_area * nmb_trans / (old_width ** r)
        else:
            old_delta_value = 0
            
        return new_delta_value - old_delta_value

    '''
    Função de remoção de ruído. Todos os clusters maiores que o limite permanecem ativos.
     parâmetros de entrada:
     limite -- nível de ruído do cluster
    '''
    def noise_reduction(self, limit):
        # Remova todos os clusters vazios e barulhentos
        new_clusters = {}
        for item in self.clusters:
            if self.clusters[item].count_transactions > limit:# se o cluster é maior que o limite permanece na lista de clusters ativos
                new_clusters[item] = self.clusters[item]
            else: # clusters pequenos são considerados ruidosos e saem da lista de clusters ativo - 
                  # passam para alista de clusters com ruido
                self.noise_clusters[item] = True
        self.clusters = new_clusters

    '''
    Cálculo da função objetivo para todos os clusters já formados
     Usado ao modificar clusters ou inicializá-los
     parâmetros de entrada:
     r -- número real denotando repulsão de cluster no sentido de CLOPE
     valor retornado:
     Retorna o valor da função objetivo
    '''
    def get_goal_function(self, r):
        measure = 0.0
        # Percorremos todos os clusters e para cada um calculamos seu peso. 
        # Todos os pesos são resumidos em uma métrica comum
        for item in self.clusters:
            if item.width == 0:
                # print "test"
                pass
            else:
                # # Tentando encontrar uma métrica diferente
                # measure += (r ** 2 * math.log(item.Area ** (1 / r) / item.Width) ** 2) *
                # item.CountTransactions / self.CountTransactions
                measure += item.area / (item.width ** r) * item.count_transactions 
        return measure / self.count_transactions

    '''
     Adicionando uma nova transação
     Estamos tentando redistribuir a transação com o número de id em outra classe para que a função de custo tenha
     valor máximo
     parâmetros de entrada:
     transação -- transação (fatia com objetos)
     id -- número da transação
     repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
     isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
     parâmetro retornado:
     Retorna o número do cluster ao qual a transação atual foi adicionada
    '''
    def move_transaction(self, transaction, id, repulsion=2, max_count_clusters=None):
        
        r = repulsion
        max_value = None
        max_value_index = None
        self.count_transactions += 1
        
        # Estamos procurando um cluster no qual o valor máximo da mudança na função objetivo seja alcançado
        for cluster_number in self.clusters:
            delta = self.get_delta(transaction, cluster_number, r)
            if (delta > 0 or max_count_clusters is not None) and (max_value is None or delta > max_value):
                max_value_index = cluster_number
                max_value = delta

        # Adicione uma transação a um novo cluster e veja o resultado - registre o cluster com maior valor
        if max_count_clusters is None or len(self.clusters) < max_count_clusters:
            self.clusters[self.max_cluster_number] = Cluster(self.count_transactions)
            if max_value is None or self.get_delta(transaction, self.max_cluster_number, r) > max_value:
                max_value_index = self.max_cluster_number
                self.max_cluster_number += 1
            else:
                del self.clusters[self.max_cluster_number]

        # Lembramos em qual cluster está a transação atual
        self.transaction[id] = max_value_index

        #Adicionando uma transação ao cluster necessário
        self.clusters[max_value_index].add_transaction(transaction)

        return max_value_index

    '''
    Cálculo de limiar de ruído adaptativo. O limite é limpo em relação à mediana dos tamanhos de cluster (incluindo
     transações). Pegue 3/4 da mediana
    '''
    def get_noise_limit(self, percentile=0.75):
        size_clusters = []
        for item in self.clusters:
            size_clusters.append(self.clusters[item].count_transactions)
        sorted(size_clusters)
        median_element = int(len(size_clusters) * percentile) + 1
        if len(size_clusters) < 5:
            limit = 10
        else:
            limit = size_clusters[median_element]
        return limit

    '''
    Inicialização do cluster
    parâmetros de entrada:
    dados -- fatia com transações
    isPrint -- se deve imprimir informações de progresso (0 -- não é necessário, se > 0 -- imprimir a cada isPrint time)
    repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
    isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
    isNoiseReduction -- redução de ruído (limiar corresponde ao número de elementos no cluster no qual ele é destruído).
                        Se isNoiseReduction == -1, então o limite é selecionado de forma adaptativa (tudo que for maior que a mediana
                        restos)
    '''
    def init_clusters(self, data, repulsion=2, is_noise_reduction=-1, noise_median_threshold=0.75,
                      max_count_clusters=None):
        index = 0
        keys = sorted(data.keys())
        np.random.seed(self.random_seed)
        np.random.shuffle(keys)
        for item in keys:
            self.move_transaction(data[item], item, repulsion, max_count_clusters)
            index += 1
            if self.print_step > 0 and index % self.print_step == 0:
                print("ITERAÇÃO: ", self.iteration, ". NÚMERO DA ETAPA", index, ". NÚMERO DE CLUSTERS: ", len(self.clusters))
                pass

        # Obtendo o limite de ruído ideal
        if is_noise_reduction < 0:
            is_noise_reduction = self.get_noise_limit(noise_median_threshold)
        # Remova todos os clusters de ruído 
        # (após a inicialização, não há classes vazias, portanto, o sinal é estritamente maior)
        if is_noise_reduction > 0:
            self.noise_reduction(is_noise_reduction)

        self.iteration = 1

    '''
    Execução do algoritmo. Dando o próximo passo
    parâmetros de entrada:
    dados -- fatia com transações
    isPrint -- se deve imprimir informações de progresso (0 -- não é necessário, se > 0 -- imprimir a cada isPrint time)
    repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
    isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
    isNoiseReduction -- redução de ruído (limiar corresponde ao número de elementos no cluster no qual ele é destruído).
                        Se isNoiseReduction == -1, então o limite é selecionado de forma adaptativa (tudo que for maior que a mediana
                        restos)
    parâmetro retornado:
    Retorna o número de operações para transferir uma transação de cluster para cluster
    '''
    def next_step(self, data, repulsion=2, is_noise_reduction=-1, noise_median_threshold=0.75, max_count_clusters=None):

        # Remova todos os clusters vazios (ou ruído, se isNoiseReduction > 0)
        if is_noise_reduction < 0:
            is_noise_reduction = self.get_noise_limit(noise_median_threshold)
        self.noise_reduction(is_noise_reduction)

        index = 0
        # O número de transações que foram transferidas
        moves = 0
        keys = sorted(data.keys())
        np.random.seed(self.random_seed)
        np.random.shuffle(keys)
        for id in keys:
            # Nós olhamos onde esta transação está agora
            cluster_number = self.transaction[id]
            transaction = data[id]
            # Se a transação pertencer a um cluster de ruído, não tentaremos alterá-la
#             if cluster_number in self.noise_clusters:
#                 eps += 0
#             else:
            # Recuperar uma transação do cluster atual
            self.clusters[cluster_number].remove_transaction(transaction)
            # Consideramos a transação como recém-chegada e a adicionamos ao cluster onde o valor do destino
            # máximiza a função custo
            moves += int(self.move_transaction(transaction, id, repulsion, max_count_clusters) != cluster_number)
                
            index += 1
            if self.print_step is not None and self.print_step > 0 and index % self.print_step == 0:
#                 print("Итерация: ", self.iteration, ". Номер шага", index, ". Число кластеров: ", len(self.clusters))
#                 print("ITERAÇÃO: ", self.iteration, ". NÚMERO DA ETAPA", index, ". NÚMERO DE CLUSTERS: ", len(self.clusters))
                pass

        self.iteration += 1

        self.noise_reduction(is_noise_reduction)
        
        return moves

    '''
    Desenhamos um gráfico mostrando o número de transações em diferentes classes
    
    '''
    def print_history_count(self, repulsion, seed):
        pass

# %%
# funções que constroem a matriz de confusão e calculam o erro usando o ground truth 

def CompareResultAndAnnotation(accession, annot, clope, verbose=False):
    
    # pegamos a lista de genotipos distintos
    species=list(set(annot)) # colunas
    if verbose:
        print("list of genotypes in dataset:\n",species)# numeramos os genótipos segundo a ordem na lista
    species_nmb={} # dict 
    ctr=0
    for sp in species:
        species_nmb[sp]=ctr
        ctr+=1
    
    # calculamos o numero de transacoes de cada espécie (soma das colunas da matriz)
    colsum=np.zeros(len(species),dtype=int)
    for sp in annot:
        colsum[species_nmb[sp]]+=1
    if verbose:
        print("number of strain by genotype\n",colsum)
    
    # inicializa a matriz de confusão
    conf_matrix = np.zeros((clope.max_cluster_number,len(species)),dtype=int)
    # varre dict transaction {trans_id:cluster}
    for trans_id in range(len(clope.transaction)):
        cluster = clope.transaction[trans_id]
        conf_matrix[cluster,species_nmb[annot[trans_id]]]+=1
           
    # attributing most probable genotype to each cluster and eliminating empty clusters
    new_confmat=[]
    annotation={}
    for item in range(clope.max_cluster_number):
        if np.sum(conf_matrix[item])>0:
            new_confmat.append(conf_matrix[item])
            # anotando cada cluster com a especie mais provável
            sort=-np.sort(-conf_matrix[item])
            if sort[1]==sort[0]: # tem mais de um máximo
                annotation[accession[item]]="UNKNOWN"
            else:
                annotation[accession[item]]=species[np.argmax(conf_matrix[item])]
        
    return np.array(new_confmat), annotation

def GetClusteringError(confmat):
    
    # cálculo da métrica de erro relativo por cluster : numero de seqs - max
    acc=[]
    n=np.sum(confmat)
    tot_error=0
    for cluster in range(confmat.shape[0]):
        aux0 = np.sum(confmat[cluster])
        aux = aux0 - np.max(confmat[cluster])
        tot_error += aux
        if aux0>0:
            acc.append(1-aux/aux0)
        else: 
            acc.append(0)

    return np.array(acc), 1-tot_error/n

# %% [markdown]
# # acessando à anotação de cada classe primária

# %%
# GAMBEARRA   para pegar a anotação do genome detective QUE iNES MANDOU PARA MIM!

annot={"SARS-CoV-2humanAUSGC-2512020":" International A_B Diversity",
"SARS-CoV-2humanAUSQLD9352020":" International A_B Diversity",
"SARS-CoV-2humanAUSVIC012020":" International A_B Diversity",
"SARS-CoV-2humanAUSVIC962020":" International A_B Diversity",
"SARS-CoV-2humanAUSVIC172020":" International A_B Diversity",
"SARS-CoV-2humanBRASP02cc2020":" International A_B Diversity",
"SARS-CoV-2humanBRAcv2021":" International A_B Diversity",
"SARS-CoV-2humanBRARIO-RS":" International A_B Diversity",
"SARS-CoV-2Homo":" International A_B Diversity",
"SARS-CoV-2humanBRA30482021":" Gamma (P.1 20J)",
"SARS-CoV-2humanBRA39182021":" Gamma (P.1 20J)",
"SARS-CoV-2humanBRACD1739-P4202":" Gamma (P.1 20J)",
"SARS-CoV-2humanBRAPR-HF1022021":" International A_B Diversity",
"SARS-CoV-2humanBRARio-P12020":" International A_B Diversity",
"SARS-CoV-2humanCHNFuyang":" International A_B Diversity",
"SARS-CoV-2humanCHNYunnan-01202":" International A_B Diversity",
"SARS-CoV-2humanCOLCali-012020":" International A_B Diversity",
"SARS-CoV-2humanCZECzechiaMotol-0":" International A_B Diversity",
"SARS-CoV-2humanCZECzechiaMotol-1":" International A_B Diversity",
"SARS-CoV-2humanDNKDK-AHH12020":" International A_B Diversity",
"nCoV-FIN-29-Jan-2020":" International A_B Diversity",
"SARS-CoV-2humanFrance10027AA20":" International A_B Diversity",
"SARS-CoV-2humanFrance40005BH20":" International A_B Diversity",
"SARS-CoV-2humanDEUFFM52020":" International A_B Diversity",
"SARS-CoV-2humanDEUBavPat12020":" International A_B Diversity",
"SARS-CoV-2humanGRC35":" International A_B Diversity",
"SARS-CoV-2humanGRC36":" International A_B Diversity",
"SARS-CoV-2humanGUMGU-NHG-01202":" International A_B Diversity",
"SARS-CoV-2humanHKG.85":" International A_B Diversity",
"SARS-CoV-2humanIND509MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
"SARS-CoV-2humanIND528MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
"SARS-CoV-2humanIND565MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
"SARS-CoV-2humanINDWuhan2021":" Delta (B.1.617.2 21A,21I,21J)",
"SARS-CoV-2humanINDGBRC6482021":" International A_B Diversity",
"SARS-CoV-2humanINDILS212020":" International A_B Diversity",
"SARS-CoV-2humanINDhospital":" International A_B Diversity",
"SARS-CoV-2humanIND510MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
"SARS-CoV-2humanIND512MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
"SARS-CoV-2humanINDGBRC622020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC62020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC17a2020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC17b2020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC232020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC24a2020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC82020":" International A_B Diversity",
"SARS-CoV-2humanIND1662020":" International A_B Diversity",
"SARS-CoV-2humanINDAIIMS-Bhopal":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC12020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC122020":" International A_B Diversity",
"SARS-CoV-2humanINDGBRC162020":" International A_B Diversity",
"SARS-CoV-2humanIRNHGRC-2-21622":" International A_B Diversity",
"SARS-CoV-2humanITATE.237004202":" International A_B Diversity",
"SARS-CoV-2humanITAPango":" International A_B Diversity",
"SARS-CoV-2humanITAPV-5314-21Fe":" International A_B Diversity",
"SARS-CoV-2humanITAPA-IZSBM194-":" International A_B Diversity",
"TKY10468":" International A_B Diversity",
"hCoV-19JapanP4-82020":" International A_B Diversity",
"SARS-CoV-2humanLBY77002020":" International A_B Diversity",
"SARS-CoV-2humanMexicoSEARCH-10":" International A_B Diversity",
"SARS-CoV-2humanNZL20VR07702020":" International A_B Diversity",
"SARS-CoV-2humanPERPeru-102020":" International A_B Diversity",
"SARS-CoV2humanUSAPR-CDC-S92020":" International A_B Diversity",
"SARS-CoV-2humanZAFR030062020":" International A_B Diversity",
"SNU01":" International A_B Diversity",
"SARS-CoV-2humanESPValencia1420":" International A_B Diversity",
"SARS-CoV-2humanESPHUD-66682640":" International A_B Diversity",
"SARS-CoV-2humanSWE012020":" International A_B Diversity",
"SARS-CoV-2humanTWNCGMH-CGU-032":" International A_B Diversity",
"SARS-CoV-2humanTWNCGMH-CGU-022":" International A_B Diversity",
"SARS-CoV-2humanTHASI200615-NT2":" International A_B Diversity",
"SARS-CoV-2humanTHASI202620-NT2":" International A_B Diversity",
"SARS-CoV-2humanTURERAGEM-00120":" International A_B Diversity",
"SARS-CoV-2humanUSAIA-CDC-82002":" International A_B Diversity",
"SARS-CoV-2humanUSAIN-CDC-72003":" International A_B Diversity",
"USAMN1-MDH12020":" International A_B Diversity",
"SARS-CoV-2humanUSAAZ-ASU292220":" International A_B Diversity",
"SARS-CoV-2humanUSAVA-DCLS-0001":" International A_B Diversity",
"SARS-CoV-2humanUSAWI-UW-269202":" International A_B Diversity",
"SARS-CoV-2humanGBRRem2.5p13.52":" International A_B Diversity",
"SARS-CoV-2humanGBRCVR-GLA-2202":" International A_B Diversity",
"SARS-CoV-2humanVENBol47152021":" Gamma (P.1 20J)"}
# annot=np.array(annot)

# %%
# pegando as espécies virais anotadas
species=list(set(annot.values()))
print(species)
# Out:
# [' International A_B Diversity', ' Delta (B.1.617.2 21A,21I,21J)', ' Gamma (P.1 20J)']

# %%
def get_accession(new_accession, transactions):
    for j in range(len(transactions)):
#         print(new_accession,"=?",transactions[j][0].replace("/",""))
        if new_accession in transactions[j][0].replace("/",""):
            return transactions[j][0]
    return "unknown"

# %% [markdown]
# # random iterations:
# ## varying repulsion in a given search interval
# ## for each repulsion value:
# ### > finding clusters with different sorting of input
# ### > calculating minimum accuracies of clusters to control achievement of quality criteria
# ### > finishing random iterations  it check if repulsion satisfies the quality threshold:
# ### >> if OK exit the repulsion loop and build model data

# %%
# MAIN -----------------------------------------------------

# pegando a lista de accession
Acc = gvf['accession']
# tirando barras para match com annot
Accession0=[]
for acc in Acc:
    Accession0.append(acc.replace("/",""))
# print(Accession0[:3])

# pegando o groundthruth da anotação
GroundTruth0 = list(annot.values())
#GroundTruth0[:3]

# pegando os vetores de chars dos códigos das classes primárias como transações
InputData0 = pvec
nmb_trans=len(pvec)

nmb_annot=len(GroundTruth0)
print('check: number of transactions = annotations: ',nmb_trans,'=',nmb_annot)

if nmb_trans!=nmb_annot:
    print("DATASET NOT FULLY OR WRONGLY ANNOTATED .....\nRESULTS MAY BE CONFUSING....")
    
noiseLimit = 0.0 # dummy

nRandIterations=50 #50
ClusterAccThres=1.00

print("Looking for optimal repulsion with ",nRandIterations,"random iterations and threshold of minimum cluster accuracy of ",ClusterAccThres)

optimum=False
minRep=2
maxRep=20

for repulsion in range(minRep,maxRep): #>= 11 da 1005 acc de clusters com 200 iteracoes randomicas

    print("repulsion", repulsion)
    
    cluster_acc=[]
    Accuracy=[]

    K=3000
    best_cluster_acc=0

    codes = InputData0
    GT = GroundTruth0
        
    for i in range(nRandIterations):

#         print("RANDOM ITERATION ",i+1)

        seed = None #150 <<<<<<<<<<<<<<<<<<<<<<<< ORDENAÇÂO ALEATORIA
        np.random.seed(seed)

    #     InputData=InputData0.copy()
        list_zipped = list(zip(Accession0,InputData0,GroundTruth0))
        np.random.shuffle(list_zipped)
        Accession, InputData, GroundTruth = zip(*list_zipped) #unzipping

        # print('first transactions:\n',InputData[:3])
        # print('first annotations:\n',GroundTruth[:3])

        trans_len=len(InputData[0])

        Data = {} # usamos um dicionario para os dados com as features indexadas por posição

        for trans_nmb in range(0, len(InputData)):
            Data[trans_nmb] = [''] * trans_len # inicializa a transação efetiva 
            fst=0 # for SARS2
            for index in range(fst, len(InputData[trans_nmb])):
                # adicionando a posição (coluna) da feature se não for missing & counting missings
                if InputData[trans_nmb][index] != '?':
                    Data[trans_nmb][index] = str(index) + ":"+InputData[trans_nmb][index].replace(" ","")  # add feature position

        clope = CLOPE(print_step=1000, random_seed=seed) 
        # Dados iniciais

        # Inicializamos o algoritmo
        clope.init_clusters(Data, repulsion, noiseLimit)

            # Nós iteramos
        while clope.next_step(Data, repulsion, noiseLimit ) > 0:
            clope.print_history_count(repulsion, seed)

#         print("CLOPE number of clusters ",clope.max_cluster_number)
        # print(clope.transaction.values())
        # print("annot",list(GroundTruth))

        # cálculo do erro da classificação

        confmat, map_species2cluster = CompareResultAndAnnotation(Accession, GroundTruth, clope)
#         print("non-empty cluster number ",len(confmat))

#         print("matriz de confusão - quantas seqs pertencem a cada genótipo (colunas) em cada cluster (linha):\n",confmat)
#         print(map_species_cluster)

        # cálculo da métrica de erro por cluster : numero de seqs - max
        acc_lst, tot_acc = GetClusteringError(confmat) 

        cluster_acc.append(acc_lst)
        Accuracy.append(tot_acc)

#         print("erro relativo por cluster: \n",100*acc_lst," %")
#         print("acurácia total",100*tot_acc," %")

        # condition to choose the best clustering during iterations
        if (np.min(cluster_acc[-1])>best_cluster_acc) and (len(confmat)<K): 
            best_cluster_acc=np.min(cluster_acc[-1])
            K=len(confmat)
            best_confmat=confmat
            best_annotation = map_species2cluster
            map_class2cluster = clope.transaction  
            codes = InputData
            GT = GroundTruth
            best_accession = Accession
            
        del clope

        # calculo a media e desvio padrão da minima acuracia nos clusters em cada iteração
        min_lst=[]
        for i in range(len(cluster_acc)):
            min_lst.append(np.min(cluster_acc[i]))
        #     print(np.min(cluster_acc[i]))
        mean_min_cluster_acc=np.mean(min_lst)
        std_min_cluster_acc=np.std(min_lst)
        min_min_cluster_acc=np.min(min_lst)
    #     print("mean minimum cluster accuracy ",mean_min_cluster_acc," standard deviation ",std_min_cluster_acc)
    #     print("minimum minimum cluster accuracy ",min_min_cluster_acc,"estimated minimum minimum cluster accuracy ", \
    #           mean_min_cluster_acc-2*std_min_cluster_acc)
    
    # controle de optimalidade
    if min_min_cluster_acc >= ClusterAccThres:
        print("satisfied optimality criteria")
        optimum=True
        break

if optimum:
    model.NmbOfClusters=K
    model.Accuracy=np.mean(Accuracy) # MODEL
    model.MinClusterAcc=min_min_cluster_acc # MODEL
    model.ConfusionMatrix = best_confmat # MODEL
    model.CodeOfClass = codes # origin CBUC but shuffled by AGUA 
    model.GroundTruth = GT # ANNOTATION
    model.TheClusterOfClass = map_class2cluster # CLOPE
    model.TheSpeciesOfCluster = list(best_annotation.values()) # CLOPE + ANNOTATION
    baccession=[]
    for acc in best_accession:
        baccession.append(get_accession(acc,t))
    model.Accession=baccession # CBUC but shuffled by AGUA
    
    print("Mean accuracy of the model ",model.Accuracy," standard deviation of accuracy ",np.std(Accuracy))
    print("Number of Classes :",model.NmbOfClasses)
#     print("CodesOf Classes :\n",model.CodeOfClass)
#     print("Annotation of Classes :\n",model.GroundTruth) 
    print("Number of clusters",model.NmbOfClusters)
    print("Confusion matrix\n",pd.DataFrame(zip(model.ConfusionMatrix,model.TheSpeciesOfCluster)))
else:
    print("optimum not found for repulsion in the interval [",minRep,",",maxRep,"]")
# Out:
# check: number of transactions = annotations:  189 = 81
# DATASET NOT FULLY OR WRONGLY ANNOTATED .....
# RESULTS MAY BE CONFUSING....
# Looking for optimal repulsion with  50 random iterations and threshold of minimum cluster accuracy of  1.0
# repulsion 2
# repulsion 3
# repulsion 4
# repulsion 5
# repulsion 6
# repulsion 7
# repulsion 8
# repulsion 9
# repulsion 10
# repulsion 11
# repulsion 12
# repulsion 13
# repulsion 14
# repulsion 15
# repulsion 16
# repulsion 17
# repulsion 18
# repulsion 19
# optimum not found for repulsion in the interval [ 2 , 20 ]

# %%
# Check
# print(model.TheClusterOfClass)
# target = 1
# for pclass in model.TheClusterOfClass.keys():
#     if model.TheClusterOfClass[pclass]==target:
#         print("classes in cluster ",target," = ",pclass," annot ",model.GroundTruth[pclass])

# %% [markdown]
# # FASE 3 - ANÁLISE QUALITATIVA

# %%
# calculating distances between pairs of IDs -> put in categorical distance matrix

def categoricaldist(u,v,var,mode=0): # calcula a distancia entre 2 vetores categóricos: numero de entradas distintas / total de entradas
    dist=0
    for i in range(len(u)):
        if u[i]!=v[i]:
            if mode==0:
                dist+=1/var[i] # weighted -> INVERSAMENTE PROPORCIONAL À VARIABILIDADE DO SITE
            else:
                dist+=1 # SEM CONSIDERAR A VARIABILIDADE DO SITE
                
    return dist/len(u)

# -------------------------------------------------------------------

print("FASE2 - CÁLCULO DA MATRIZ DE DISTÂNCIAS ENTRE PARES DE CLASSES PRIMÁRIAS ")

fvec=model.CodeOfClass

start=time.time()

cat_distmatrix=[]
for i in range(P-1):
    cat_distmatrix.append([])
    for j in range(i+1,P):
#         dotdistmatrix[-1].append(np.dot(pvec[i],pvec[j]))
        cat_distmatrix[-1].append(categoricaldist(fvec[i],fvec[j],var,0))
#         print(i,j,np.dot(pvec[i],pvec[j]))
        
# check 
# for distvec in cat_distmatrix:
#     print(distvec)

# gerando matriz de distancias simetrica

# nota: os vetores dists , fst e scd estão alinhados, ou seja dists[k] é a distância entre a classe fst[k] e a scd[k] !!!

DistMat=np.zeros((P,P),dtype=float)
labels=[]
# fst & scd são o par de indexadores de cada distância (as classes primárias que são comparadas)
fst=[]
scd=[]
for i in range(P-1):
    labels.append("class"+str(i)+" annot "+model.GroundTruth[i]+ " cluster "+str(model.TheClusterOfClass[i])+" pred "+\
                  model.TheSpeciesOfCluster[model.TheClusterOfClass[i]])
    for j in range(i+1,P):
        fst.append(i)
        scd.append(j)
        DistMat[i][j]=cat_distmatrix[i][j-i-1]
        DistMat[j][i]=DistMat[i][j] # building a symmetric matrix
        
labels.append("class"+str(P-1)+" annot "+model.GroundTruth[P-1]+ " cluster "+str(model.TheClusterOfClass[P-1])+ " pred "+\
                  model.TheSpeciesOfCluster[model.TheClusterOfClass[P-1]])

print("matriz de distâncias\n", DistMat)

np.savetxt('dist_mat.txt', DistMat)

dists = squareform(DistMat) # saida para a construcao de arvores com dendogram
print("vetor de distancias\n", dists)

print(f"tempo:{time.time()-start} segundos")
# Out:
# FASE2 - CÁLCULO DA MATRIZ DE DISTÂNCIAS ENTRE PARES DE CLASSES PRIMÁRIAS
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb Célula 35 line 2
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=23'>24</a>     cat_distmatrix.append([])
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=24'>25</a>     for j in range(i+1,P):
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=25'>26</a> #         dotdistmatrix[-1].append(np.dot(pvec[i],pvec[j]))
# ---> <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=26'>27</a>         cat_distmatrix[-1].append(categoricaldist(fvec[i],fvec[j],var,0))
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=27'>28</a> #         print(i,j,np.dot(pvec[i],pvec[j]))
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=28'>29</a>
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=29'>30</a> # check
#    (...)
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=34'>35</a>
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=35'>36</a> # nota: os vetores dists , fst e scd estão alinhados, ou seja dists[k] é a distância entre a classe fst[k] e a scd[k] !!!
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=37'>38</a> DistMat=np.zeros((P,P),dtype=float)
#
# IndexError: list index out of range

# %%
#atualizando labels com a especie predita

# print(model.TheClusterOfClass)
# target = 7
# for pclass in model.TheClusterOfClass.keys():
#     labels[pclass]+=" annot "+model.GroundTruth[pclass]+" pred "+model.TheSpeciesOfCluster[model.TheClusterOfClass[pclass]]
# #     if model.TheClusterOfClass[pclass]==target:
# #         print("classes in cluster ",target," = ",pclass," annot ",model.GroundTruth[pclass])

# %% [markdown]
# # visualizando árvore filogenética

# %% [markdown]
# # linkage methods
# The following are methods for calculating the distance between the newly formed cluster  and each .
#
# 1. method=’single’  also known as the Nearest Point Algorithm.
#
# 2. method=’complete’  also known by the Farthest Point Algorithm or Voor Hees Algorithm.
#
# 3. method=’average’ also called the UPGMA algorithm.
#
# 4. method=’weighted’ also called WPGMA.
#
# 5. method=’centroid’  also known as the UPGMC algorithm.
#
# 6. method=’median’  also known as the WPGMC algorithm.
#
# 7. method=’ward’ also known as the incremental algorithm.

# %%
# methods=['single', 'complete','average','weighted','centroid','median','ward']
# methodknownas=['NearestPoint', 'FarthestPoint','UPGMA','WPGMA','UPGMC','WPGMC','Incremental']
methods=['ward']
methodknownas=['Incremental']
nmeth=len(methods)

# %%
# construindo arvores com distintos métodos de linkagem da scipy.cluster.hierarch.linkage
ctr=0
for meth in methods:
    linkage_matrix = linkage(dists, meth)
    fig, ax = plt.subplots(1, 1, figsize=(10, 18))
    fig.set_size_inches(10, 18, forward=True)
    dn= dendrogram(linkage_matrix, ax=ax, labels=labels, show_leaf_counts=True, show_contracted=True, orientation='left',leaf_font_size=10)
    plt.title("SARS2 - Host independent study with linkage method '"+meth+"' ("+methodknownas[ctr]+")")
#     plt.tight_layout()
    #or:
    plt.tight_layout(pad=4)
    plt.show()
    fig.savefig('tree_'+methodknownas[ctr]+'.png', dpi=fig.dpi)
    ctr+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb Célula 40 line 7
#       <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X54sZmlsZQ%3D%3D?line=4'>5</a>     fig, ax = plt.subplots(1, 1, figsize=(10, 18))
#       <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X54sZmlsZQ%3D%3D?line=5'>6</a>     fig.set_size_inches(10, 18, forward=True)
# ----> <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X54sZmlsZQ%3D%3D?line=6'>7</a>     dn= dendrogram(linkage_matrix, ax=ax, labels=labels, show_leaf_counts=True, show_contracted=True, orientation='left',leaf_font_size=10)
#       <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X54sZmlsZQ%3D%3D?line=7'>8</a>     plt.title("SARS2 - Host independent study with linkage method '"+meth+"' ("+methodknownas[ctr]+")")
#       <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X54sZmlsZQ%3D%3D?line=8'>9</a> #     plt.tight_layout()
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X54sZmlsZQ%3D%3D?line=9'>10</a>     #or:
#
# File ~/.local/lib/python3.10/site-packages/scipy/cluster/hierarchy.py:3304, in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    3300     raise ValueError("orientation must be one of 'top', 'left', "
#    3301                      "'bottom', or 'right'")
#    3303 if labels is not None and Z.shape[0] + 1 != len(labels):
# -> 3304     raise ValueError("Dimensions of Z and labels must be consistent.")
#    3306 is_valid_linkage(Z, throw=True, name='Z')
#    3307 Zs = Z.shape
#
# ValueError: Dimensions of Z and labels must be consistent.

# %%
def print_model(model,n):
    print("name:", model.name)
    print("ListOfVarSites:\n",model.ListOfVarSites)
    print("NmbOfClasses:",model.NmbOfClasses)
    print("CodeOfClass[:",n,"]:\n",model.CodeOfClass[:n])
    print("GroundTruth[:",n,"]:\n",model.GroundTruth[:n])
    print("Accession[:",n,"]:\n",model.Accession[:n])
    print("repulsion:",model.repulsion)
    print("NmbOfClusters:",model.NmbOfClusters)
    print("TheSpeciesOfCluster:\n",model.TheSpeciesOfCluster)
    print("MinClusterAcc:",model.MinClusterAcc)
    print("Accuracy:",model.Accuracy)
    print("ConfusionMatrix:\n",model.ConfusionMatrix)
    print("TheClusterOfClass:\n",model.TheClusterOfClass)

# %%
print_model(model,2)

# %% [markdown]
# # CREATING THE GENE VARIANT FILE

# %%
# creating and saving the final GVF file

GVF=pd.DataFrame(model.CodeOfClass)
col_rename_dict = {i:j for i,j in zip(GVF.columns,model.ListOfVarSites)}
GVF.rename(columns=col_rename_dict, inplace=True)

GVF['accession']=model.Accession
GVF['ground_truth']=model.GroundTruth

GVF

GVF.to_csv(model.name+'.gvf')

# %%
print(GVF.columns)
# Out:
# Index(['accession', 'ground_truth'], dtype='object')

# %%
# saving and loading the  model

# Save the file
model_filename=model.name+".obj"
dill.dump(model, file = open(model_filename, "wb"))

# Reload the file
loaded_model = dill.load(open(model_filename, "rb"))
print_model(loaded_model,2)
# Out:
# name: SARS2-spike
# ListOfVarSites:
#  [4, 8, 17, 24, 25, 26, 27, 28, 31, 37, 44, 48, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 78, 82, 85, 87, 94, 95, 101, 112, 121, 125, 126, 128, 139, 140, 141, 142, 143, 145, 146, 149, 150, 152, 156, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 173, 175, 177, 180, 181, 184, 185, 196, 200, 201, 205, 210, 212, 213, 214, 217, 218, 220, 221, 222, 232, 244, 252, 254, 255, 256, 257, 258, 259, 260, 261, 262, 267, 286, 292, 293, 294, 295, 301, 305, 306, 308, 309, 319, 320, 345, 347, 353, 362, 366, 375, 376, 377, 378, 379, 391, 392, 401, 402, 403, 404, 405, 406, 407, 408, 409, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 437, 440, 443, 444, 445, 446, 448, 451, 453, 474, 475, 483, 489, 492, 497, 498, 500, 505, 518, 519, 520, 521, 522, 527, 553, 556, 557, 568, 569, 571, 591, 612, 613, 617, 623, 645, 646, 647, 648, 649, 654, 657, 662, 671, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 703, 704, 706, 707, 708, 710, 715, 722, 727, 728, 734, 764, 766, 768, 792, 804, 808, 812, 813, 820, 823, 828, 833, 836, 844, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 876, 878, 880, 883, 886, 891, 894, 931, 938, 945, 946, 948, 957, 959, 965, 966, 967, 981, 983, 984, 990, 997, 998, 999, 1000, 1001, 1008, 1017, 1036, 1043, 1050, 1054, 1057, 1061, 1068, 1080, 1113, 1117, 1123, 1127, 1139, 1142, 1161, 1162, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1185, 1190, 1197, 1199, 1218, 1228, 1229, 1243, 1253, 1264]
# NmbOfClasses: 189
# CodeOfClass[: 2 ]:
#  []
# GroundTruth[: 2 ]:
#  []
# Accession[: 2 ]:
#  []
# repulsion: 2
# NmbOfClusters: 0
# TheSpeciesOfCluster:
#  {}
# MinClusterAcc: 0
# Accuracy: 0
# ConfusionMatrix:
#  []
# TheClusterOfClass:
#  {}

# %%
# READY TO USE IN THE PRODUCTION PHASE - 23.10.2022
