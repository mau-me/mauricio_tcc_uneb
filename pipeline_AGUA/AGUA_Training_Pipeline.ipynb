# %% [markdown]
# # AGUA : Ad hoc Genotyping with Unsupervised
# # Algorithm / Analysis / Approach / Advisor
# ## training pipeline Python script
# ### Diego Frias, 23.10.2022

# %%
# %pip install seaborn

# %%
#import our three important packages
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import os
import sys
import Bio as Bio
from Bio import SeqIO
from Bio import AlignIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import Phylo
import seaborn as sns
import time as time
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform

import pandas as pd
import random 

import dill

# import re

# %% [markdown]
# # FASE 1 - PREPROCESSAMENTO
# ## LEITURA DO DATASET DE TREINAMENTO & IDENTIFICAÇÃO/CODIFICAÇÃO DE CLASSES PRIMÁRIAS

# %%
base = [16, 4, 1]

nucleotides = {
"A": 0,
"G": 1,
"C": 2,
"T": 3,
"a": 0,
"g": 1,
"c": 2,
"t": 3,
"-": 4,
"N": 5,
"n": 5
}
    
stops=["TAA","TAG","TGA"]
    
stopnmb=[]

for triplet in stops:
    codonNumber = 0 # 0 to 63
    for p in range(3):
          codonNumber += base[p] * nucleotides[triplet[p]]
    stopnmb.append(codonNumber)

print("stop codon ordinals ",stopnmb)
# Out:
# stop codon ordinals  [48, 49, 52]

# %%
#import the sequences we will use. These are 16s sequences from GenBank
#example: https://www.ncbi.nlm.nih.gov/nuccore/FJ039971.1?report=genbank 
fname = "/home/m_souza/tcc/dataset/dataset_agua/sequencias_treinamento.fasta"
# fname = "/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/spike_alignment.fas"
# t1 = SeqIO.read("sequence1.fasta", "fasta")
# t2 = SeqIO.read("sequence2.fasta", "fasta")
# t3 = SeqIO.read("sequence3.fasta", "fasta")
# t4 = SeqIO.read("sequence4.fasta", "fasta")
# t5 = SeqIO.read("sequence5.fasta", "fasta")
# t6 = SeqIO.read("sequence6.fasta", "fasta")
# t7 = SeqIO.read("sequence7.fasta", "fasta")

t=[]
with open(fname) as handle:
    for values in SeqIO.FastaIO.SimpleFastaParser(handle):
        t.append(values)
        print(t[-1][0])
        
Nseq=len(t)

print("number of sequences in file ",fname," = ",Nseq)
# Out:
# spike(pos.ini:21562 pos.fin:25384)accn|MT628234
# spike(pos.ini:21562 pos.fin:25384)accn|MT628235
# spike(pos.ini:21562 pos.fin:25384)accn|MT628237
# spike(pos.ini:21562 pos.fin:25384)accn|MW053744
# spike(pos.ini:21562 pos.fin:25384)accn|MT628238
# spike(pos.ini:21562 pos.fin:25384)accn|MT628247
# spike(pos.ini:21562 pos.fin:25384)accn|MT628251
# spike(pos.ini:21562 pos.fin:25384)accn|MT628253
# spike(pos.ini:21562 pos.fin:25384)accn|MT628254
# spike(pos.ini:21562 pos.fin:25384)accn|MT628255
# spike(pos.ini:21562 pos.fin:25384)accn|MT628256
# spike(pos.ini:21562 pos.fin:25384)accn|MT628257
# spike(pos.ini:21562 pos.fin:25384)accn|MT628259
# spike(pos.ini:21562 pos.fin:25384)accn|MT628260
# spike(pos.ini:21562 pos.fin:25384)accn|MT628263
# spike(pos.ini:21562 pos.fin:25384)accn|MT628266
# spike(pos.ini:21562 pos.fin:25384)accn|MT628267
# spike(pos.ini:21562 pos.fin:25384)accn|MT628268
# spike(pos.ini:21562 pos.fin:25384)accn|MT628269
# spike(pos.ini:21562 pos.fin:25384)accn|MT628271
# spike(pos.ini:21562 pos.fin:25384)accn|MT628272
# spike(pos.ini:21562 pos.fin:25384)accn|MW053804
# spike(pos.ini:21562 pos.fin:25384)accn|MW053821
# spike(pos.ini:21562 pos.fin:25384)accn|MW053849
# spike(pos.ini:21562 pos.fin:25384)accn|MT632495
# spike(pos.ini:21562 pos.fin:25384)accn|MT632496
# spike(pos.ini:21562 pos.fin:25384)accn|MT632500
# spike(pos.ini:21562 pos.fin:25384)accn|MT632501
# spike(pos.ini:21562 pos.fin:25384)accn|MT632502
# spike(pos.ini:21562 pos.fin:25384)accn|MT632506
# spike(pos.ini:21562 pos.fin:25384)accn|MT632514
# spike(pos.ini:21562 pos.fin:25384)accn|MT632515
# spike(pos.ini:21562 pos.fin:25384)accn|MT632518
# spike(pos.ini:21562 pos.fin:25384)accn|MT632526
# spike(pos.ini:21562 pos.fin:25384)accn|MT632531
# spike(pos.ini:21562 pos.fin:25384)accn|MT632534
# spike(pos.ini:21562 pos.fin:25384)accn|MT632535
# spike(pos.ini:21562 pos.fin:25384)accn|MT632538
# spike(pos.ini:21562 pos.fin:25384)accn|MT632539
# spike(pos.ini:21562 pos.fin:25384)accn|MT632542
# spike(pos.ini:21562 pos.fin:25384)accn|MT632543
# spike(pos.ini:21562 pos.fin:25384)accn|MT632544
# spike(pos.ini:21562 pos.fin:25384)accn|MT632545
# spike(pos.ini:21562 pos.fin:25384)accn|MT632546
# spike(pos.ini:21562 pos.fin:25384)accn|MT632550
# spike(pos.ini:21562 pos.fin:25384)accn|MT632548
# spike(pos.ini:21562 pos.fin:25384)accn|MT632551
# spike(pos.ini:21562 pos.fin:25384)accn|MT632552
# spike(pos.ini:21562 pos.fin:25384)accn|MT632555
# spike(pos.ini:21562 pos.fin:25384)accn|MT632556
# spike(pos.ini:21562 pos.fin:25384)accn|MT632554
# spike(pos.ini:21562 pos.fin:25384)accn|MT632557
# spike(pos.ini:21562 pos.fin:25384)accn|MT632558
# spike(pos.ini:21562 pos.fin:25384)accn|MT632559
# spike(pos.ini:21562 pos.fin:25384)accn|MT632560
# spike(pos.ini:21562 pos.fin:25384)accn|MT632561
# spike(pos.ini:21562 pos.fin:25384)accn|MT632562
# spike(pos.ini:21562 pos.fin:25384)accn|MT632563
# spike(pos.ini:21562 pos.fin:25384)accn|MT632564
# spike(pos.ini:21562 pos.fin:25384)accn|MT632567
# spike(pos.ini:21562 pos.fin:25384)accn|MT632569
# spike(pos.ini:21562 pos.fin:25384)accn|MT632570
# spike(pos.ini:21562 pos.fin:25384)accn|MT632572
# spike(pos.ini:21562 pos.fin:25384)accn|MT632573
# spike(pos.ini:21562 pos.fin:25384)accn|MT632574
# spike(pos.ini:21562 pos.fin:25384)accn|MT632575
# spike(pos.ini:21562 pos.fin:25384)accn|MT632576
# spike(pos.ini:21562 pos.fin:25384)accn|MT632577
# spike(pos.ini:21562 pos.fin:25384)accn|MT632581
# spike(pos.ini:21562 pos.fin:25384)accn|MT632582
# spike(pos.ini:21562 pos.fin:25384)accn|MT632583
# spike(pos.ini:21562 pos.fin:25384)accn|MT632584
# spike(pos.ini:21562 pos.fin:25384)accn|MT632585
# spike(pos.ini:21562 pos.fin:25384)accn|MT632586
# spike(pos.ini:21562 pos.fin:25384)accn|MT632587
# spike(pos.ini:21562 pos.fin:25384)accn|MT632588
# spike(pos.ini:21562 pos.fin:25384)accn|MT632589
# spike(pos.ini:21562 pos.fin:25384)accn|MT632591
# spike(pos.ini:21562 pos.fin:25384)accn|MT632592
# spike(pos.ini:21562 pos.fin:25384)accn|MT632593
# spike(pos.ini:21562 pos.fin:25384)accn|MT632595
# spike(pos.ini:21562 pos.fin:25384)accn|MT632596
# spike(pos.ini:21562 pos.fin:25384)accn|MT632597
# spike(pos.ini:21562 pos.fin:25384)accn|MT632599
# spike(pos.ini:21562 pos.fin:25384)accn|MT632601
# spike(pos.ini:21562 pos.fin:25384)accn|MT632602
# spike(pos.ini:21562 pos.fin:25384)accn|MT632606
# spike(pos.ini:21562 pos.fin:25384)accn|MT632607
# spike(pos.ini:21562 pos.fin:25384)accn|MT632609
# spike(pos.ini:21562 pos.fin:25384)accn|MT632610
# spike(pos.ini:21562 pos.fin:25384)accn|MT632611
# spike(pos.ini:21562 pos.fin:25384)accn|MT632612
# spike(pos.ini:21562 pos.fin:25384)accn|MT632614
# spike(pos.ini:21562 pos.fin:25384)accn|MT632615
# spike(pos.ini:21562 pos.fin:25384)accn|MT632617
# spike(pos.ini:21562 pos.fin:25384)accn|MT632618
# spike(pos.ini:21562 pos.fin:25384)accn|MT632621
# spike(pos.ini:21562 pos.fin:25384)accn|MT632622
# spike(pos.ini:21562 pos.fin:25384)accn|MT632624
# spike(pos.ini:21562 pos.fin:25384)accn|MT632631
# spike(pos.ini:21562 pos.fin:25384)accn|MT632632
# spike(pos.ini:21562 pos.fin:25384)accn|MT632766
# spike(pos.ini:21562 pos.fin:25384)accn|MT632772
# spike(pos.ini:21562 pos.fin:25384)accn|MT632773
# spike(pos.ini:21562 pos.fin:25384)accn|MT632786
# spike(pos.ini:21562 pos.fin:25384)accn|MT632788
# spike(pos.ini:21562 pos.fin:25384)accn|MT632790
# spike(pos.ini:21562 pos.fin:25384)accn|MT632793
# spike(pos.ini:21562 pos.fin:25384)accn|MT632795
# spike(pos.ini:21562 pos.fin:25384)accn|MT632797
# spike(pos.ini:21562 pos.fin:25384)accn|MT632798
# spike(pos.ini:21562 pos.fin:25384)accn|MW054035
# spike(pos.ini:21562 pos.fin:25384)accn|MT632803
# spike(pos.ini:21562 pos.fin:25384)accn|MT632804
# spike(pos.ini:21562 pos.fin:25384)accn|MT632817
# spike(pos.ini:21562 pos.fin:25384)accn|MT632820
# spike(pos.ini:21562 pos.fin:25384)accn|MT632821
# spike(pos.ini:21562 pos.fin:25384)accn|MT632823
# spike(pos.ini:21562 pos.fin:25384)accn|MT632824
# spike(pos.ini:21562 pos.fin:25384)accn|MT632828
# spike(pos.ini:21562 pos.fin:25384)accn|MT632830
# spike(pos.ini:21562 pos.fin:25384)accn|MT632833
# spike(pos.ini:21562 pos.fin:25384)accn|MT632842
# spike(pos.ini:21562 pos.fin:25384)accn|MT632840
# spike(pos.ini:21562 pos.fin:25384)accn|MT632841
# spike(pos.ini:21562 pos.fin:25384)accn|MT632843
# spike(pos.ini:21562 pos.fin:25384)accn|MT632846
# spike(pos.ini:21562 pos.fin:25384)accn|MT632847
# spike(pos.ini:21562 pos.fin:25384)accn|MT632852
# spike(pos.ini:21562 pos.fin:25384)accn|MT632856
# spike(pos.ini:21562 pos.fin:25384)accn|MT632859
# spike(pos.ini:21562 pos.fin:25384)accn|MT632860
# spike(pos.ini:21562 pos.fin:25384)accn|MT632865
# spike(pos.ini:21562 pos.fin:25384)accn|MT632866
# spike(pos.ini:21562 pos.fin:25384)accn|MT632868
# spike(pos.ini:21562 pos.fin:25384)accn|MT632872
# spike(pos.ini:21562 pos.fin:25384)accn|MT632873
# spike(pos.ini:21562 pos.fin:25384)accn|MT632874
# spike(pos.ini:21562 pos.fin:25384)accn|MT632875
# spike(pos.ini:21562 pos.fin:25384)accn|MT632876
# spike(pos.ini:21562 pos.fin:25384)accn|MT632877
# spike(pos.ini:21562 pos.fin:25384)accn|MT632881
# spike(pos.ini:21562 pos.fin:25384)accn|MT632884
# spike(pos.ini:21562 pos.fin:25384)accn|MT632885
# spike(pos.ini:21562 pos.fin:25384)accn|MT632886
# spike(pos.ini:21562 pos.fin:25384)accn|MT632887
# spike(pos.ini:21562 pos.fin:25384)accn|MT632888
# spike(pos.ini:21562 pos.fin:25384)accn|MT632890
# spike(pos.ini:21562 pos.fin:25384)accn|MT632892
# spike(pos.ini:21562 pos.fin:25384)accn|MT632893
# spike(pos.ini:21562 pos.fin:25384)accn|OU348132
# spike(pos.ini:21562 pos.fin:25384)accn|OU340519
# spike(pos.ini:21562 pos.fin:25384)accn|OU290602
# spike(pos.ini:21562 pos.fin:25384)accn|OU286689
# spike(pos.ini:21562 pos.fin:25384)accn|OU287044
# spike(pos.ini:21562 pos.fin:25384)accn|OU298008
# spike(pos.ini:21562 pos.fin:25384)accn|OU314138
# spike(pos.ini:21562 pos.fin:25384)accn|OU288618
# spike(pos.ini:21562 pos.fin:25384)accn|OU292159
# spike(pos.ini:21562 pos.fin:25384)accn|OU299530
# spike(pos.ini:21562 pos.fin:25384)accn|OU306095
# spike(pos.ini:21562 pos.fin:25384)accn|OU290842
# spike(pos.ini:21562 pos.fin:25384)accn|OU293156
# spike(pos.ini:21562 pos.fin:25384)accn|OU384887
# spike(pos.ini:21562 pos.fin:25384)accn|OU384946
# spike(pos.ini:21562 pos.fin:25384)accn|OU386869
# spike(pos.ini:21562 pos.fin:25384)accn|OU386943
# spike(pos.ini:21562 pos.fin:25384)accn|OU387013
# spike(pos.ini:21562 pos.fin:25384)accn|OU385218
# spike(pos.ini:21562 pos.fin:25384)accn|OU385287
# spike(pos.ini:21562 pos.fin:25384)accn|OU385386
# spike(pos.ini:21562 pos.fin:25384)accn|OU385389
# spike(pos.ini:21562 pos.fin:25384)accn|OU423210
# spike(pos.ini:21562 pos.fin:25384)accn|OU419371
# spike(pos.ini:21562 pos.fin:25384)accn|OU423351
# spike(pos.ini:21562 pos.fin:25384)accn|OU387405
# spike(pos.ini:21562 pos.fin:25384)accn|OU417612
# spike(pos.ini:21562 pos.fin:25384)accn|OU385748
# spike(pos.ini:21562 pos.fin:25384)accn|OU419591
# spike(pos.ini:21562 pos.fin:25384)accn|OU387592
# spike(pos.ini:21562 pos.fin:25384)accn|OU387622
# spike(pos.ini:21562 pos.fin:25384)accn|OU417849
# spike(pos.ini:21562 pos.fin:25384)accn|OU421726
# spike(pos.ini:21562 pos.fin:25384)accn|OU423661
# spike(pos.ini:21562 pos.fin:25384)accn|OU417890
# spike(pos.ini:21562 pos.fin:25384)accn|OU386082
# spike(pos.ini:21562 pos.fin:25384)accn|OU386095
# spike(pos.ini:21562 pos.fin:25384)accn|OU391440
# spike(pos.ini:21562 pos.fin:25384)accn|OU393315
# spike(pos.ini:21562 pos.fin:25384)accn|OU393316
# spike(pos.ini:21562 pos.fin:25384)accn|OU421933
# spike(pos.ini:21562 pos.fin:25384)accn|OU388180
# spike(pos.ini:21562 pos.fin:25384)accn|OU388182
# spike(pos.ini:21562 pos.fin:25384)accn|OU384628
# spike(pos.ini:21562 pos.fin:25384)accn|OU391754
# spike(pos.ini:21562 pos.fin:25384)accn|OU394917
# spike(pos.ini:21562 pos.fin:25384)accn|OU420270
# spike(pos.ini:21562 pos.fin:25384)accn|OU390004
# spike(pos.ini:21562 pos.fin:25384)accn|OU395025
# spike(pos.ini:21562 pos.fin:25384)accn|OU422368
# spike(pos.ini:21562 pos.fin:25384)accn|OU395154
# spike(pos.ini:21562 pos.fin:25384)accn|OU422480
# spike(pos.ini:21562 pos.fin:25384)accn|OU390214
# spike(pos.ini:21562 pos.fin:25384)accn|OU418693
# spike(pos.ini:21562 pos.fin:25384)accn|OU418743
# spike(pos.ini:21562 pos.fin:25384)accn|OU422610
# spike(pos.ini:21562 pos.fin:25384)accn|OU393967
# spike(pos.ini:21562 pos.fin:25384)accn|OU418795
# spike(pos.ini:21562 pos.fin:25384)accn|OU388830
# spike(pos.ini:21562 pos.fin:25384)accn|OU390401
# spike(pos.ini:21562 pos.fin:25384)accn|OU395623
# spike(pos.ini:21562 pos.fin:25384)accn|OU420792
# spike(pos.ini:21562 pos.fin:25384)accn|OU392329
# spike(pos.ini:21562 pos.fin:25384)accn|OU423024
# spike(pos.ini:21562 pos.fin:25384)accn|OU396268
# spike(pos.ini:21562 pos.fin:25384)accn|OU392813
# spike(pos.ini:21562 pos.fin:25384)accn|OU396720
# spike(pos.ini:21562 pos.fin:25384)accn|OU396763
# spike(pos.ini:21562 pos.fin:25384)accn|OU390594
# spike(pos.ini:21562 pos.fin:25384)accn|OU390681
# spike(pos.ini:21562 pos.fin:25384)accn|OU390804
# spike(pos.ini:21562 pos.fin:25384)accn|OU359282
# spike(pos.ini:21562 pos.fin:25384)accn|OU799559
# spike(pos.ini:21562 pos.fin:25384)accn|OU246304
# spike(pos.ini:21562 pos.fin:25384)accn|OU269919
# spike(pos.ini:21562 pos.fin:25384)accn|OU270386
# spike(pos.ini:21562 pos.fin:25384)accn|OU269503
# spike(pos.ini:21562 pos.fin:25384)accn|OU264589
# spike(pos.ini:21562 pos.fin:25384)accn|OU269678
# spike(pos.ini:21562 pos.fin:25384)accn|OU272650
# spike(pos.ini:21562 pos.fin:25384)accn|OU264257
# spike(pos.ini:21562 pos.fin:25384)accn|OU272774
# spike(pos.ini:21562 pos.fin:25384)accn|OU281879
# spike(pos.ini:21562 pos.fin:25384)accn|OU281882
# spike(pos.ini:21562 pos.fin:25384)accn|OU282996
# spike(pos.ini:21562 pos.fin:25384)accn|OU281509
# spike(pos.ini:21562 pos.fin:25384)accn|OU285003
# spike(pos.ini:21562 pos.fin:25384)accn|OU285172
# spike(pos.ini:21562 pos.fin:25384)accn|OU284812
# spike(pos.ini:21562 pos.fin:25384)accn|MW341443
# spike(pos.ini:21562 pos.fin:25384)accn|ON870954
# spike(pos.ini:21562 pos.fin:25384)accn|ON878765
# spike(pos.ini:21562 pos.fin:25384)accn|ON878781
# spike(pos.ini:21562 pos.fin:25384)accn|ON878782
# spike(pos.ini:21562 pos.fin:25384)accn|ON878788
# spike(pos.ini:21562 pos.fin:25384)accn|ON878787
# spike(pos.ini:21562 pos.fin:25384)accn|ON878797
# spike(pos.ini:21562 pos.fin:25384)accn|ON878795
# spike(pos.ini:21562 pos.fin:25384)accn|ON878796
# spike(pos.ini:21562 pos.fin:25384)accn|ON878815
# spike(pos.ini:21562 pos.fin:25384)accn|ON878808
# spike(pos.ini:21562 pos.fin:25384)accn|ON878823
# spike(pos.ini:21562 pos.fin:25384)accn|ON878822
# spike(pos.ini:21562 pos.fin:25384)accn|ON878820
# spike(pos.ini:21562 pos.fin:25384)accn|ON878826
# spike(pos.ini:21562 pos.fin:25384)accn|ON878854
# spike(pos.ini:21562 pos.fin:25384)accn|ON878860
# spike(pos.ini:21562 pos.fin:25384)accn|ON878865
# spike(pos.ini:21562 pos.fin:25384)accn|ON878874
# spike(pos.ini:21562 pos.fin:25384)accn|ON878869
# spike(pos.ini:21562 pos.fin:25384)accn|ON878890
# spike(pos.ini:21562 pos.fin:25384)accn|ON878891
# spike(pos.ini:21562 pos.fin:25384)accn|ON878892
# spike(pos.ini:21562 pos.fin:25384)accn|ON878889
# spike(pos.ini:21562 pos.fin:25384)accn|ON878894
# spike(pos.ini:21562 pos.fin:25384)accn|ON878895
# spike(pos.ini:21562 pos.fin:25384)accn|ON878897
# spike(pos.ini:21562 pos.fin:25384)accn|MT781415
# spike(pos.ini:21562 pos.fin:25384)accn|OP648148
# spike(pos.ini:21562 pos.fin:25384)accn|OP648149
# spike(pos.ini:21562 pos.fin:25384)accn|OP648147
# spike(pos.ini:21562 pos.fin:25384)accn|MT447158
# spike(pos.ini:21562 pos.fin:25384)accn|MT447163
# spike(pos.ini:21562 pos.fin:25384)accn|MT447165
# spike(pos.ini:21562 pos.fin:25384)accn|MT447166
# spike(pos.ini:21562 pos.fin:25384)accn|MT447169
# spike(pos.ini:21562 pos.fin:25384)accn|MT447171
# spike(pos.ini:21562 pos.fin:25384)accn|MT447173
# spike(pos.ini:21562 pos.fin:25384)accn|MT447174
# spike(pos.ini:21562 pos.fin:25384)accn|MT447175
# spike(pos.ini:21562 pos.fin:25384)accn|MT447176
# spike(pos.ini:21562 pos.fin:25384)accn|MZ372711
# spike(pos.ini:21562 pos.fin:25384)accn|MZ372712
# spike(pos.ini:21562 pos.fin:25384)accn|OU075229
# spike(pos.ini:21562 pos.fin:25384)accn|MZ591007
# spike(pos.ini:21562 pos.fin:25384)accn|MZ593669
# spike(pos.ini:21562 pos.fin:25384)accn|MZ591877
# spike(pos.ini:21562 pos.fin:25384)accn|MZ647317
# spike(pos.ini:21562 pos.fin:25384)accn|MZ647385
# spike(pos.ini:21562 pos.fin:25384)accn|MZ784304
# spike(pos.ini:21562 pos.fin:25384)accn|MZ850490
# spike(pos.ini:21562 pos.fin:25384)accn|MZ864889
# spike(pos.ini:21562 pos.fin:25384)accn|MZ864935
# spike(pos.ini:21562 pos.fin:25384)accn|MZ850777
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865068
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865071
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865084
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865217
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865225
# spike(pos.ini:21562 pos.fin:25384)accn|MZ849766
# spike(pos.ini:21562 pos.fin:25384)accn|MZ867275
# spike(pos.ini:21562 pos.fin:25384)accn|MZ866066
# spike(pos.ini:21562 pos.fin:25384)accn|MZ931039
# spike(pos.ini:21562 pos.fin:25384)accn|MZ942221
# spike(pos.ini:21562 pos.fin:25384)accn|MZ942229
# spike(pos.ini:21562 pos.fin:25384)accn|MZ942442
# spike(pos.ini:21562 pos.fin:25384)accn|MZ834989
# spike(pos.ini:21562 pos.fin:25384)accn|MZ554751
# spike(pos.ini:21562 pos.fin:25384)accn|MZ726579
# spike(pos.ini:21562 pos.fin:25384)accn|OK235125
# spike(pos.ini:21562 pos.fin:25384)accn|OK233007
# spike(pos.ini:21562 pos.fin:25384)accn|OK242908
# spike(pos.ini:21562 pos.fin:25384)accn|OK122709
# spike(pos.ini:21562 pos.fin:25384)accn|OK127420
# spike(pos.ini:21562 pos.fin:25384)accn|OK152360
# spike(pos.ini:21562 pos.fin:25384)accn|OK548683
# spike(pos.ini:21562 pos.fin:25384)accn|OK548699
# spike(pos.ini:21562 pos.fin:25384)accn|OK570439
# spike(pos.ini:21562 pos.fin:25384)accn|OK555491
# spike(pos.ini:21562 pos.fin:25384)accn|OL543753
# spike(pos.ini:21562 pos.fin:25384)accn|OL543754
# spike(pos.ini:21562 pos.fin:25384)accn|MW617768
# spike(pos.ini:21562 pos.fin:25384)accn|OL848696
# spike(pos.ini:21562 pos.fin:25384)accn|MW689883
# spike(pos.ini:21562 pos.fin:25384)accn|MW780563
# spike(pos.ini:21562 pos.fin:25384)accn|MW783256
# spike(pos.ini:21562 pos.fin:25384)accn|MW810328
# spike(pos.ini:21562 pos.fin:25384)accn|MW871230
# spike(pos.ini:21562 pos.fin:25384)accn|ON017300
# spike(pos.ini:21562 pos.fin:25384)accn|ON017304
# spike(pos.ini:21562 pos.fin:25384)accn|ON017308
# spike(pos.ini:21562 pos.fin:25384)accn|ON017309
# spike(pos.ini:21562 pos.fin:25384)accn|ON017310
# spike(pos.ini:21562 pos.fin:25384)accn|ON017465
# spike(pos.ini:21562 pos.fin:25384)accn|ON017475
# spike(pos.ini:21562 pos.fin:25384)accn|ON017476
# spike(pos.ini:21562 pos.fin:25384)accn|ON017494
# spike(pos.ini:21562 pos.fin:25384)accn|MZ075092
# spike(pos.ini:21562 pos.fin:25384)accn|ON316688
# spike(pos.ini:21562 pos.fin:25384)accn|ON316704
# spike(pos.ini:21562 pos.fin:25384)accn|MZ240356
# spike(pos.ini:21562 pos.fin:25384)accn|MW868542
# spike(pos.ini:21562 pos.fin:25384)accn|MZ531687
# spike(pos.ini:21562 pos.fin:25384)accn|MZ531728
# spike(pos.ini:21562 pos.fin:25384)accn|MZ877201
# spike(pos.ini:21562 pos.fin:25384)accn|MZ879302
# spike(pos.ini:21562 pos.fin:25384)accn|MZ877252
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882519
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882582
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886640
# spike(pos.ini:21562 pos.fin:25384)accn|MZ888660
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882633
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882638
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882658
# spike(pos.ini:21562 pos.fin:25384)accn|MZ877448
# spike(pos.ini:21562 pos.fin:25384)accn|MZ877469
# spike(pos.ini:21562 pos.fin:25384)accn|MZ889525
# spike(pos.ini:21562 pos.fin:25384)accn|MZ889533
# spike(pos.ini:21562 pos.fin:25384)accn|MZ874923
# spike(pos.ini:21562 pos.fin:25384)accn|MZ877534
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886885
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886888
# spike(pos.ini:21562 pos.fin:25384)accn|MZ875109
# spike(pos.ini:21562 pos.fin:25384)accn|MZ866732
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885139
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885140
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886964
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885154
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885155
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885156
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885157
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887000
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882933
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882935
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887004
# spike(pos.ini:21562 pos.fin:25384)accn|MZ875194
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887035
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887036
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882978
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887054
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887076
# spike(pos.ini:21562 pos.fin:25384)accn|MZ866855
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887098
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887099
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887146
# spike(pos.ini:21562 pos.fin:25384)accn|MZ891769
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885352
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885353
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885362
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887189
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885380
# spike(pos.ini:21562 pos.fin:25384)accn|MZ875461
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885489
# spike(pos.ini:21562 pos.fin:25384)accn|MZ875539
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885541
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885615
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885640
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885648
# spike(pos.ini:21562 pos.fin:25384)accn|MZ875670
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887536
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887543
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887593
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887604
# spike(pos.ini:21562 pos.fin:25384)accn|MZ885796
# spike(pos.ini:21562 pos.fin:25384)accn|MZ887625
# spike(pos.ini:21562 pos.fin:25384)accn|MZ892953
# spike(pos.ini:21562 pos.fin:25384)accn|MZ893401
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865569
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865570
# spike(pos.ini:21562 pos.fin:25384)accn|MZ867480
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886032
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886064
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886073
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886156
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886165
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886224
# spike(pos.ini:21562 pos.fin:25384)accn|MZ888128
# spike(pos.ini:21562 pos.fin:25384)accn|MZ865956
# spike(pos.ini:21562 pos.fin:25384)accn|MZ888156
# spike(pos.ini:21562 pos.fin:25384)accn|MZ866025
# spike(pos.ini:21562 pos.fin:25384)accn|MZ896191
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886445
# spike(pos.ini:21562 pos.fin:25384)accn|MZ888283
# spike(pos.ini:21562 pos.fin:25384)accn|MZ866125
# spike(pos.ini:21562 pos.fin:25384)accn|MZ866126
# spike(pos.ini:21562 pos.fin:25384)accn|MZ896266
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886520
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886524
# spike(pos.ini:21562 pos.fin:25384)accn|MZ896347
# spike(pos.ini:21562 pos.fin:25384)accn|MZ896369
# spike(pos.ini:21562 pos.fin:25384)accn|MZ888486
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929492
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929522
# spike(pos.ini:21562 pos.fin:25384)accn|MZ920209
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929561
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929575
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929580
# spike(pos.ini:21562 pos.fin:25384)accn|MZ921451
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939091
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939096
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939105
# spike(pos.ini:21562 pos.fin:25384)accn|MZ921490
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937211
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937215
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929658
# spike(pos.ini:21562 pos.fin:25384)accn|MZ926860
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937302
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937306
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929728
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929759
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929761
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937397
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929766
# spike(pos.ini:21562 pos.fin:25384)accn|MZ917022
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939307
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937418
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937419
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937497
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937502
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929845
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937532
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929895
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929922
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929929
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929936
# spike(pos.ini:21562 pos.fin:25384)accn|MZ927710
# spike(pos.ini:21562 pos.fin:25384)accn|MZ929986
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930003
# spike(pos.ini:21562 pos.fin:25384)accn|MZ927825
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930034
# spike(pos.ini:21562 pos.fin:25384)accn|MZ927925
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937942
# spike(pos.ini:21562 pos.fin:25384)accn|MZ937970
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938022
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939890
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939930
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938263
# spike(pos.ini:21562 pos.fin:25384)accn|MZ928191
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939973
# spike(pos.ini:21562 pos.fin:25384)accn|MZ930611
# spike(pos.ini:21562 pos.fin:25384)accn|MZ928238
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938378
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938382
# spike(pos.ini:21562 pos.fin:25384)accn|MZ928284
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938483
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938576
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938641
# spike(pos.ini:21562 pos.fin:25384)accn|MZ941095
# spike(pos.ini:21562 pos.fin:25384)accn|MZ938656
# spike(pos.ini:21562 pos.fin:25384)accn|MZ941107
# spike(pos.ini:21562 pos.fin:25384)accn|MZ940237
# spike(pos.ini:21562 pos.fin:25384)accn|MZ941216
# spike(pos.ini:21562 pos.fin:25384)accn|MZ940317
# spike(pos.ini:21562 pos.fin:25384)accn|MZ940329
# spike(pos.ini:21562 pos.fin:25384)accn|OM019981
# spike(pos.ini:21562 pos.fin:25384)accn|OM173384
# spike(pos.ini:21562 pos.fin:25384)accn|OM104437
# spike(pos.ini:21562 pos.fin:25384)accn|OM019996
# spike(pos.ini:21562 pos.fin:25384)accn|OM104457
# spike(pos.ini:21562 pos.fin:25384)accn|OM020011
# spike(pos.ini:21562 pos.fin:25384)accn|OM020036
# spike(pos.ini:21562 pos.fin:25384)accn|OM104494
# spike(pos.ini:21562 pos.fin:25384)accn|OM173452
# spike(pos.ini:21562 pos.fin:25384)accn|OM104522
# spike(pos.ini:21562 pos.fin:25384)accn|OM173494
# spike(pos.ini:21562 pos.fin:25384)accn|OM104608
# spike(pos.ini:21562 pos.fin:25384)accn|OM173621
# spike(pos.ini:21562 pos.fin:25384)accn|OM173687
# spike(pos.ini:21562 pos.fin:25384)accn|OM104747
# spike(pos.ini:21562 pos.fin:25384)accn|OM020338
# spike(pos.ini:21562 pos.fin:25384)accn|OM104787
# spike(pos.ini:21562 pos.fin:25384)accn|OM104806
# spike(pos.ini:21562 pos.fin:25384)accn|OM020371
# spike(pos.ini:21562 pos.fin:25384)accn|OM104835
# spike(pos.ini:21562 pos.fin:25384)accn|OM173789
# spike(pos.ini:21562 pos.fin:25384)accn|OM104854
# spike(pos.ini:21562 pos.fin:25384)accn|OM020424
# spike(pos.ini:21562 pos.fin:25384)accn|OM173827
# spike(pos.ini:21562 pos.fin:25384)accn|OM173840
# spike(pos.ini:21562 pos.fin:25384)accn|OM020452
# spike(pos.ini:21562 pos.fin:25384)accn|OM173861
# spike(pos.ini:21562 pos.fin:25384)accn|OM104915
# spike(pos.ini:21562 pos.fin:25384)accn|OM104927
# spike(pos.ini:21562 pos.fin:25384)accn|OM104928
# spike(pos.ini:21562 pos.fin:25384)accn|OM020517
# spike(pos.ini:21562 pos.fin:25384)accn|OM173920
# spike(pos.ini:21562 pos.fin:25384)accn|OM173944
# spike(pos.ini:21562 pos.fin:25384)accn|OM173954
# spike(pos.ini:21562 pos.fin:25384)accn|OM020598
# spike(pos.ini:21562 pos.fin:25384)accn|OM020614
# spike(pos.ini:21562 pos.fin:25384)accn|OM174021
# spike(pos.ini:21562 pos.fin:25384)accn|OM020646
# spike(pos.ini:21562 pos.fin:25384)accn|OM105237
# spike(pos.ini:21562 pos.fin:25384)accn|OM105283
# spike(pos.ini:21562 pos.fin:25384)accn|OM105284
# spike(pos.ini:21562 pos.fin:25384)accn|OM020744
# spike(pos.ini:21562 pos.fin:25384)accn|OM174340
# spike(pos.ini:21562 pos.fin:25384)accn|OM174337
# spike(pos.ini:21562 pos.fin:25384)accn|OM174339
# spike(pos.ini:21562 pos.fin:25384)accn|OM174361
# spike(pos.ini:21562 pos.fin:25384)accn|OM174388
# spike(pos.ini:21562 pos.fin:25384)accn|OM174397
# spike(pos.ini:21562 pos.fin:25384)accn|OM105432
# spike(pos.ini:21562 pos.fin:25384)accn|OM020876
# spike(pos.ini:21562 pos.fin:25384)accn|OM174432
# spike(pos.ini:21562 pos.fin:25384)accn|OM174441
# spike(pos.ini:21562 pos.fin:25384)accn|OM174474
# spike(pos.ini:21562 pos.fin:25384)accn|OM174509
# spike(pos.ini:21562 pos.fin:25384)accn|OM174510
# spike(pos.ini:21562 pos.fin:25384)accn|OM105985
# spike(pos.ini:21562 pos.fin:25384)accn|OM020980
# spike(pos.ini:21562 pos.fin:25384)accn|OM174541
# spike(pos.ini:21562 pos.fin:25384)accn|OM174538
# spike(pos.ini:21562 pos.fin:25384)accn|OM106020
# spike(pos.ini:21562 pos.fin:25384)accn|OM174578
# spike(pos.ini:21562 pos.fin:25384)accn|OM106054
# spike(pos.ini:21562 pos.fin:25384)accn|OM106053
# spike(pos.ini:21562 pos.fin:25384)accn|OM174585
# spike(pos.ini:21562 pos.fin:25384)accn|OM174595
# spike(pos.ini:21562 pos.fin:25384)accn|OM106086
# spike(pos.ini:21562 pos.fin:25384)accn|OM106091
# spike(pos.ini:21562 pos.fin:25384)accn|OM106095
# spike(pos.ini:21562 pos.fin:25384)accn|OM174622
# spike(pos.ini:21562 pos.fin:25384)accn|OM174628
# spike(pos.ini:21562 pos.fin:25384)accn|OM021097
# spike(pos.ini:21562 pos.fin:25384)accn|OM106126
# spike(pos.ini:21562 pos.fin:25384)accn|OM174648
# spike(pos.ini:21562 pos.fin:25384)accn|OM106130
# spike(pos.ini:21562 pos.fin:25384)accn|OM106133
# spike(pos.ini:21562 pos.fin:25384)accn|OM106148
# spike(pos.ini:21562 pos.fin:25384)accn|OM106153
# spike(pos.ini:21562 pos.fin:25384)accn|OM021153
# spike(pos.ini:21562 pos.fin:25384)accn|OM106173
# spike(pos.ini:21562 pos.fin:25384)accn|OM106172
# spike(pos.ini:21562 pos.fin:25384)accn|OM174700
# spike(pos.ini:21562 pos.fin:25384)accn|OM174723
# spike(pos.ini:21562 pos.fin:25384)accn|OM021185
# spike(pos.ini:21562 pos.fin:25384)accn|OM174749
# spike(pos.ini:21562 pos.fin:25384)accn|OM174754
# spike(pos.ini:21562 pos.fin:25384)accn|OM174759
# spike(pos.ini:21562 pos.fin:25384)accn|OM174785
# spike(pos.ini:21562 pos.fin:25384)accn|OM107959
# spike(pos.ini:21562 pos.fin:25384)accn|OM107965
# spike(pos.ini:21562 pos.fin:25384)accn|OM174799
# spike(pos.ini:21562 pos.fin:25384)accn|OM107974
# spike(pos.ini:21562 pos.fin:25384)accn|OM174815
# spike(pos.ini:21562 pos.fin:25384)accn|OM174828
# spike(pos.ini:21562 pos.fin:25384)accn|OM174846
# spike(pos.ini:21562 pos.fin:25384)accn|OM174852
# spike(pos.ini:21562 pos.fin:25384)accn|OM174859
# spike(pos.ini:21562 pos.fin:25384)accn|OM174838
# spike(pos.ini:21562 pos.fin:25384)accn|OM174875
# spike(pos.ini:21562 pos.fin:25384)accn|OM108066
# spike(pos.ini:21562 pos.fin:25384)accn|OM174905
# spike(pos.ini:21562 pos.fin:25384)accn|OM174915
# spike(pos.ini:21562 pos.fin:25384)accn|OM174920
# spike(pos.ini:21562 pos.fin:25384)accn|OM174934
# spike(pos.ini:21562 pos.fin:25384)accn|OM022355
# spike(pos.ini:21562 pos.fin:25384)accn|OM174943
# spike(pos.ini:21562 pos.fin:25384)accn|OM022359
# spike(pos.ini:21562 pos.fin:25384)accn|OM022365
# spike(pos.ini:21562 pos.fin:25384)accn|OM149410
# spike(pos.ini:21562 pos.fin:25384)accn|OM174957
# spike(pos.ini:21562 pos.fin:25384)accn|OM149418
# spike(pos.ini:21562 pos.fin:25384)accn|OM149423
# spike(pos.ini:21562 pos.fin:25384)accn|OM149426
# spike(pos.ini:21562 pos.fin:25384)accn|OM149431
# spike(pos.ini:21562 pos.fin:25384)accn|OM174973
# spike(pos.ini:21562 pos.fin:25384)accn|OM149441
# spike(pos.ini:21562 pos.fin:25384)accn|OM175011
# spike(pos.ini:21562 pos.fin:25384)accn|OM022428
# spike(pos.ini:21562 pos.fin:25384)accn|OM149477
# spike(pos.ini:21562 pos.fin:25384)accn|OM149478
# spike(pos.ini:21562 pos.fin:25384)accn|OM149482
# spike(pos.ini:21562 pos.fin:25384)accn|OM149483
# spike(pos.ini:21562 pos.fin:25384)accn|OM149495
# spike(pos.ini:21562 pos.fin:25384)accn|OM149497
# spike(pos.ini:21562 pos.fin:25384)accn|OM022456
# spike(pos.ini:21562 pos.fin:25384)accn|OM149517
# spike(pos.ini:21562 pos.fin:25384)accn|OM022471
# spike(pos.ini:21562 pos.fin:25384)accn|OM149525
# spike(pos.ini:21562 pos.fin:25384)accn|OM175064
# spike(pos.ini:21562 pos.fin:25384)accn|OM149523
# spike(pos.ini:21562 pos.fin:25384)accn|OM022475
# spike(pos.ini:21562 pos.fin:25384)accn|OM175070
# spike(pos.ini:21562 pos.fin:25384)accn|OM175086
# spike(pos.ini:21562 pos.fin:25384)accn|OM149562
# spike(pos.ini:21562 pos.fin:25384)accn|OM022521
# spike(pos.ini:21562 pos.fin:25384)accn|OM149567
# spike(pos.ini:21562 pos.fin:25384)accn|OM149573
# spike(pos.ini:21562 pos.fin:25384)accn|OM149581
# spike(pos.ini:21562 pos.fin:25384)accn|OM149589
# spike(pos.ini:21562 pos.fin:25384)accn|OM175141
# spike(pos.ini:21562 pos.fin:25384)accn|OM175145
# spike(pos.ini:21562 pos.fin:25384)accn|OM022562
# spike(pos.ini:21562 pos.fin:25384)accn|OM149618
# spike(pos.ini:21562 pos.fin:25384)accn|OM175160
# spike(pos.ini:21562 pos.fin:25384)accn|OM149633
# spike(pos.ini:21562 pos.fin:25384)accn|OM175189
# spike(pos.ini:21562 pos.fin:25384)accn|OM022613
# spike(pos.ini:21562 pos.fin:25384)accn|OM022652
# spike(pos.ini:21562 pos.fin:25384)accn|OM022651
# spike(pos.ini:21562 pos.fin:25384)accn|OM022659
# spike(pos.ini:21562 pos.fin:25384)accn|OM175245
# spike(pos.ini:21562 pos.fin:25384)accn|OU412175
# spike(pos.ini:21562 pos.fin:25384)accn|OU408246
# spike(pos.ini:21562 pos.fin:25384)accn|OU408835
# spike(pos.ini:21562 pos.fin:25384)accn|OU375016
# spike(pos.ini:21562 pos.fin:25384)accn|OU429497
# spike(pos.ini:21562 pos.fin:25384)accn|OU383643
# spike(pos.ini:21562 pos.fin:25384)accn|OU379844
# spike(pos.ini:21562 pos.fin:25384)accn|OU379862
# spike(pos.ini:21562 pos.fin:25384)accn|OU417957
# spike(pos.ini:21562 pos.fin:25384)accn|OU379961
# spike(pos.ini:21562 pos.fin:25384)accn|OU513737
# spike(pos.ini:21562 pos.fin:25384)accn|OU428443
# spike(pos.ini:21562 pos.fin:25384)accn|OU397514
# spike(pos.ini:21562 pos.fin:25384)accn|OU430894
# spike(pos.ini:21562 pos.fin:25384)accn|OU401634
# spike(pos.ini:21562 pos.fin:25384)accn|OU426773
# spike(pos.ini:21562 pos.fin:25384)accn|OU397704
# spike(pos.ini:21562 pos.fin:25384)accn|OU431092
# spike(pos.ini:21562 pos.fin:25384)accn|OU431355
# spike(pos.ini:21562 pos.fin:25384)accn|OU433655
# spike(pos.ini:21562 pos.fin:25384)accn|OU400459
# spike(pos.ini:21562 pos.fin:25384)accn|OU402796
# spike(pos.ini:21562 pos.fin:25384)accn|OU437687
# spike(pos.ini:21562 pos.fin:25384)accn|OU435807
# spike(pos.ini:21562 pos.fin:25384)accn|OU434167
# spike(pos.ini:21562 pos.fin:25384)accn|OU472330
# spike(pos.ini:21562 pos.fin:25384)accn|OU439605
# spike(pos.ini:21562 pos.fin:25384)accn|OU460723
# spike(pos.ini:21562 pos.fin:25384)accn|OU472376
# spike(pos.ini:21562 pos.fin:25384)accn|OU474512
# spike(pos.ini:21562 pos.fin:25384)accn|OU436801
# spike(pos.ini:21562 pos.fin:25384)accn|OU469202
# spike(pos.ini:21562 pos.fin:25384)accn|OU455264
# spike(pos.ini:21562 pos.fin:25384)accn|OU442056
# spike(pos.ini:21562 pos.fin:25384)accn|OU463527
# spike(pos.ini:21562 pos.fin:25384)accn|OU469392
# spike(pos.ini:21562 pos.fin:25384)accn|OU473238
# spike(pos.ini:21562 pos.fin:25384)accn|OU465403
# spike(pos.ini:21562 pos.fin:25384)accn|OU449900
# spike(pos.ini:21562 pos.fin:25384)accn|OU446336
# spike(pos.ini:21562 pos.fin:25384)accn|OU453376
# spike(pos.ini:21562 pos.fin:25384)accn|OU450715
# spike(pos.ini:21562 pos.fin:25384)accn|OU447013
# spike(pos.ini:21562 pos.fin:25384)accn|OU454057
# spike(pos.ini:21562 pos.fin:25384)accn|OU501682
# spike(pos.ini:21562 pos.fin:25384)accn|OU494323
# spike(pos.ini:21562 pos.fin:25384)accn|OU511856
# spike(pos.ini:21562 pos.fin:25384)accn|OU492397
# spike(pos.ini:21562 pos.fin:25384)accn|OU478445
# spike(pos.ini:21562 pos.fin:25384)accn|OU501913
# spike(pos.ini:21562 pos.fin:25384)accn|OU492578
# spike(pos.ini:21562 pos.fin:25384)accn|OU488914
# spike(pos.ini:21562 pos.fin:25384)accn|OU480764
# spike(pos.ini:21562 pos.fin:25384)accn|OU484849
# spike(pos.ini:21562 pos.fin:25384)accn|OU484920
# spike(pos.ini:21562 pos.fin:25384)accn|OU493173
# spike(pos.ini:21562 pos.fin:25384)accn|OU480928
# spike(pos.ini:21562 pos.fin:25384)accn|OU504636
# spike(pos.ini:21562 pos.fin:25384)accn|OU487337
# spike(pos.ini:21562 pos.fin:25384)accn|OU503130
# spike(pos.ini:21562 pos.fin:25384)accn|OU493618
# spike(pos.ini:21562 pos.fin:25384)accn|OU503463
# spike(pos.ini:21562 pos.fin:25384)accn|OU544326
# spike(pos.ini:21562 pos.fin:25384)accn|OU538590
# spike(pos.ini:21562 pos.fin:25384)accn|OU546765
# spike(pos.ini:21562 pos.fin:25384)accn|OU544861
# spike(pos.ini:21562 pos.fin:25384)accn|OU545082
# spike(pos.ini:21562 pos.fin:25384)accn|OU545367
# spike(pos.ini:21562 pos.fin:25384)accn|OU541659
# spike(pos.ini:21562 pos.fin:25384)accn|OU550740
# spike(pos.ini:21562 pos.fin:25384)accn|OU546201
# spike(pos.ini:21562 pos.fin:25384)accn|OU552516
# spike(pos.ini:21562 pos.fin:25384)accn|OU552537
# spike(pos.ini:21562 pos.fin:25384)accn|OU574543
# spike(pos.ini:21562 pos.fin:25384)accn|OU582476
# spike(pos.ini:21562 pos.fin:25384)accn|OU561620
# spike(pos.ini:21562 pos.fin:25384)accn|OU578720
# spike(pos.ini:21562 pos.fin:25384)accn|OU584633
# spike(pos.ini:21562 pos.fin:25384)accn|OU560203
# spike(pos.ini:21562 pos.fin:25384)accn|OU556292
# spike(pos.ini:21562 pos.fin:25384)accn|OU562229
# spike(pos.ini:21562 pos.fin:25384)accn|OU577296
# spike(pos.ini:21562 pos.fin:25384)accn|OU584268
# spike(pos.ini:21562 pos.fin:25384)accn|OU578195
# spike(pos.ini:21562 pos.fin:25384)accn|OU442789
# spike(pos.ini:21562 pos.fin:25384)accn|OU473427
# spike(pos.ini:21562 pos.fin:25384)accn|OU592494
# spike(pos.ini:21562 pos.fin:25384)accn|OU591082
# spike(pos.ini:21562 pos.fin:25384)accn|OU586319
# spike(pos.ini:21562 pos.fin:25384)accn|OU591515
# spike(pos.ini:21562 pos.fin:25384)accn|OU677081
# spike(pos.ini:21562 pos.fin:25384)accn|OU654054
# spike(pos.ini:21562 pos.fin:25384)accn|OU670561
# spike(pos.ini:21562 pos.fin:25384)accn|OU654281
# spike(pos.ini:21562 pos.fin:25384)accn|OU679576
# spike(pos.ini:21562 pos.fin:25384)accn|OU677776
# spike(pos.ini:21562 pos.fin:25384)accn|OU670688
# spike(pos.ini:21562 pos.fin:25384)accn|OU686061
# spike(pos.ini:21562 pos.fin:25384)accn|OU670962
# spike(pos.ini:21562 pos.fin:25384)accn|OU666724
# spike(pos.ini:21562 pos.fin:25384)accn|OU680126
# spike(pos.ini:21562 pos.fin:25384)accn|OU680194
# spike(pos.ini:21562 pos.fin:25384)accn|OU664786
# spike(pos.ini:21562 pos.fin:25384)accn|OU676141
# spike(pos.ini:21562 pos.fin:25384)accn|OU657377
# spike(pos.ini:21562 pos.fin:25384)accn|OU692702
# spike(pos.ini:21562 pos.fin:25384)accn|OU671554
# spike(pos.ini:21562 pos.fin:25384)accn|OU682572
# spike(pos.ini:21562 pos.fin:25384)accn|OU689013
# spike(pos.ini:21562 pos.fin:25384)accn|OU676984
# spike(pos.ini:21562 pos.fin:25384)accn|OU680785
# spike(pos.ini:21562 pos.fin:25384)accn|OU661419
# spike(pos.ini:21562 pos.fin:25384)accn|OU697639
# spike(pos.ini:21562 pos.fin:25384)accn|OU689431
# spike(pos.ini:21562 pos.fin:25384)accn|OU697898
# spike(pos.ini:21562 pos.fin:25384)accn|OU703285
# spike(pos.ini:21562 pos.fin:25384)accn|OU672171
# spike(pos.ini:21562 pos.fin:25384)accn|OU685435
# spike(pos.ini:21562 pos.fin:25384)accn|OU701541
# spike(pos.ini:21562 pos.fin:25384)accn|OU688007
# spike(pos.ini:21562 pos.fin:25384)accn|OU688010
# spike(pos.ini:21562 pos.fin:25384)accn|OU701652
# spike(pos.ini:21562 pos.fin:25384)accn|OU692180
# spike(pos.ini:21562 pos.fin:25384)accn|OU692282
# spike(pos.ini:21562 pos.fin:25384)accn|OU714031
# spike(pos.ini:21562 pos.fin:25384)accn|OU694189
# spike(pos.ini:21562 pos.fin:25384)accn|OU714152
# spike(pos.ini:21562 pos.fin:25384)accn|OU694306
# spike(pos.ini:21562 pos.fin:25384)accn|OU701882
# spike(pos.ini:21562 pos.fin:25384)accn|OU708294
# spike(pos.ini:21562 pos.fin:25384)accn|OU714413
# spike(pos.ini:21562 pos.fin:25384)accn|OU702164
# spike(pos.ini:21562 pos.fin:25384)accn|OU702271
# spike(pos.ini:21562 pos.fin:25384)accn|OU709007
# spike(pos.ini:21562 pos.fin:25384)accn|OU702499
# spike(pos.ini:21562 pos.fin:25384)accn|OU702724
# spike(pos.ini:21562 pos.fin:25384)accn|OU702811
# spike(pos.ini:21562 pos.fin:25384)accn|OU744489
# spike(pos.ini:21562 pos.fin:25384)accn|OU744683
# spike(pos.ini:21562 pos.fin:25384)accn|OU744693
# spike(pos.ini:21562 pos.fin:25384)accn|OU745472
# spike(pos.ini:21562 pos.fin:25384)accn|OU746403
# spike(pos.ini:21562 pos.fin:25384)accn|OU746951
# spike(pos.ini:21562 pos.fin:25384)accn|OU747024
# spike(pos.ini:21562 pos.fin:25384)accn|OU747379
# spike(pos.ini:21562 pos.fin:25384)accn|OU750038
# spike(pos.ini:21562 pos.fin:25384)accn|OU751733
# spike(pos.ini:21562 pos.fin:25384)accn|OU752004
# spike(pos.ini:21562 pos.fin:25384)accn|OU752176
# spike(pos.ini:21562 pos.fin:25384)accn|OU753790
# spike(pos.ini:21562 pos.fin:25384)accn|LR883974
# spike(pos.ini:21562 pos.fin:25384)accn|LR883995
# spike(pos.ini:21562 pos.fin:25384)accn|LR883996
# spike(pos.ini:21562 pos.fin:25384)accn|LR884009
# spike(pos.ini:21562 pos.fin:25384)accn|LR884020
# spike(pos.ini:21562 pos.fin:25384)accn|LR884033
# spike(pos.ini:21562 pos.fin:25384)accn|LR884054
# spike(pos.ini:21562 pos.fin:25384)accn|LR884063
# spike(pos.ini:21562 pos.fin:25384)accn|LR884065
# spike(pos.ini:21562 pos.fin:25384)accn|LR884078
# spike(pos.ini:21562 pos.fin:25384)accn|LR884082
# spike(pos.ini:21562 pos.fin:25384)accn|LR884120
# spike(pos.ini:21562 pos.fin:25384)accn|LR884126
# spike(pos.ini:21562 pos.fin:25384)accn|LR884128
# spike(pos.ini:21562 pos.fin:25384)accn|LR884129
# spike(pos.ini:21562 pos.fin:25384)accn|LR884140
# spike(pos.ini:21562 pos.fin:25384)accn|LR884163
# spike(pos.ini:21562 pos.fin:25384)accn|LR884166
# spike(pos.ini:21562 pos.fin:25384)accn|LR884170
# spike(pos.ini:21562 pos.fin:25384)accn|LR884171
# spike(pos.ini:21562 pos.fin:25384)accn|LR884172
# spike(pos.ini:21562 pos.fin:25384)accn|LR884174
# spike(pos.ini:21562 pos.fin:25384)accn|LR884175
# spike(pos.ini:21562 pos.fin:25384)accn|LR884176
# spike(pos.ini:21562 pos.fin:25384)accn|MT641755
# spike(pos.ini:21562 pos.fin:25384)accn|MT655135
# spike(pos.ini:21562 pos.fin:25384)accn|MW065372
# spike(pos.ini:21562 pos.fin:25384)accn|MT459861
# spike(pos.ini:21562 pos.fin:25384)accn|MT451185
# spike(pos.ini:21562 pos.fin:25384)accn|OK435591
# spike(pos.ini:21562 pos.fin:25384)accn|OK549005
# spike(pos.ini:21562 pos.fin:25384)accn|OK549043
# spike(pos.ini:21562 pos.fin:25384)accn|OL756142
# spike(pos.ini:21562 pos.fin:25384)accn|FR998175
# spike(pos.ini:21562 pos.fin:25384)accn|FR999847
# spike(pos.ini:21562 pos.fin:25384)accn|MW672626
# spike(pos.ini:21562 pos.fin:25384)accn|MW672628
# spike(pos.ini:21562 pos.fin:25384)accn|MW672653
# spike(pos.ini:21562 pos.fin:25384)accn|ON017219
# spike(pos.ini:21562 pos.fin:25384)accn|ON017230
# spike(pos.ini:21562 pos.fin:25384)accn|OA964422
# spike(pos.ini:21562 pos.fin:25384)accn|OA964701
# spike(pos.ini:21562 pos.fin:25384)accn|OA965074
# spike(pos.ini:21562 pos.fin:25384)accn|OA966159
# spike(pos.ini:21562 pos.fin:25384)accn|OA966199
# spike(pos.ini:21562 pos.fin:25384)accn|OA966240
# spike(pos.ini:21562 pos.fin:25384)accn|OA966567
# spike(pos.ini:21562 pos.fin:25384)accn|OA971552
# spike(pos.ini:21562 pos.fin:25384)accn|OA971920
# spike(pos.ini:21562 pos.fin:25384)accn|MW375727
# spike(pos.ini:21562 pos.fin:25384)accn|MT810558
# spike(pos.ini:21562 pos.fin:25384)accn|MT811550
# spike(pos.ini:21562 pos.fin:25384)accn|FR998439
# spike(pos.ini:21562 pos.fin:25384)accn|FR998477
# spike(pos.ini:21562 pos.fin:25384)accn|FR999205
# spike(pos.ini:21562 pos.fin:25384)accn|MT256924
# spike(pos.ini:21562 pos.fin:25384)accn|OA966291
# spike(pos.ini:21562 pos.fin:25384)accn|MW190973
# spike(pos.ini:21562 pos.fin:25384)accn|MT370848
# spike(pos.ini:21562 pos.fin:25384)accn|MT451042
# spike(pos.ini:21562 pos.fin:25384)accn|MT459919
# spike(pos.ini:21562 pos.fin:25384)accn|MT466071
# spike(pos.ini:21562 pos.fin:25384)accn|MT582461
# spike(pos.ini:21562 pos.fin:25384)accn|MW030223
# spike(pos.ini:21562 pos.fin:25384)accn|OU329975
# spike(pos.ini:21562 pos.fin:25384)accn|OU428228
# spike(pos.ini:21562 pos.fin:25384)accn|OU509703
# spike(pos.ini:21562 pos.fin:25384)accn|OU480847
# spike(pos.ini:21562 pos.fin:25384)accn|OU534438
# spike(pos.ini:21562 pos.fin:25384)accn|OU540618
# spike(pos.ini:21562 pos.fin:25384)accn|OU534072
# spike(pos.ini:21562 pos.fin:25384)accn|OU550290
# spike(pos.ini:21562 pos.fin:25384)accn|OU556646
# spike(pos.ini:21562 pos.fin:25384)accn|OU557230
# spike(pos.ini:21562 pos.fin:25384)accn|OU467729
# spike(pos.ini:21562 pos.fin:25384)accn|OU594919
# spike(pos.ini:21562 pos.fin:25384)accn|OU589198
# spike(pos.ini:21562 pos.fin:25384)accn|OU593779
# spike(pos.ini:21562 pos.fin:25384)accn|OU686021
# spike(pos.ini:21562 pos.fin:25384)accn|OU699625
# spike(pos.ini:21562 pos.fin:25384)accn|OU685624
# spike(pos.ini:21562 pos.fin:25384)accn|OU681572
# spike(pos.ini:21562 pos.fin:25384)accn|OU715380
# spike(pos.ini:21562 pos.fin:25384)accn|OU750147
# spike(pos.ini:21562 pos.fin:25384)accn|OU750217
# spike(pos.ini:21562 pos.fin:25384)accn|OU751188
# spike(pos.ini:21562 pos.fin:25384)accn|OU753785
# spike(pos.ini:21562 pos.fin:25384)accn|OU754017
# spike(pos.ini:21562 pos.fin:25384)accn|OU754335
# spike(pos.ini:21562 pos.fin:25384)accn|OU775104
# spike(pos.ini:21562 pos.fin:25384)accn|OU775690
# spike(pos.ini:21562 pos.fin:25384)accn|OU759303
# spike(pos.ini:21562 pos.fin:25384)accn|OU777900
# spike(pos.ini:21562 pos.fin:25384)accn|OU761411
# spike(pos.ini:21562 pos.fin:25384)accn|OU779319
# spike(pos.ini:21562 pos.fin:25384)accn|OU783272
# spike(pos.ini:21562 pos.fin:25384)accn|OU788076
# spike(pos.ini:21562 pos.fin:25384)accn|OU911630
# spike(pos.ini:21562 pos.fin:25384)accn|OU912285
# spike(pos.ini:21562 pos.fin:25384)accn|OU902899
# spike(pos.ini:21562 pos.fin:25384)accn|OU892897
# spike(pos.ini:21562 pos.fin:25384)accn|OU893748
# spike(pos.ini:21562 pos.fin:25384)accn|OU905199
# spike(pos.ini:21562 pos.fin:25384)accn|OU897332
# spike(pos.ini:21562 pos.fin:25384)accn|OU908044
# spike(pos.ini:21562 pos.fin:25384)accn|OU908162
# spike(pos.ini:21562 pos.fin:25384)accn|OU898258
# spike(pos.ini:21562 pos.fin:25384)accn|OU900028
# spike(pos.ini:21562 pos.fin:25384)accn|OU900038
# spike(pos.ini:21562 pos.fin:25384)accn|OU911003
# spike(pos.ini:21562 pos.fin:25384)accn|OU900968
# spike(pos.ini:21562 pos.fin:25384)accn|OU901314
# spike(pos.ini:21562 pos.fin:25384)accn|OU871935
# spike(pos.ini:21562 pos.fin:25384)accn|OU850958
# spike(pos.ini:21562 pos.fin:25384)accn|OU884012
# spike(pos.ini:21562 pos.fin:25384)accn|OU874190
# spike(pos.ini:21562 pos.fin:25384)accn|OU864530
# spike(pos.ini:21562 pos.fin:25384)accn|OU866255
# spike(pos.ini:21562 pos.fin:25384)accn|OU876406
# spike(pos.ini:21562 pos.fin:25384)accn|OU854824
# spike(pos.ini:21562 pos.fin:25384)accn|OU856679
# spike(pos.ini:21562 pos.fin:25384)accn|OU858906
# spike(pos.ini:21562 pos.fin:25384)accn|OU840552
# spike(pos.ini:21562 pos.fin:25384)accn|OU820532
# spike(pos.ini:21562 pos.fin:25384)accn|OU830860
# spike(pos.ini:21562 pos.fin:25384)accn|OU831117
# spike(pos.ini:21562 pos.fin:25384)accn|OU841558
# spike(pos.ini:21562 pos.fin:25384)accn|OU841640
# spike(pos.ini:21562 pos.fin:25384)accn|OU842467
# spike(pos.ini:21562 pos.fin:25384)accn|OU842726
# spike(pos.ini:21562 pos.fin:25384)accn|OU843103
# spike(pos.ini:21562 pos.fin:25384)accn|OU823213
# spike(pos.ini:21562 pos.fin:25384)accn|OU834582
# spike(pos.ini:21562 pos.fin:25384)accn|OU845279
# spike(pos.ini:21562 pos.fin:25384)accn|OU835722
# spike(pos.ini:21562 pos.fin:25384)accn|OU845916
# spike(pos.ini:21562 pos.fin:25384)accn|OU846463
# spike(pos.ini:21562 pos.fin:25384)accn|OU847038
# spike(pos.ini:21562 pos.fin:25384)accn|OU816374
# spike(pos.ini:21562 pos.fin:25384)accn|OU791141
# spike(pos.ini:21562 pos.fin:25384)accn|OU816670
# spike(pos.ini:21562 pos.fin:25384)accn|OU838741
# spike(pos.ini:21562 pos.fin:25384)accn|OU839115
# spike(pos.ini:21562 pos.fin:25384)accn|OU849384
# spike(pos.ini:21562 pos.fin:25384)accn|OU849484
# spike(pos.ini:21562 pos.fin:25384)accn|OU839755
# spike(pos.ini:21562 pos.fin:25384)accn|OU808927
# spike(pos.ini:21562 pos.fin:25384)accn|OU768287
# spike(pos.ini:21562 pos.fin:25384)accn|OU737317
# spike(pos.ini:21562 pos.fin:25384)accn|OU737821
# spike(pos.ini:21562 pos.fin:25384)accn|OU769551
# spike(pos.ini:21562 pos.fin:25384)accn|OU739204
# spike(pos.ini:21562 pos.fin:25384)accn|OU645105
# spike(pos.ini:21562 pos.fin:25384)accn|OU788882
# spike(pos.ini:21562 pos.fin:25384)accn|OU789808
# spike(pos.ini:21562 pos.fin:25384)accn|OU716603
# spike(pos.ini:21562 pos.fin:25384)accn|OU638045
# spike(pos.ini:21562 pos.fin:25384)accn|OU717372
# spike(pos.ini:21562 pos.fin:25384)accn|OU717877
# spike(pos.ini:21562 pos.fin:25384)accn|OU728633
# spike(pos.ini:21562 pos.fin:25384)accn|OU521408
# spike(pos.ini:21562 pos.fin:25384)accn|OU524005
# spike(pos.ini:21562 pos.fin:25384)accn|OU524022
# spike(pos.ini:21562 pos.fin:25384)accn|OU526343
# spike(pos.ini:21562 pos.fin:25384)accn|OK470431
# spike(pos.ini:21562 pos.fin:25384)accn|OU916660
# spike(pos.ini:21562 pos.fin:25384)accn|OU916826
# spike(pos.ini:21562 pos.fin:25384)accn|OU914388
# spike(pos.ini:21562 pos.fin:25384)accn|OU914910
# spike(pos.ini:21562 pos.fin:25384)accn|OU965405
# spike(pos.ini:21562 pos.fin:25384)accn|OU945120
# spike(pos.ini:21562 pos.fin:25384)accn|OU967092
# spike(pos.ini:21562 pos.fin:25384)accn|OU938491
# spike(pos.ini:21562 pos.fin:25384)accn|OU967877
# spike(pos.ini:21562 pos.fin:25384)accn|OU968183
# spike(pos.ini:21562 pos.fin:25384)accn|OU958459
# spike(pos.ini:21562 pos.fin:25384)accn|OU948316
# spike(pos.ini:21562 pos.fin:25384)accn|OU958597
# spike(pos.ini:21562 pos.fin:25384)accn|OU958921
# spike(pos.ini:21562 pos.fin:25384)accn|OU948711
# spike(pos.ini:21562 pos.fin:25384)accn|OU974856
# spike(pos.ini:21562 pos.fin:25384)accn|OU959041
# spike(pos.ini:21562 pos.fin:25384)accn|OU959198
# spike(pos.ini:21562 pos.fin:25384)accn|OU959230
# spike(pos.ini:21562 pos.fin:25384)accn|OU959279
# spike(pos.ini:21562 pos.fin:25384)accn|OU959309
# spike(pos.ini:21562 pos.fin:25384)accn|OU959321
# spike(pos.ini:21562 pos.fin:25384)accn|OU959451
# spike(pos.ini:21562 pos.fin:25384)accn|OU975504
# spike(pos.ini:21562 pos.fin:25384)accn|OU975730
# spike(pos.ini:21562 pos.fin:25384)accn|OU975795
# spike(pos.ini:21562 pos.fin:25384)accn|OU976232
# spike(pos.ini:21562 pos.fin:25384)accn|OU977157
# spike(pos.ini:21562 pos.fin:25384)accn|OU961275
# spike(pos.ini:21562 pos.fin:25384)accn|OU977442
# spike(pos.ini:21562 pos.fin:25384)accn|OU977487
# spike(pos.ini:21562 pos.fin:25384)accn|OU951487
# spike(pos.ini:21562 pos.fin:25384)accn|OU978123
# spike(pos.ini:21562 pos.fin:25384)accn|OU952135
# spike(pos.ini:21562 pos.fin:25384)accn|OU978424
# spike(pos.ini:21562 pos.fin:25384)accn|OU979099
# spike(pos.ini:21562 pos.fin:25384)accn|OU979131
# spike(pos.ini:21562 pos.fin:25384)accn|OU963372
# spike(pos.ini:21562 pos.fin:25384)accn|OU979664
# spike(pos.ini:21562 pos.fin:25384)accn|OU979703
# spike(pos.ini:21562 pos.fin:25384)accn|OU963931
# ...
# spike(pos.ini:21562 pos.fin:25384)accn|OV012961
# spike(pos.ini:21562 pos.fin:25384)accn|OU982458
# spike(pos.ini:21562 pos.fin:25384)accn|OU982587
# spike(pos.ini:21562 pos.fin:25384)accn|OV013151
# spike(pos.ini:21562 pos.fin:25384)accn|OV013274
# spike(pos.ini:21562 pos.fin:25384)accn|OU993316
# spike(pos.ini:21562 pos.fin:25384)accn|OV013318
# spike(pos.ini:21562 pos.fin:25384)accn|OV003415
# spike(pos.ini:21562 pos.fin:25384)accn|OU993606
# spike(pos.ini:21562 pos.fin:25384)accn|OU983188
# spike(pos.ini:21562 pos.fin:25384)accn|OV023897
# spike(pos.ini:21562 pos.fin:25384)accn|OV004120
# spike(pos.ini:21562 pos.fin:25384)accn|OV004152
# spike(pos.ini:21562 pos.fin:25384)accn|OV014275
# spike(pos.ini:21562 pos.fin:25384)accn|OU983781
# spike(pos.ini:21562 pos.fin:25384)accn|OV014458
# spike(pos.ini:21562 pos.fin:25384)accn|OV015022
# spike(pos.ini:21562 pos.fin:25384)accn|OV025228
# spike(pos.ini:21562 pos.fin:25384)accn|OV005428
# spike(pos.ini:21562 pos.fin:25384)accn|OU985088
# spike(pos.ini:21562 pos.fin:25384)accn|OU995694
# spike(pos.ini:21562 pos.fin:25384)accn|OV025696
# spike(pos.ini:21562 pos.fin:25384)accn|OV015823
# spike(pos.ini:21562 pos.fin:25384)accn|OV005955
# spike(pos.ini:21562 pos.fin:25384)accn|OU985646
# spike(pos.ini:21562 pos.fin:25384)accn|OV016220
# spike(pos.ini:21562 pos.fin:25384)accn|OU985765
# spike(pos.ini:21562 pos.fin:25384)accn|OV016435
# spike(pos.ini:21562 pos.fin:25384)accn|OV026687
# spike(pos.ini:21562 pos.fin:25384)accn|OU986287
# spike(pos.ini:21562 pos.fin:25384)accn|OV016785
# spike(pos.ini:21562 pos.fin:25384)accn|OV082023
# spike(pos.ini:21562 pos.fin:25384)accn|OV106369
# spike(pos.ini:21562 pos.fin:25384)accn|OV066232
# spike(pos.ini:21562 pos.fin:25384)accn|OV066233
# spike(pos.ini:21562 pos.fin:25384)accn|OV082038
# spike(pos.ini:21562 pos.fin:25384)accn|OV066240
# spike(pos.ini:21562 pos.fin:25384)accn|OV082050
# spike(pos.ini:21562 pos.fin:25384)accn|OV066347
# spike(pos.ini:21562 pos.fin:25384)accn|OV106533
# spike(pos.ini:21562 pos.fin:25384)accn|OV106545
# spike(pos.ini:21562 pos.fin:25384)accn|OV066417
# spike(pos.ini:21562 pos.fin:25384)accn|OV082243
# spike(pos.ini:21562 pos.fin:25384)accn|OV066465
# spike(pos.ini:21562 pos.fin:25384)accn|OV082318
# spike(pos.ini:21562 pos.fin:25384)accn|OV082340
# spike(pos.ini:21562 pos.fin:25384)accn|OV106694
# spike(pos.ini:21562 pos.fin:25384)accn|OV082371
# spike(pos.ini:21562 pos.fin:25384)accn|OV082382
# spike(pos.ini:21562 pos.fin:25384)accn|OV066578
# spike(pos.ini:21562 pos.fin:25384)accn|OV066595
# spike(pos.ini:21562 pos.fin:25384)accn|OV082402
# spike(pos.ini:21562 pos.fin:25384)accn|OV066656
# spike(pos.ini:21562 pos.fin:25384)accn|OV082491
# spike(pos.ini:21562 pos.fin:25384)accn|OV082618
# spike(pos.ini:21562 pos.fin:25384)accn|OV082620
# spike(pos.ini:21562 pos.fin:25384)accn|OV082639
# spike(pos.ini:21562 pos.fin:25384)accn|OV082641
# spike(pos.ini:21562 pos.fin:25384)accn|OV066855
# spike(pos.ini:21562 pos.fin:25384)accn|OV107029
# spike(pos.ini:21562 pos.fin:25384)accn|OV082717
# spike(pos.ini:21562 pos.fin:25384)accn|OV082748
# spike(pos.ini:21562 pos.fin:25384)accn|OV066962
# spike(pos.ini:21562 pos.fin:25384)accn|OV066994
# spike(pos.ini:21562 pos.fin:25384)accn|OV082843
# spike(pos.ini:21562 pos.fin:25384)accn|OV113059
# spike(pos.ini:21562 pos.fin:25384)accn|OV082902
# spike(pos.ini:21562 pos.fin:25384)accn|OV067112
# spike(pos.ini:21562 pos.fin:25384)accn|OV113124
# spike(pos.ini:21562 pos.fin:25384)accn|OV067135
# spike(pos.ini:21562 pos.fin:25384)accn|OV067176
# spike(pos.ini:21562 pos.fin:25384)accn|OV082996
# spike(pos.ini:21562 pos.fin:25384)accn|OV067201
# spike(pos.ini:21562 pos.fin:25384)accn|OV067214
# spike(pos.ini:21562 pos.fin:25384)accn|OV067218
# spike(pos.ini:21562 pos.fin:25384)accn|OV083054
# spike(pos.ini:21562 pos.fin:25384)accn|OV067252
# spike(pos.ini:21562 pos.fin:25384)accn|OV067257
# spike(pos.ini:21562 pos.fin:25384)accn|OV113283
# spike(pos.ini:21562 pos.fin:25384)accn|OV083108
# spike(pos.ini:21562 pos.fin:25384)accn|OV113303
# spike(pos.ini:21562 pos.fin:25384)accn|OV067320
# spike(pos.ini:21562 pos.fin:25384)accn|OV083156
# spike(pos.ini:21562 pos.fin:25384)accn|OV067352
# spike(pos.ini:21562 pos.fin:25384)accn|OV067379
# spike(pos.ini:21562 pos.fin:25384)accn|OV067389
# spike(pos.ini:21562 pos.fin:25384)accn|OV113410
# spike(pos.ini:21562 pos.fin:25384)accn|OV067410
# spike(pos.ini:21562 pos.fin:25384)accn|OV113455
# spike(pos.ini:21562 pos.fin:25384)accn|OV113456
# spike(pos.ini:21562 pos.fin:25384)accn|OV067451
# spike(pos.ini:21562 pos.fin:25384)accn|OV113464
# spike(pos.ini:21562 pos.fin:25384)accn|OV067477
# spike(pos.ini:21562 pos.fin:25384)accn|OV067484
# spike(pos.ini:21562 pos.fin:25384)accn|OV083322
# spike(pos.ini:21562 pos.fin:25384)accn|OV083325
# spike(pos.ini:21562 pos.fin:25384)accn|OV083344
# spike(pos.ini:21562 pos.fin:25384)accn|OV067547
# spike(pos.ini:21562 pos.fin:25384)accn|OV067595
# spike(pos.ini:21562 pos.fin:25384)accn|OV067610
# spike(pos.ini:21562 pos.fin:25384)accn|OV083430
# spike(pos.ini:21562 pos.fin:25384)accn|OV067640
# spike(pos.ini:21562 pos.fin:25384)accn|OV067641
# spike(pos.ini:21562 pos.fin:25384)accn|OV113677
# spike(pos.ini:21562 pos.fin:25384)accn|OV067682
# spike(pos.ini:21562 pos.fin:25384)accn|OV067700
# spike(pos.ini:21562 pos.fin:25384)accn|OV083522
# spike(pos.ini:21562 pos.fin:25384)accn|OV067708
# spike(pos.ini:21562 pos.fin:25384)accn|OV083530
# spike(pos.ini:21562 pos.fin:25384)accn|OV083548
# spike(pos.ini:21562 pos.fin:25384)accn|OV113745
# spike(pos.ini:21562 pos.fin:25384)accn|OV067762
# spike(pos.ini:21562 pos.fin:25384)accn|OV067791
# spike(pos.ini:21562 pos.fin:25384)accn|OV083610
# spike(pos.ini:21562 pos.fin:25384)accn|OV113799
# spike(pos.ini:21562 pos.fin:25384)accn|OV067805
# spike(pos.ini:21562 pos.fin:25384)accn|OV067825
# spike(pos.ini:21562 pos.fin:25384)accn|OV067846
# spike(pos.ini:21562 pos.fin:25384)accn|OV067854
# spike(pos.ini:21562 pos.fin:25384)accn|OV083677
# spike(pos.ini:21562 pos.fin:25384)accn|OV067922
# spike(pos.ini:21562 pos.fin:25384)accn|OV067934
# spike(pos.ini:21562 pos.fin:25384)accn|OV067944
# spike(pos.ini:21562 pos.fin:25384)accn|OV083759
# spike(pos.ini:21562 pos.fin:25384)accn|OV067947
# spike(pos.ini:21562 pos.fin:25384)accn|OV067972
# spike(pos.ini:21562 pos.fin:25384)accn|OV083785
# spike(pos.ini:21562 pos.fin:25384)accn|OV068003
# spike(pos.ini:21562 pos.fin:25384)accn|OV068021
# spike(pos.ini:21562 pos.fin:25384)accn|OV083841
# spike(pos.ini:21562 pos.fin:25384)accn|OV068044
# spike(pos.ini:21562 pos.fin:25384)accn|OV083861
# spike(pos.ini:21562 pos.fin:25384)accn|OV068068
# spike(pos.ini:21562 pos.fin:25384)accn|OV083904
# spike(pos.ini:21562 pos.fin:25384)accn|OV083927
# spike(pos.ini:21562 pos.fin:25384)accn|OV068118
# spike(pos.ini:21562 pos.fin:25384)accn|OV114142
# spike(pos.ini:21562 pos.fin:25384)accn|OV068181
# spike(pos.ini:21562 pos.fin:25384)accn|OV084099
# spike(pos.ini:21562 pos.fin:25384)accn|OV068324
# spike(pos.ini:21562 pos.fin:25384)accn|OV114324
# spike(pos.ini:21562 pos.fin:25384)accn|OV068339
# spike(pos.ini:21562 pos.fin:25384)accn|OV068357
# spike(pos.ini:21562 pos.fin:25384)accn|OV068378
# spike(pos.ini:21562 pos.fin:25384)accn|OV068447
# spike(pos.ini:21562 pos.fin:25384)accn|OV068517
# spike(pos.ini:21562 pos.fin:25384)accn|OV114526
# spike(pos.ini:21562 pos.fin:25384)accn|OV114542
# spike(pos.ini:21562 pos.fin:25384)accn|OV090249
# spike(pos.ini:21562 pos.fin:25384)accn|OV090278
# spike(pos.ini:21562 pos.fin:25384)accn|OV068671
# spike(pos.ini:21562 pos.fin:25384)accn|OV068678
# spike(pos.ini:21562 pos.fin:25384)accn|OV068690
# spike(pos.ini:21562 pos.fin:25384)accn|OV068736
# spike(pos.ini:21562 pos.fin:25384)accn|OV068748
# spike(pos.ini:21562 pos.fin:25384)accn|OV068755
# spike(pos.ini:21562 pos.fin:25384)accn|OV068758
# spike(pos.ini:21562 pos.fin:25384)accn|OV114798
# spike(pos.ini:21562 pos.fin:25384)accn|OV068810
# spike(pos.ini:21562 pos.fin:25384)accn|OV090450
# spike(pos.ini:21562 pos.fin:25384)accn|OV068826
# spike(pos.ini:21562 pos.fin:25384)accn|OV068846
# spike(pos.ini:21562 pos.fin:25384)accn|OV114895
# spike(pos.ini:21562 pos.fin:25384)accn|OV090539
# spike(pos.ini:21562 pos.fin:25384)accn|OV068902
# spike(pos.ini:21562 pos.fin:25384)accn|OV090559
# spike(pos.ini:21562 pos.fin:25384)accn|OV068936
# spike(pos.ini:21562 pos.fin:25384)accn|OV090603
# spike(pos.ini:21562 pos.fin:25384)accn|OV068996
# spike(pos.ini:21562 pos.fin:25384)accn|OV069034
# spike(pos.ini:21562 pos.fin:25384)accn|OV069067
# spike(pos.ini:21562 pos.fin:25384)accn|OV069138
# spike(pos.ini:21562 pos.fin:25384)accn|OV069143
# spike(pos.ini:21562 pos.fin:25384)accn|OV069152
# spike(pos.ini:21562 pos.fin:25384)accn|OV069153
# spike(pos.ini:21562 pos.fin:25384)accn|OV069157
# spike(pos.ini:21562 pos.fin:25384)accn|OV069159
# spike(pos.ini:21562 pos.fin:25384)accn|OV115172
# spike(pos.ini:21562 pos.fin:25384)accn|OV069187
# spike(pos.ini:21562 pos.fin:25384)accn|OV069203
# spike(pos.ini:21562 pos.fin:25384)accn|OV090856
# spike(pos.ini:21562 pos.fin:25384)accn|MZ713883
# spike(pos.ini:21562 pos.fin:25384)accn|MZ713959
# spike(pos.ini:21562 pos.fin:25384)accn|OU473233
# spike(pos.ini:21562 pos.fin:25384)accn|OU451604
# spike(pos.ini:21562 pos.fin:25384)accn|OU451744
# spike(pos.ini:21562 pos.fin:25384)accn|OU451747
# spike(pos.ini:21562 pos.fin:25384)accn|OU451756
# spike(pos.ini:21562 pos.fin:25384)accn|OU451896
# spike(pos.ini:21562 pos.fin:25384)accn|OU451914
# spike(pos.ini:21562 pos.fin:25384)accn|OU451985
# spike(pos.ini:21562 pos.fin:25384)accn|OU451388
# spike(pos.ini:21562 pos.fin:25384)accn|OU508223
# spike(pos.ini:21562 pos.fin:25384)accn|OU502583
# spike(pos.ini:21562 pos.fin:25384)accn|MZ809971
# spike(pos.ini:21562 pos.fin:25384)accn|MZ874900
# spike(pos.ini:21562 pos.fin:25384)accn|MZ858714
# spike(pos.ini:21562 pos.fin:25384)accn|MZ864793
# spike(pos.ini:21562 pos.fin:25384)accn|MZ862993
# spike(pos.ini:21562 pos.fin:25384)accn|MZ908701
# spike(pos.ini:21562 pos.fin:25384)accn|MZ939609
# spike(pos.ini:21562 pos.fin:25384)accn|MZ946789
# spike(pos.ini:21562 pos.fin:25384)accn|MZ944696
# spike(pos.ini:21562 pos.fin:25384)accn|OU566513
# spike(pos.ini:21562 pos.fin:25384)accn|OU562939
# spike(pos.ini:21562 pos.fin:25384)accn|OU566574
# spike(pos.ini:21562 pos.fin:25384)accn|OU566679
# spike(pos.ini:21562 pos.fin:25384)accn|OU566763
# spike(pos.ini:21562 pos.fin:25384)accn|OU566764
# spike(pos.ini:21562 pos.fin:25384)accn|OU566766
# spike(pos.ini:21562 pos.fin:25384)accn|OU566812
# spike(pos.ini:21562 pos.fin:25384)accn|OU566839
# spike(pos.ini:21562 pos.fin:25384)accn|OU566849
# spike(pos.ini:21562 pos.fin:25384)accn|OU566853
# spike(pos.ini:21562 pos.fin:25384)accn|OU566861
# spike(pos.ini:21562 pos.fin:25384)accn|OU566881
# spike(pos.ini:21562 pos.fin:25384)accn|OU566886
# spike(pos.ini:21562 pos.fin:25384)accn|OU566906
# spike(pos.ini:21562 pos.fin:25384)accn|OU566954
# spike(pos.ini:21562 pos.fin:25384)accn|OU570531
# spike(pos.ini:21562 pos.fin:25384)accn|OU568535
# spike(pos.ini:21562 pos.fin:25384)accn|OU570533
# spike(pos.ini:21562 pos.fin:25384)accn|OU570543
# spike(pos.ini:21562 pos.fin:25384)accn|OU570561
# spike(pos.ini:21562 pos.fin:25384)accn|OU567007
# spike(pos.ini:21562 pos.fin:25384)accn|OU574555
# spike(pos.ini:21562 pos.fin:25384)accn|OU568596
# spike(pos.ini:21562 pos.fin:25384)accn|OU567021
# spike(pos.ini:21562 pos.fin:25384)accn|OU567024
# spike(pos.ini:21562 pos.fin:25384)accn|OU565350
# spike(pos.ini:21562 pos.fin:25384)accn|OU576564
# spike(pos.ini:21562 pos.fin:25384)accn|OU568648
# spike(pos.ini:21562 pos.fin:25384)accn|OU570647
# spike(pos.ini:21562 pos.fin:25384)accn|OU570648
# spike(pos.ini:21562 pos.fin:25384)accn|OU567078
# spike(pos.ini:21562 pos.fin:25384)accn|OU570669
# spike(pos.ini:21562 pos.fin:25384)accn|OU567122
# spike(pos.ini:21562 pos.fin:25384)accn|OU567125
# spike(pos.ini:21562 pos.fin:25384)accn|OU574672
# spike(pos.ini:21562 pos.fin:25384)accn|OU567159
# spike(pos.ini:21562 pos.fin:25384)accn|OU567187
# spike(pos.ini:21562 pos.fin:25384)accn|OU567190
# spike(pos.ini:21562 pos.fin:25384)accn|OU553803
# spike(pos.ini:21562 pos.fin:25384)accn|OU574734
# spike(pos.ini:21562 pos.fin:25384)accn|OU567225
# spike(pos.ini:21562 pos.fin:25384)accn|OU568837
# spike(pos.ini:21562 pos.fin:25384)accn|OU576747
# spike(pos.ini:21562 pos.fin:25384)accn|OU565525
# spike(pos.ini:21562 pos.fin:25384)accn|OU565563
# spike(pos.ini:21562 pos.fin:25384)accn|OU570976
# spike(pos.ini:21562 pos.fin:25384)accn|OU578798
# spike(pos.ini:21562 pos.fin:25384)accn|OU574912
# spike(pos.ini:21562 pos.fin:25384)accn|OU572913
# spike(pos.ini:21562 pos.fin:25384)accn|OU565655
# spike(pos.ini:21562 pos.fin:25384)accn|OU567483
# spike(pos.ini:21562 pos.fin:25384)accn|OU567487
# spike(pos.ini:21562 pos.fin:25384)accn|OU567489
# spike(pos.ini:21562 pos.fin:25384)accn|OU567503
# spike(pos.ini:21562 pos.fin:25384)accn|OU569184
# spike(pos.ini:21562 pos.fin:25384)accn|OU569203
# spike(pos.ini:21562 pos.fin:25384)accn|OU573039
# spike(pos.ini:21562 pos.fin:25384)accn|OU567541
# spike(pos.ini:21562 pos.fin:25384)accn|OU567551
# spike(pos.ini:21562 pos.fin:25384)accn|OU573063
# spike(pos.ini:21562 pos.fin:25384)accn|OU575075
# spike(pos.ini:21562 pos.fin:25384)accn|OU577040
# spike(pos.ini:21562 pos.fin:25384)accn|OU577066
# spike(pos.ini:21562 pos.fin:25384)accn|OU569389
# spike(pos.ini:21562 pos.fin:25384)accn|OU577149
# spike(pos.ini:21562 pos.fin:25384)accn|OU567706
# spike(pos.ini:21562 pos.fin:25384)accn|OU581636
# spike(pos.ini:21562 pos.fin:25384)accn|OU569532
# spike(pos.ini:21562 pos.fin:25384)accn|OU573352
# spike(pos.ini:21562 pos.fin:25384)accn|OU569627
# spike(pos.ini:21562 pos.fin:25384)accn|OU569632
# spike(pos.ini:21562 pos.fin:25384)accn|OU571583
# spike(pos.ini:21562 pos.fin:25384)accn|OU571585
# spike(pos.ini:21562 pos.fin:25384)accn|MZ860979
# spike(pos.ini:21562 pos.fin:25384)accn|OU566049
# spike(pos.ini:21562 pos.fin:25384)accn|OU573427
# spike(pos.ini:21562 pos.fin:25384)accn|OU569794
# spike(pos.ini:21562 pos.fin:25384)accn|OU568048
# spike(pos.ini:21562 pos.fin:25384)accn|OU566184
# spike(pos.ini:21562 pos.fin:25384)accn|OU568089
# spike(pos.ini:21562 pos.fin:25384)accn|OU566194
# spike(pos.ini:21562 pos.fin:25384)accn|OU579529
# spike(pos.ini:21562 pos.fin:25384)accn|OU568167
# spike(pos.ini:21562 pos.fin:25384)accn|OU566244
# spike(pos.ini:21562 pos.fin:25384)accn|OU579593
# spike(pos.ini:21562 pos.fin:25384)accn|OU570030
# spike(pos.ini:21562 pos.fin:25384)accn|OU566267
# spike(pos.ini:21562 pos.fin:25384)accn|OU577655
# spike(pos.ini:21562 pos.fin:25384)accn|OU566380
# spike(pos.ini:21562 pos.fin:25384)accn|OU577753
# spike(pos.ini:21562 pos.fin:25384)accn|OU572118
# spike(pos.ini:21562 pos.fin:25384)accn|OU566451
# spike(pos.ini:21562 pos.fin:25384)accn|OU576131
# spike(pos.ini:21562 pos.fin:25384)accn|OU578063
# spike(pos.ini:21562 pos.fin:25384)accn|OU578188
# spike(pos.ini:21562 pos.fin:25384)accn|MZ861875
# spike(pos.ini:21562 pos.fin:25384)accn|OU578199
# spike(pos.ini:21562 pos.fin:25384)accn|OU578244
# spike(pos.ini:21562 pos.fin:25384)accn|OU578262
# spike(pos.ini:21562 pos.fin:25384)accn|MZ741199
# spike(pos.ini:21562 pos.fin:25384)accn|OU456208
# spike(pos.ini:21562 pos.fin:25384)accn|OK034113
# spike(pos.ini:21562 pos.fin:25384)accn|OK034246
# spike(pos.ini:21562 pos.fin:25384)accn|OU595017
# spike(pos.ini:21562 pos.fin:25384)accn|OU592959
# spike(pos.ini:21562 pos.fin:25384)accn|OU585869
# spike(pos.ini:21562 pos.fin:25384)accn|OU591640
# spike(pos.ini:21562 pos.fin:25384)accn|OU592363
# spike(pos.ini:21562 pos.fin:25384)accn|OK176546
# spike(pos.ini:21562 pos.fin:25384)accn|OK180092
# spike(pos.ini:21562 pos.fin:25384)accn|OK201043
# spike(pos.ini:21562 pos.fin:25384)accn|OK240817
# spike(pos.ini:21562 pos.fin:25384)accn|OK276644
# spike(pos.ini:21562 pos.fin:25384)accn|OU665873
# spike(pos.ini:21562 pos.fin:25384)accn|OK278209
# spike(pos.ini:21562 pos.fin:25384)accn|OU668526
# spike(pos.ini:21562 pos.fin:25384)accn|OK283721
# spike(pos.ini:21562 pos.fin:25384)accn|OK279028
# spike(pos.ini:21562 pos.fin:25384)accn|OU703304
# spike(pos.ini:21562 pos.fin:25384)accn|OU707468
# spike(pos.ini:21562 pos.fin:25384)accn|OU707508
# spike(pos.ini:21562 pos.fin:25384)accn|OU707563
# spike(pos.ini:21562 pos.fin:25384)accn|OU707751
# spike(pos.ini:21562 pos.fin:25384)accn|OU701594
# spike(pos.ini:21562 pos.fin:25384)accn|OU706041
# spike(pos.ini:21562 pos.fin:25384)accn|OU706055
# spike(pos.ini:21562 pos.fin:25384)accn|OU706063
# number of sequences in file  /home/m_souza/tcc/dataset/dataset_agua/sequencias_treinamento.fasta  =  5797

# %%
# # Open the alignment file as a MultipleSeqAlignment object 

# idlst = []
# sequences = []
# labels = []
# ctr = 0

# # Abra o arquivo de alinhamento e leia as sequências como objetos SeqRecord
# with open(fname, "r") as aln:
#     for seq_record in SeqIO.parse(aln, "fasta"):
#         sequences.append(seq_record)

# Nseqs = len(sequences)
# print("Número de sequências no alinhamento:", Nseqs)


# Open the alignment file as a MultipleSeqAlignment object 

with open(fname,"r") as aln: 
    alignment = AlignIO.read(aln,"fasta")

idlst=[]
sequences=[]
labels=[]
ctr=0
for strain in alignment:
#     print(strain.description)
    
    if strain.description not in idlst:
        idlst.append(strain.description)
    else:
        print(ctr, "duplicated description ",strain.description)
        
    labels.append("strain"+str(ctr)) # strain.description # o id só saia cortado e acahava depois que itnha sequncias repetidas
    sequences.append(alignment[ctr].seq)
    ctr+=1
    
Nseqs=len(sequences)
print("number of seqs in the alignment", Nseqs)
# Out:
# number of seqs in the alignment 5797

# %%
def nucleotideToCodon(tripleNucleotides):
    
    codonNumber = 0 # 0 to 63

    for p in range(3):
        if ("AGCTagct".find(tripleNucleotides[p]) != -1):
            codonNumber += base[p] * nucleotides[tripleNucleotides[p]]
        else:
            codonNumber = 64 if tripleNucleotides[p] == "-" else 65
            break
    
    #debb
#     if codonNumber in stopnmb:
#         print("codon ",codonNumber," found in sequence")
        
    return codonNumber

def nucleotideSequenceToCodons(sequence):
    tripleNucleotidesList = [sequence[i:i + 3] for i in range(0, len(sequence), 3)]
    return list(map(lambda triple: nucleotideToCodon(triple), tripleNucleotidesList))

# %%
# transformando sequencias de nucleotideos a codons 

print(len(sequences[0]))

sequenceLength = len(sequences[0])

if (sequenceLength % 3 != 0):
    print(sequenceLength)
    print("ERRO: tamanho não Múltiplo de 3")
    exit(1)
elif (next((True for seq in sequences if len(seq) > sequenceLength), False)):
    print("ERRO: as sequências não tem o mesmo tamanho")
else:
    nprm = int(sequenceLength / 3) # comprimento das seqs em codons

print(f"O dataset contem {Nseqs} sequências com {nprm} resíduos.")
print("Transformação das sequências de nucleotídeos em sequências númericas de códons.")

start = time.time()

codonSequences = list(map(lambda seq: nucleotideSequenceToCodons(seq), sequences))

print(f"Transformação concluída em {(time.time() - start) / 60} minutos");
# Out:
# 3822
# O dataset contem 5797 sequências com 1274 resíduos.
# Transformação das sequências de nucleotídeos em sequências númericas de códons.
# Transformação concluída em 0.330822229385376 minutos

# %%
print(np.min(codonSequences[0]),np.max(codonSequences[0]))
# Out:
# 0 63

# %%
# filtrando sequências com stop codons TGA,TAG,TAA
filtered_codonSeqs=[]
filtered_SeqID=[]
ctr=0
laststop=0
for seq in codonSequences:
    stopfound=False
    for stp in stopnmb:
        stoppos=np.where(np.array(seq)==stp)[0]
        if len(stoppos)>0:
            if len(stoppos)==1 and (stoppos[0]==nprm-1): # last stop found
                laststop=1
            else:
                print(" stop codon ",stp," found in frame in sequence ",alignment[ctr].id," at positions ",stoppos[0])  
                stopfound=True
                break
            
    if not stopfound:
        filtered_codonSeqs.append(seq[:-laststop]) #excluindo o ultimo stop se existir
        filtered_SeqID.append(alignment[ctr].id)
   
    ctr+=1

# %%
print(len(codonSequences[0]),len(filtered_codonSeqs[0]))
# Out:
# 1274 1273

# %%
# transformando o dataset em matriz de codons

cdnseq=np.array(filtered_codonSeqs)
print(cdnseq.shape)

# contando número de codons distintos por coluna (sítios)
cdns=[]
V=[]

for pos in range(cdnseq.shape[1]):
    cdnlst=list(set(list(cdnseq[:,pos])))
    V.append(len(cdnlst))
    cdns.append(cdnlst)
# Out:
# (5797, 1273)

# %%
V=np.array(V)

# ordeno as colunas de maior a menor variabilidade
# Idx=np.argsort(-V)
# print("Idx",Idx)
# print("V[Idx]",V[Idx])

# seleciono as colunas com variabilidade > 1
var_sites=np.argwhere(V>1)
Var_Sites=[]
for site in var_sites:
    Var_Sites.append(int(site))
    
var=V[var_sites]

# print("var",var)

IDsz=len(var_sites)
print("ID size ",IDsz)

# gero os IDs com os codons de cada seq (lista de listas)

ID=cdnseq[:,var_sites].tolist() # vetor coluna de IDs como vetores linha

strID=[] # lista de IDs como strings
for lst in ID:
    strID.append(str(lst).replace('[','').replace(']',''))
# Out:
# /tmp/ipykernel_29477/3874165719.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   Var_Sites.append(int(site))
# ID size  838

# %%
# check 
print(len(strID),"=",Nseqs)
# Out:
# 5797 = 5797

# %%
# ALTEREI

# gero a lista de string IDs das classes primárias - unique
start=time.time()
p=[] # vetor com string das IDs das classes primárias
pvec=[]

for Id in strID:
    p.append(Id)
    pvec.append(np.array(p[-1].split(", ")))

# for Id in strID:
#     if Id not in p:
#         p.append(Id)
#         pvec.append(np.array(p[-1].split(", ")))

print("check string and vector of chars")
print(p[0])
print(pvec[0])

# numero de classes primarias
P=len(p)
print("there were found ",P," primary classes in the dataset with ",Nseqs," sequences in ",time.time()-start," segundos")
# Out:
# check string and vector of chars
# 63, 47, 60, 61, 40, 44, 59, 7, 33, 55, 31, 47, 8, 10, 4, 11, 42, 43, 24, 50, 11, 3, 59, 62, 8, 39, 31, 50, 62, 58, 56, 35, 33, 18, 61, 62, 60, 43, 62, 63, 58, 3, 31, 11, 53, 62, 35, 27, 12, 35, 30, 59, 21, 10, 3, 23, 11, 1, 5, 63, 19, 2, 43, 30, 44, 40, 63, 3, 19, 23, 31, 51, 63, 27, 58, 11, 17, 1, 59, 2, 12, 12, 4, 22, 53, 15, 63, 23, 11, 11, 60, 19, 57, 1, 10, 33, 58, 44, 47, 15, 31, 3, 2, 27, 11, 3, 31, 31, 15, 0, 30, 55, 16, 63, 32, 63, 55, 3, 19, 40, 63, 61, 23, 31, 51, 50, 34, 0, 2, 2, 0, 7, 53, 13, 16, 7, 17, 62, 4, 31, 51, 59, 7, 25, 3, 3, 54, 11, 63, 16, 51, 30, 59, 33, 43, 63, 47, 13, 18, 47, 16, 20, 0, 33, 23, 3, 62, 5, 16, 63, 29, 63, 1, 3, 15, 19, 23, 51, 63, 0, 12, 59, 1, 9, 43, 15, 3, 60, 29, 39, 19, 46, 43, 33, 57, 27, 28, 19, 61, 40, 12, 23, 15, 2, 14, 11, 5, 63, 32, 11, 60, 47, 27, 60, 35, 4, 7, 51, 61, 11, 43, 23, 19, 59, 59, 56, 23, 53, 8, 27, 23, 27, 24, 27, 51, 51, 29, 23, 51, 47, 32, 43, 5, 11, 63, 44, 60, 0, 51, 3, 16, 3, 20, 10, 15, 8, 19, 27, 28, 18, 55, 24, 47, 18, 43, 46, 56, 16, 8, 1, 55, 9, 61, 0, 58, 62, 11, 28, 16, 0, 20, 14, 51, 32, 11, 59, 2, 63, 4, 30, 32, 40, 8, 16, 59, 15, 31, 4, 43, 3, 15, 8, 43, 63, 23, 16, 63, 2, 26, 10, 24, 31, 27, 53, 2, 5, 1, 6, 2, 31, 27, 59, 30, 44, 51, 3, 56, 58, 11, 29, 43, 0, 19, 54, 63, 11, 3, 30, 24, 56, 28, 15, 4, 23, 19, 16, 30, 4, 27, 21, 32, 11, 20, 1, 15, 27, 19, 51, 3, 40, 19, 19, 63, 8, 22, 54, 59, 2, 3, 47, 19, 59, 1, 31, 23, 23, 51, 3, 50, 45, 51, 4, 61, 63, 5, 1, 59, 3, 46, 0, 43, 63, 17, 4, 15, 56, 11, 16, 14, 51, 33, 26, 23, 6, 8, 43, 55, 3, 23, 31, 16, 23, 63, 3, 50, 63, 56, 51, 23, 62, 32, 42, 11, 3, 23, 31, 23, 50, 32, 40, 50, 63, 16, 47, 44, 35, 24, 40, 24, 11, 31, 55, 20, 43, 0, 2, 3, 62, 62, 8, 22, 31, 11, 17, 2, 0, 1, 63, 45, 43, 62, 63, 22, 18, 15, 27, 11, 11, 19, 27, 30, 19, 33, 17, 15, 18, 8, 30, 7, 31, 3, 11, 31, 47, 51, 33, 19, 31, 2, 8, 31, 27, 15, 24, 32, 51, 59, 8, 24, 22, 55, 60, 21, 27, 35, 30, 2, 51, 17, 12, 42, 15, 23, 24, 23, 54, 27, 7, 51, 33, 11, 33, 11, 3, 59, 43, 37, 37, 24, 39, 7, 28, 27, 7, 32, 58, 14, 26, 56, 24, 16, 31, 27, 50, 59, 3, 59, 15, 42, 8, 3, 7, 10, 44, 40, 29, 13, 10, 8, 23, 22, 8, 2, 39, 60, 11, 20, 27, 31, 32, 10, 32, 63, 24, 32, 30, 0, 8, 40, 15, 0, 19, 63, 23, 23, 40, 19, 40, 40, 6, 1, 5, 56, 15, 16, 19, 44, 47, 2, 0, 29, 47, 24, 19, 27, 14, 32, 51, 19, 54, 47, 23, 19, 15, 27, 27, 46, 15, 24, 1, 2, 22, 47, 11, 31, 46, 15, 27, 24, 45, 25, 8, 59, 24, 27, 24, 27, 23, 20, 31, 8, 33, 3, 31, 46, 2, 26, 7, 15, 22, 15, 18, 56, 47, 59, 58, 8, 24, 47, 20, 32, 19, 30, 2, 2, 9, 0, 47, 6, 58, 3, 63, 23, 24, 15, 56, 7, 60, 14, 56, 39, 18, 0, 17, 16, 29, 5, 61, 47, 33, 51, 11, 32, 14, 27, 47, 27, 13, 28, 20, 56, 20, 1, 22, 35, 47, 58, 43, 56, 24, 43, 35, 62, 61, 29, 43, 24, 1, 2, 62, 8, 27, 43, 26, 35, 19, 20, 24, 34, 63, 30, 22, 34, 32, 51, 14, 15, 8, 18, 2, 8, 29, 59, 23, 31, 12, 15, 30, 2, 8, 19, 43, 43, 16, 18, 56, 62, 17, 17, 60, 19, 51, 3, 35, 40, 19, 19, 23, 18, 14, 22, 27, 56, 31, 28, 2, 15, 32, 0, 16, 15, 18, 3, 17, 1, 3, 3, 16, 14, 46, 32, 16, 47, 17, 33, 0, 53, 50, 23, 63, 22, 15, 26, 28, 13, 29, 8, 15, 13, 47, 54, 55, 13, 10, 7, 54, 55, 46, 1, 22, 55, 55, 59, 55, 58, 0, 16, 18, 59, 17, 40, 29, 46, 0, 20, 30, 0, 60
# ['63' '47' '60' '61' '40' '44' '59' '7' '33' '55' '31' '47' '8' '10' '4'
#  '11' '42' '43' '24' '50' '11' '3' '59' '62' '8' '39' '31' '50' '62' '58'
#  '56' '35' '33' '18' '61' '62' '60' '43' '62' '63' '58' '3' '31' '11' '53'
#  '62' '35' '27' '12' '35' '30' '59' '21' '10' '3' '23' '11' '1' '5' '63'
#  '19' '2' '43' '30' '44' '40' '63' '3' '19' '23' '31' '51' '63' '27' '58'
#  '11' '17' '1' '59' '2' '12' '12' '4' '22' '53' '15' '63' '23' '11' '11'
#  '60' '19' '57' '1' '10' '33' '58' '44' '47' '15' '31' '3' '2' '27' '11'
#  '3' '31' '31' '15' '0' '30' '55' '16' '63' '32' '63' '55' '3' '19' '40'
#  '63' '61' '23' '31' '51' '50' '34' '0' '2' '2' '0' '7' '53' '13' '16' '7'
#  '17' '62' '4' '31' '51' '59' '7' '25' '3' '3' '54' '11' '63' '16' '51'
#  '30' '59' '33' '43' '63' '47' '13' '18' '47' '16' '20' '0' '33' '23' '3'
#  '62' '5' '16' '63' '29' '63' '1' '3' '15' '19' '23' '51' '63' '0' '12'
#  '59' '1' '9' '43' '15' '3' '60' '29' '39' '19' '46' '43' '33' '57' '27'
#  '28' '19' '61' '40' '12' '23' '15' '2' '14' '11' '5' '63' '32' '11' '60'
#  '47' '27' '60' '35' '4' '7' '51' '61' '11' '43' '23' '19' '59' '59' '56'
#  '23' '53' '8' '27' '23' '27' '24' '27' '51' '51' '29' '23' '51' '47' '32'
#  '43' '5' '11' '63' '44' '60' '0' '51' '3' '16' '3' '20' '10' '15' '8'
#  '19' '27' '28' '18' '55' '24' '47' '18' '43' '46' '56' '16' '8' '1' '55'
#  '9' '61' '0' '58' '62' '11' '28' '16' '0' '20' '14' '51' '32' '11' '59'
#  '2' '63' '4' '30' '32' '40' '8' '16' '59' '15' '31' '4' '43' '3' '15' '8'
#  '43' '63' '23' '16' '63' '2' '26' '10' '24' '31' '27' '53' '2' '5' '1'
#  '6' '2' '31' '27' '59' '30' '44' '51' '3' '56' '58' '11' '29' '43' '0'
#  '19' '54' '63' '11' '3' '30' '24' '56' '28' '15' '4' '23' '19' '16' '30'
#  '4' '27' '21' '32' '11' '20' '1' '15' '27' '19' '51' '3' '40' '19' '19'
#  '63' '8' '22' '54' '59' '2' '3' '47' '19' '59' '1' '31' '23' '23' '51'
#  '3' '50' '45' '51' '4' '61' '63' '5' '1' '59' '3' '46' '0' '43' '63' '17'
#  '4' '15' '56' '11' '16' '14' '51' '33' '26' '23' '6' '8' '43' '55' '3'
#  '23' '31' '16' '23' '63' '3' '50' '63' '56' '51' '23' '62' '32' '42' '11'
#  '3' '23' '31' '23' '50' '32' '40' '50' '63' '16' '47' '44' '35' '24' '40'
#  '24' '11' '31' '55' '20' '43' '0' '2' '3' '62' '62' '8' '22' '31' '11'
#  '17' '2' '0' '1' '63' '45' '43' '62' '63' '22' '18' '15' '27' '11' '11'
#  '19' '27' '30' '19' '33' '17' '15' '18' '8' '30' '7' '31' '3' '11' '31'
#  '47' '51' '33' '19' '31' '2' '8' '31' '27' '15' '24' '32' '51' '59' '8'
#  '24' '22' '55' '60' '21' '27' '35' '30' '2' '51' '17' '12' '42' '15' '23'
#  '24' '23' '54' '27' '7' '51' '33' '11' '33' '11' '3' '59' '43' '37' '37'
#  '24' '39' '7' '28' '27' '7' '32' '58' '14' '26' '56' '24' '16' '31' '27'
#  '50' '59' '3' '59' '15' '42' '8' '3' '7' '10' '44' '40' '29' '13' '10'
#  '8' '23' '22' '8' '2' '39' '60' '11' '20' '27' '31' '32' '10' '32' '63'
#  '24' '32' '30' '0' '8' '40' '15' '0' '19' '63' '23' '23' '40' '19' '40'
#  '40' '6' '1' '5' '56' '15' '16' '19' '44' '47' '2' '0' '29' '47' '24'
#  '19' '27' '14' '32' '51' '19' '54' '47' '23' '19' '15' '27' '27' '46'
#  '15' '24' '1' '2' '22' '47' '11' '31' '46' '15' '27' '24' '45' '25' '8'
#  '59' '24' '27' '24' '27' '23' '20' '31' '8' '33' '3' '31' '46' '2' '26'
#  '7' '15' '22' '15' '18' '56' '47' '59' '58' '8' '24' '47' '20' '32' '19'
#  '30' '2' '2' '9' '0' '47' '6' '58' '3' '63' '23' '24' '15' '56' '7' '60'
#  '14' '56' '39' '18' '0' '17' '16' '29' '5' '61' '47' '33' '51' '11' '32'
#  '14' '27' '47' '27' '13' '28' '20' '56' '20' '1' '22' '35' '47' '58' '43'
#  '56' '24' '43' '35' '62' '61' '29' '43' '24' '1' '2' '62' '8' '27' '43'
#  '26' '35' '19' '20' '24' '34' '63' '30' '22' '34' '32' '51' '14' '15' '8'
#  '18' '2' '8' '29' '59' '23' '31' '12' '15' '30' '2' '8' '19' '43' '43'
#  '16' '18' '56' '62' '17' '17' '60' '19' '51' '3' '35' '40' '19' '19' '23'
#  '18' '14' '22' '27' '56' '31' '28' '2' '15' '32' '0' '16' '15' '18' '3'
#  '17' '1' '3' '3' '16' '14' '46' '32' '16' '47' '17' '33' '0' '53' '50'
#  '23' '63' '22' '15' '26' '28' '13' '29' '8' '15' '13' '47' '54' '55' '13'
#  '10' '7' '54' '55' '46' '1' '22' '55' '55' '59' '55' '58' '0' '16' '18'
#  '59' '17' '40' '29' '46' '0' '20' '30' '0' '60']
# there were found  5797  primary classes in the dataset with  5797  sequences in  0.3977212905883789  segundos

# %%
# salvando os códigos de cada classe primária para agrupamento com CLOPE - ## Entender e colocar na referência ##

# # print to test 
# print(p[:5])

# with open(r'SARS2.txt', 'w') as fp:
#     for item in p:
#         fp.write("{}\n".format(item))

# %%
# check
print(len(pvec),"=",P)
# Out:
# 5797 = 5797

# %%
# etiqueto as sequencias com a classe primária correspondente e conto o numero de sequencias em cada classe primária
pClass=[]
for Id in strID:
    pClass.append(p.index(Id))

# %%
# criando datafram com o Gene Variant File  

UniqueSeqs=[]
UniqueLabs=[]
UniqueClass=[]

unq, idxunq = np.unique(pClass, return_index=True)

# print(idxunq)

for i, idx in enumerate(idxunq):
    UniqueSeqs.append(sequences[idx])
    UniqueLabs.append(filtered_SeqID[idx])
    UniqueClass.append(unq[i])
#     print(">"+UniqueLabs[-1])
#     print(UniqueSeqs[-1])
#     print(UniqueClass[-1])

gvf = pd.DataFrame({'class':pd.Series(UniqueClass),'accession':pd.Series(UniqueLabs),'fasta_aln':pd.Series(UniqueSeqs)}) #,index=0)

gvf
# Out:
#       class            accession  \
# 0         0  spike(pos.ini:21562
# 1         3  spike(pos.ini:21562
# 2        17  spike(pos.ini:21562
# 3        22  spike(pos.ini:21562
# 4        28  spike(pos.ini:21562
# ...     ...                  ...
# 1633   5783  spike(pos.ini:21562
# 1634   5786  spike(pos.ini:21562
# 1635   5788  spike(pos.ini:21562
# 1636   5791  spike(pos.ini:21562
# 1637   5794  spike(pos.ini:21562
#
#                                               fasta_aln
# 0     (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 1     (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 2     (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 3     (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 4     (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# ...                                                 ...
# 1633  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 1634  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 1635  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 1636  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 1637  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
#
# [1638 rows x 3 columns]

# %%
# histograma de frequencia das classes primárias - depende do ordenamento
plt.hist(pClass,P)
plt.show()

# %%
class Model:
    def __init__(self, name = "", rep=2, nmbofclasses=0, nmbofclusters=0):
        
        self.name = name
        self.ListOfVarSites =[] #CBUC
        self.NmbOfClasses = nmbofclasses # CBUC
        self.CodeOfClass = [] # CBUC
        self.GroundTruth = [] # ANNOTATION
        self.NmbOfClusters =  nmbofclusters # CLOPE 
        self.TheClusterOfClass = {} # CLOPE
        self.TheSpeciesOfCluster = {} # CLOPE + ANNOTATION
        self.repulsion = rep # CLOPE 
        self.MinClusterAcc = 0 #  MODEL
        self.Accuracy = 0 # MODEL
        self.ConfusionMatrix =[] # MODEL 
        self.Accession = [] # DATA - GVF -> Tipo de Arquivo Gene Variant File - Importante Variant Call Format VCF

# %%
model = Model("SARS2-spike",nmbofclasses=P)
model.ListOfVarSites = Var_Sites #CBUC

# %% [markdown]
# # FASE 2 - ANÁLISE QUANTITATIVA
#
# ## AGRUPAMENTO
# ## ANOTAÇÃO DAS CLASSES PRIMÁRIAS
# ## CÁLCULO DA ACURÁCIA

# %%
# classes e funções da clusterização com CLOPE

class Cluster:

    def __init__(self, history_count):
       # Histórico do número de transações em clusters
        self.history_count_transact = [0] * history_count
        # Área do histograma
        self.area = 0.0
        # A altura do histograma (no sentido de H=S/W). Esse valor não é calculado explicitamente em nenhum lugar.
         # Armazenado na classe para completar a descrição da classe e nada mais.
        self.height = 0.0
        # Largura do histograma (em termos de número de elementos)
        self.width = 0.0
        # Gradiente (no sentido de G=H/W). Esse valor não é calculado explicitamente em nenhum lugar. 
        # Armazenado na classe para completar a descrição da classe e nada mais.
        self.gradient = 0.0
        # Número de transações
        self.count_transactions = 0
        # Histograma
        self.histogram = {}

    '''
    Adicione uma transação ao cluster. Iterar sobre todos os elementos do histograma, completar o histograma
     parâmetros de entrada:
     transação -- fatia com objetos (transação)
    '''
    def add_transaction(self, transaction):
        # Iterar por todos os elementos do histograma um por um e adicionar à coluna correspondente do histograma. 
        # Se não há elemento em questão, então adicione uma nova coluna ao histograma
        for item in transaction:
            if not (item in self.histogram):
                self.histogram[item] = 1 # adiciona novo elelento ao histograma
            else:
                self.histogram[item] += 1 # incrementa o numero do elemento existente no histograma
        # Calculamos a área total do histograma no sentido de CLOPE (número de transações)
        self.area += float(len(transaction))
        # Calcular a largura do histograma (o número de objetos diferentes)
        self.width = float(len(self.histogram))
        # incrementa o número de transações no cluster
        self.count_transactions += 1

    '''
    Excluir transação do cluster. Passamos por todos os elementos do histograma, removemos todos os elementos da transação de
     histogramas
    
     parâmetros de entrada:
     transação -- fatia com objetos (transação)
     valores retornados:
     valor gradiente G (transação) # sem sentido 
    
     Dentro da classe, não há rastreamento de quais transações são adicionadas, quais são excluídas, portanto, se em
     o processo de modificação excluirá uma transação que não foi adicionada ao cluster correspondente, o algoritmo
     vai dar resultado errado    
     '''
    
    def remove_transaction(self, transaction):
            for item in transaction:
                if self.histogram[item] > 0: # new
                    self.histogram[item] -=1 # new
                if self.histogram[item] == 0:
                    del self.histogram[item]
            self.area -= float(len(transaction))
            self.width = float(len(self.histogram))
            self.count_transactions -= 1
            return # self.gradient # rare 


class CLOPE:

    def __init__(self, print_step=1000, random_seed=None): 
        
        if random_seed is not None:
            self.random_seed = random_seed
        else:
            self.random_seed = random.randint(0, 65536 + 1)
        
        # Lista de clusters
        self.clusters = {}  # CCluster
        # Números de clusters de ruído
        # Este objeto é necessário para não levar em consideração aqueles objetos que foram classificados como ruído
        self.noise_clusters = {}
        # Número de transações adicionadas
        self.count_transactions = 0
        # Número da iteração
        self.iteration = 0
        # inicializa dicionário: número da transação/número do cluster
        self.transaction = {}
        # Número máximo do cluster
        self.max_cluster_number = 0
        self.print_step = print_step

    '''
    A mudança de meta que a função objetivo receberá ao adicionar uma transação ao cluster clusterNumber é calculada.
     O cluster que entrega o valor máximo da função será o cluster desejado (ao qual se deve adicionar a transação)
     parâmetros de entrada:
     transação -- transação (lista de objetos)
     clusterNumber -- número do cluster cujo incremento está sendo calculado
     r -- repulsão no sentido de CLOPE
     valor retornado:
     Retorna o valor de alteração da função objetivo quando uma transação é adicionada ao cluster clusterNumber
    '''
    def get_delta(self, transaction, cluster_number, r):
        
        old_area = self.clusters[cluster_number].area
        old_width = self.clusters[cluster_number].width
        nmb_trans = self.clusters[cluster_number].count_transactions
        
        area = old_area + len(transaction) # calcula a área adicionando os objetos da transação
                                                                    # em análise
        # cálculo da largura do cluster
        width = old_width 
        for item in transaction:
            if not (item in self.clusters[cluster_number].histogram): # histogram tem a lista de objetos no cluster
                width += 1
        
        # calcula delta (variação da função objetivo com a adição da transação ao cluster cluster_number)
        new_delta_value = 0
        if width != 0:
            new_delta_value = area * (nmb_trans + 1) / (width ** r)
            
        # calcula o valor de delta sem a transação
        if old_width != 0:
            old_delta_value = old_area * nmb_trans / (old_width ** r)
        else:
            old_delta_value = 0
            
        return new_delta_value - old_delta_value

    '''
    Função de remoção de ruído. Todos os clusters maiores que o limite permanecem ativos.
     parâmetros de entrada:
     limite -- nível de ruído do cluster
    '''
    def noise_reduction(self, limit):
        # Remova todos os clusters vazios e barulhentos
        new_clusters = {}
        for item in self.clusters:
            if self.clusters[item].count_transactions > limit:# se o cluster é maior que o limite permanece na lista de clusters ativos
                new_clusters[item] = self.clusters[item]
            else: # clusters pequenos são considerados ruidosos e saem da lista de clusters ativo - 
                  # passam para alista de clusters com ruido
                self.noise_clusters[item] = True
        self.clusters = new_clusters

    '''
    Cálculo da função objetivo para todos os clusters já formados
     Usado ao modificar clusters ou inicializá-los
     parâmetros de entrada:
     r -- número real denotando repulsão de cluster no sentido de CLOPE
     valor retornado:
     Retorna o valor da função objetivo
    '''
    def get_goal_function(self, r):
        measure = 0.0
        # Percorremos todos os clusters e para cada um calculamos seu peso. 
        # Todos os pesos são resumidos em uma métrica comum
        for item in self.clusters:
            if item.width == 0:
                # print "test"
                pass
            else:
                # # Tentando encontrar uma métrica diferente
                # measure += (r ** 2 * math.log(item.Area ** (1 / r) / item.Width) ** 2) *
                # item.CountTransactions / self.CountTransactions
                measure += item.area / (item.width ** r) * item.count_transactions 
        return measure / self.count_transactions

    '''
     Adicionando uma nova transação
     Estamos tentando redistribuir a transação com o número de id em outra classe para que a função de custo tenha
     valor máximo
     parâmetros de entrada:
     transação -- transação (fatia com objetos)
     id -- número da transação
     repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
     isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
     parâmetro retornado:
     Retorna o número do cluster ao qual a transação atual foi adicionada
    '''
    def move_transaction(self, transaction, id, repulsion=2, max_count_clusters=None):
        
        r = repulsion
        max_value = None
        max_value_index = None
        self.count_transactions += 1
        
        # Estamos procurando um cluster no qual o valor máximo da mudança na função objetivo seja alcançado
        for cluster_number in self.clusters:
            delta = self.get_delta(transaction, cluster_number, r)
            if (delta > 0 or max_count_clusters is not None) and (max_value is None or delta > max_value):
                max_value_index = cluster_number
                max_value = delta

        # Adicione uma transação a um novo cluster e veja o resultado - registre o cluster com maior valor
        if max_count_clusters is None or len(self.clusters) < max_count_clusters:
            self.clusters[self.max_cluster_number] = Cluster(self.count_transactions)
            if max_value is None or self.get_delta(transaction, self.max_cluster_number, r) > max_value:
                max_value_index = self.max_cluster_number
                self.max_cluster_number += 1
            else:
                del self.clusters[self.max_cluster_number]

        # Lembramos em qual cluster está a transação atual
        self.transaction[id] = max_value_index

        #Adicionando uma transação ao cluster necessário
        self.clusters[max_value_index].add_transaction(transaction)

        return max_value_index

    '''
    Cálculo de limiar de ruído adaptativo. O limite é limpo em relação à mediana dos tamanhos de cluster (incluindo
     transações). Pegue 3/4 da mediana
    '''
    def get_noise_limit(self, percentile=0.75):
        size_clusters = []
        for item in self.clusters:
            size_clusters.append(self.clusters[item].count_transactions)
        sorted(size_clusters)
        median_element = int(len(size_clusters) * percentile) + 1
        if len(size_clusters) < 5:
            limit = 10
        else:
            limit = size_clusters[median_element]
        return limit

    '''
    Inicialização do cluster
    parâmetros de entrada:
    dados -- fatia com transações
    isPrint -- se deve imprimir informações de progresso (0 -- não é necessário, se > 0 -- imprimir a cada isPrint time)
    repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
    isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
    isNoiseReduction -- redução de ruído (limiar corresponde ao número de elementos no cluster no qual ele é destruído).
                        Se isNoiseReduction == -1, então o limite é selecionado de forma adaptativa (tudo que for maior que a mediana
                        restos)
    '''
    def init_clusters(self, data, repulsion=2, is_noise_reduction=-1, noise_median_threshold=0.75,
                      max_count_clusters=None):
        index = 0
        keys = sorted(data.keys())
        np.random.seed(self.random_seed)
        np.random.shuffle(keys)
        for item in keys:
            self.move_transaction(data[item], item, repulsion, max_count_clusters)
            index += 1
            if self.print_step > 0 and index % self.print_step == 0:
                print("ITERAÇÃO: ", self.iteration, ". NÚMERO DA ETAPA", index, ". NÚMERO DE CLUSTERS: ", len(self.clusters))
                pass

        # Obtendo o limite de ruído ideal
        if is_noise_reduction < 0:
            is_noise_reduction = self.get_noise_limit(noise_median_threshold)
        # Remova todos os clusters de ruído 
        # (após a inicialização, não há classes vazias, portanto, o sinal é estritamente maior)
        if is_noise_reduction > 0:
            self.noise_reduction(is_noise_reduction)

        self.iteration = 1

    '''
    Execução do algoritmo. Dando o próximo passo
    parâmetros de entrada:
    dados -- fatia com transações
    isPrint -- se deve imprimir informações de progresso (0 -- não é necessário, se > 0 -- imprimir a cada isPrint time)
    repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
    isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
    isNoiseReduction -- redução de ruído (limiar corresponde ao número de elementos no cluster no qual ele é destruído).
                        Se isNoiseReduction == -1, então o limite é selecionado de forma adaptativa (tudo que for maior que a mediana
                        restos)
    parâmetro retornado:
    Retorna o número de operações para transferir uma transação de cluster para cluster
    '''
    def next_step(self, data, repulsion=2, is_noise_reduction=-1, noise_median_threshold=0.75, max_count_clusters=None):

        # Remova todos os clusters vazios (ou ruído, se isNoiseReduction > 0)
        if is_noise_reduction < 0:
            is_noise_reduction = self.get_noise_limit(noise_median_threshold)
        self.noise_reduction(is_noise_reduction)

        index = 0
        # O número de transações que foram transferidas
        moves = 0
        keys = sorted(data.keys())
        np.random.seed(self.random_seed)
        np.random.shuffle(keys)
        for id in keys:
            # Nós olhamos onde esta transação está agora
            cluster_number = self.transaction[id]
            transaction = data[id]
            # Se a transação pertencer a um cluster de ruído, não tentaremos alterá-la
#             if cluster_number in self.noise_clusters:
#                 eps += 0
#             else:
            # Recuperar uma transação do cluster atual
            self.clusters[cluster_number].remove_transaction(transaction)
            # Consideramos a transação como recém-chegada e a adicionamos ao cluster onde o valor do destino
            # máximiza a função custo
            moves += int(self.move_transaction(transaction, id, repulsion, max_count_clusters) != cluster_number)
                
            index += 1
            if self.print_step is not None and self.print_step > 0 and index % self.print_step == 0:
#                 print("Итерация: ", self.iteration, ". Номер шага", index, ". Число кластеров: ", len(self.clusters))
#                 print("ITERAÇÃO: ", self.iteration, ". NÚMERO DA ETAPA", index, ". NÚMERO DE CLUSTERS: ", len(self.clusters))
                pass

        self.iteration += 1

        self.noise_reduction(is_noise_reduction)
        
        return moves

    '''
    Desenhamos um gráfico mostrando o número de transações em diferentes classes
    
    '''
    def print_history_count(self, repulsion, seed):
        pass

# %%
# funções que constroem a matriz de confusão e calculam o erro usando o ground truth 

def CompareResultAndAnnotation(accession, annot, clope, verbose=False):
    
    # pegamos a lista de genotipos distintos
    species=list(set(annot)) # colunas
    if verbose:
        print("list of genotypes in dataset:\n",species)# numeramos os genótipos segundo a ordem na lista
    species_nmb={} # dict 
    ctr=0
    for sp in species:
        species_nmb[sp]=ctr
        ctr+=1
    
    # calculamos o numero de transacoes de cada espécie (soma das colunas da matriz)
    colsum=np.zeros(len(species),dtype=int)
    for sp in annot:
        colsum[species_nmb[sp]]+=1
    if verbose:
        print("number of strain by genotype\n",colsum)
    
    # inicializa a matriz de confusão
    conf_matrix = np.zeros((clope.max_cluster_number,len(species)),dtype=int)
    # varre dict transaction {trans_id:cluster}
    for trans_id in range(len(clope.transaction)):
        cluster = clope.transaction[trans_id]
        conf_matrix[cluster,species_nmb[annot[trans_id]]]+=1
           
    # attributing most probable genotype to each cluster and eliminating empty clusters
    new_confmat=[]
    annotation={}
    for item in range(clope.max_cluster_number):
        if np.sum(conf_matrix[item])>0:
            new_confmat.append(conf_matrix[item])
            # anotando cada cluster com a especie mais provável
            sort=-np.sort(-conf_matrix[item])
            if sort[1]==sort[0]: # tem mais de um máximo
                annotation[accession[item]]="UNKNOWN"
            else:
                annotation[accession[item]]=species[np.argmax(conf_matrix[item])]
        
    return np.array(new_confmat), annotation

def GetClusteringError(confmat):
    
    # cálculo da métrica de erro relativo por cluster : numero de seqs - max
    acc=[]
    n=np.sum(confmat)
    tot_error=0
    for cluster in range(confmat.shape[0]):
        aux0 = np.sum(confmat[cluster])
        aux = aux0 - np.max(confmat[cluster])
        tot_error += aux
        if aux0>0:
            acc.append(1-aux/aux0)
        else: 
            acc.append(0)

    return np.array(acc), 1-tot_error/n

# %% [markdown]
# # acessando à anotação de cada classe primária

# %%
# ALTEREI

# Caminho do arquivo de anotações
arquivo_anotacoes = '/home/m_souza/tcc/dataset/dataset_agua/anotacoes.txt'

# Dicionário para armazenar as anotações
annot = {}

# Ler o arquivo de anotações
with open(arquivo_anotacoes, 'r') as anotacoes_file:
    for linha in anotacoes_file:
        # Dividir a linha usando a vírgula como separador
        partes = linha.strip().split(',')
        
        # Verificar se a linha tem o formato correto
        if len(partes) == 2:
            cabecalho, anotacao = partes
            annot[cabecalho] = anotacao
        else:
            print(f"A linha '{linha}' não possui o formato esperado.")

# Exibir o dicionário de anotações
print(annot)

# # GAMBEARRA   para pegar a anotação do genome detective QUE iNES MANDOU PARA MIM!

# annot={"SARS-CoV-2humanAUSGC-2512020":" International A_B Diversity",
# "SARS-CoV-2humanAUSQLD9352020":" International A_B Diversity",
# "SARS-CoV-2humanAUSVIC012020":" International A_B Diversity",
# "SARS-CoV-2humanAUSVIC962020":" International A_B Diversity",
# "SARS-CoV-2humanAUSVIC172020":" International A_B Diversity",
# "SARS-CoV-2humanBRASP02cc2020":" International A_B Diversity",
# "SARS-CoV-2humanBRAcv2021":" International A_B Diversity",
# "SARS-CoV-2humanBRARIO-RS":" International A_B Diversity",
# "SARS-CoV-2Homo":" International A_B Diversity",
# "SARS-CoV-2humanBRA30482021":" Gamma (P.1 20J)",
# "SARS-CoV-2humanBRA39182021":" Gamma (P.1 20J)",
# "SARS-CoV-2humanBRACD1739-P4202":" Gamma (P.1 20J)",
# "SARS-CoV-2humanBRAPR-HF1022021":" International A_B Diversity",
# "SARS-CoV-2humanBRARio-P12020":" International A_B Diversity",
# "SARS-CoV-2humanCHNFuyang":" International A_B Diversity",
# "SARS-CoV-2humanCHNYunnan-01202":" International A_B Diversity",
# "SARS-CoV-2humanCOLCali-012020":" International A_B Diversity",
# "SARS-CoV-2humanCZECzechiaMotol-0":" International A_B Diversity",
# "SARS-CoV-2humanCZECzechiaMotol-1":" International A_B Diversity",
# "SARS-CoV-2humanDNKDK-AHH12020":" International A_B Diversity",
# "nCoV-FIN-29-Jan-2020":" International A_B Diversity",
# "SARS-CoV-2humanFrance10027AA20":" International A_B Diversity",
# "SARS-CoV-2humanFrance40005BH20":" International A_B Diversity",
# "SARS-CoV-2humanDEUFFM52020":" International A_B Diversity",
# "SARS-CoV-2humanDEUBavPat12020":" International A_B Diversity",
# "SARS-CoV-2humanGRC35":" International A_B Diversity",
# "SARS-CoV-2humanGRC36":" International A_B Diversity",
# "SARS-CoV-2humanGUMGU-NHG-01202":" International A_B Diversity",
# "SARS-CoV-2humanHKG.85":" International A_B Diversity",
# "SARS-CoV-2humanIND509MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
# "SARS-CoV-2humanIND528MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
# "SARS-CoV-2humanIND565MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
# "SARS-CoV-2humanINDWuhan2021":" Delta (B.1.617.2 21A,21I,21J)",
# "SARS-CoV-2humanINDGBRC6482021":" International A_B Diversity",
# "SARS-CoV-2humanINDILS212020":" International A_B Diversity",
# "SARS-CoV-2humanINDhospital":" International A_B Diversity",
# "SARS-CoV-2humanIND510MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
# "SARS-CoV-2humanIND512MN908947.":" Delta (B.1.617.2 21A,21I,21J)",
# "SARS-CoV-2humanINDGBRC622020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC62020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC17a2020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC17b2020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC232020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC24a2020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC82020":" International A_B Diversity",
# "SARS-CoV-2humanIND1662020":" International A_B Diversity",
# "SARS-CoV-2humanINDAIIMS-Bhopal":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC12020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC122020":" International A_B Diversity",
# "SARS-CoV-2humanINDGBRC162020":" International A_B Diversity",
# "SARS-CoV-2humanIRNHGRC-2-21622":" International A_B Diversity",
# "SARS-CoV-2humanITATE.237004202":" International A_B Diversity",
# "SARS-CoV-2humanITAPango":" International A_B Diversity",
# "SARS-CoV-2humanITAPV-5314-21Fe":" International A_B Diversity",
# "SARS-CoV-2humanITAPA-IZSBM194-":" International A_B Diversity",
# "TKY10468":" International A_B Diversity",
# "hCoV-19JapanP4-82020":" International A_B Diversity",
# "SARS-CoV-2humanLBY77002020":" International A_B Diversity",
# "SARS-CoV-2humanMexicoSEARCH-10":" International A_B Diversity",
# "SARS-CoV-2humanNZL20VR07702020":" International A_B Diversity",
# "SARS-CoV-2humanPERPeru-102020":" International A_B Diversity",
# "SARS-CoV2humanUSAPR-CDC-S92020":" International A_B Diversity",
# "SARS-CoV-2humanZAFR030062020":" International A_B Diversity",
# "SNU01":" International A_B Diversity",
# "SARS-CoV-2humanESPValencia1420":" International A_B Diversity",
# "SARS-CoV-2humanESPHUD-66682640":" International A_B Diversity",
# "SARS-CoV-2humanSWE012020":" International A_B Diversity",
# "SARS-CoV-2humanTWNCGMH-CGU-032":" International A_B Diversity",
# "SARS-CoV-2humanTWNCGMH-CGU-022":" International A_B Diversity",
# "SARS-CoV-2humanTHASI200615-NT2":" International A_B Diversity",
# "SARS-CoV-2humanTHASI202620-NT2":" International A_B Diversity",
# "SARS-CoV-2humanTURERAGEM-00120":" International A_B Diversity",
# "SARS-CoV-2humanUSAIA-CDC-82002":" International A_B Diversity",
# "SARS-CoV-2humanUSAIN-CDC-72003":" International A_B Diversity",
# "USAMN1-MDH12020":" International A_B Diversity",
# "SARS-CoV-2humanUSAAZ-ASU292220":" International A_B Diversity",
# "SARS-CoV-2humanUSAVA-DCLS-0001":" International A_B Diversity",
# "SARS-CoV-2humanUSAWI-UW-269202":" International A_B Diversity",
# "SARS-CoV-2humanGBRRem2.5p13.52":" International A_B Diversity",
# "SARS-CoV-2humanGBRCVR-GLA-2202":" International A_B Diversity",
# "SARS-CoV-2humanVENBol47152021":" Gamma (P.1 20J)"}
# # annot=np.array(annot)

# print(annot)
# Out:
# {'spike(pos.ini:21562 pos.fin:25384)accn|MT628234': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628235': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628237': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MW053744': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628238': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628247': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628251': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628253': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628254': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628255': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628256': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628257': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628259': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628260': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628263': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628266': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628267': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628268': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628269': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628271': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT628272': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MW053804': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MW053821': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MW053849': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632495': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632496': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632500': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632501': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632502': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632506': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632514': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632515': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632518': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632526': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632531': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632534': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632535': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632538': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632539': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632542': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632543': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632544': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632545': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632546': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632550': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632548': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632551': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632552': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632555': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632556': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632554': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632557': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632558': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632559': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632560': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632561': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632562': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632563': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632564': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632567': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632569': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632570': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632572': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632573': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632574': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632575': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632576': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632577': 'A.1', 'spike(pos.ini:21562 pos.fin:25384)accn|MT632581': 'A.1 ...

# %%
# ALTEREI

# pegando as espécies virais anotadas
# species=list(set(annot.values()))
species = list(annot.values())
print(species)
# Out:
# ['A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1',  ...

# %%
def get_accession(new_accession, transactions):
    for j in range(len(transactions)):
#         print(new_accession,"=?",transactions[j][0].replace("/",""))
        if new_accession in transactions[j][0].replace("/",""):
            return transactions[j][0]
    return "unknown"

# %% [markdown]
# # random iterations:
# ## varying repulsion in a given search interval
# ## for each repulsion value:
# ### > finding clusters with different sorting of input
# ### > calculating minimum accuracies of clusters to control achievement of quality criteria
# ### > finishing random iterations  it check if repulsion satisfies the quality threshold:
# ### >> if OK exit the repulsion loop and build model data

# %%
# MAIN -----------------------------------------------------

# pegando a lista de accession
Acc = gvf['accession']
# tirando barras para match com annot
Accession0=[]
for acc in Acc:
    Accession0.append(acc.replace("/",""))
# print(Accession0[:3])

# pegando o groundthruth da anotação
GroundTruth0 = list(annot.values())
#GroundTruth0[:3]

# pegando os vetores de chars dos códigos das classes primárias como transações
InputData0 = pvec
nmb_trans=len(pvec)

print(f'QUEM É O PVEC: {len(pvec)}')

nmb_annot=len(GroundTruth0)
print('check: number of transactions = annotations: ',nmb_trans,'=',nmb_annot)

if nmb_trans!=nmb_annot:
    print("DATASET NOT FULLY OR WRONGLY ANNOTATED .....\nRESULTS MAY BE CONFUSING....")
    
noiseLimit = 0.0 # dummy

nRandIterations=50 #50
ClusterAccThres=1.00

print("Looking for optimal repulsion with ",nRandIterations,"random iterations and threshold of minimum cluster accuracy of ",ClusterAccThres)

optimum=False
minRep=2
maxRep=20

for repulsion in range(minRep,maxRep): #>= 11 da 1005 acc de clusters com 200 iteracoes randomicas

    print("repulsion", repulsion)
    
    cluster_acc=[]
    Accuracy=[]

    K=3000
    best_cluster_acc=0

    codes = InputData0
    GT = GroundTruth0
        
    for i in range(nRandIterations):

#         print("RANDOM ITERATION ",i+1)

        seed = None #150 <<<<<<<<<<<<<<<<<<<<<<<< ORDENAÇÂO ALEATORIA
        np.random.seed(seed)

    #     InputData=InputData0.copy()
        list_zipped = list(zip(Accession0,InputData0,GroundTruth0))
        np.random.shuffle(list_zipped)
        Accession, InputData, GroundTruth = zip(*list_zipped) #unzipping

        # print('first transactions:\n',InputData[:3])
        # print('first annotations:\n',GroundTruth[:3])

        trans_len=len(InputData[0])

        Data = {} # usamos um dicionario para os dados com as features indexadas por posição

        for trans_nmb in range(0, len(InputData)):
            Data[trans_nmb] = [''] * trans_len # inicializa a transação efetiva 
            fst=0 # for SARS2
            for index in range(fst, len(InputData[trans_nmb])):
                # adicionando a posição (coluna) da feature se não for missing & counting missings
                if InputData[trans_nmb][index] != '?':
                    Data[trans_nmb][index] = str(index) + ":"+InputData[trans_nmb][index].replace(" ","")  # add feature position

        clope = CLOPE(print_step=1000, random_seed=seed) 
        # Dados iniciais

        # Inicializamos o algoritmo
        clope.init_clusters(Data, repulsion, noiseLimit)

            # Nós iteramos
        while clope.next_step(Data, repulsion, noiseLimit ) > 0:
            clope.print_history_count(repulsion, seed)

#         print("CLOPE number of clusters ",clope.max_cluster_number)
        # print(clope.transaction.values())
        # print("annot",list(GroundTruth))

        # cálculo do erro da classificação

        confmat, map_species2cluster = CompareResultAndAnnotation(Accession, GroundTruth, clope)
#         print("non-empty cluster number ",len(confmat))

#         print("matriz de confusão - quantas seqs pertencem a cada genótipo (colunas) em cada cluster (linha):\n",confmat)
#         print(map_species_cluster)

        # cálculo da métrica de erro por cluster : numero de seqs - max
        acc_lst, tot_acc = GetClusteringError(confmat) 

        cluster_acc.append(acc_lst)
        Accuracy.append(tot_acc)

#         print("erro relativo por cluster: \n",100*acc_lst," %")
#         print("acurácia total",100*tot_acc," %")

        # condition to choose the best clustering during iterations
        if (np.min(cluster_acc[-1])>best_cluster_acc) and (len(confmat)<K): 
            best_cluster_acc=np.min(cluster_acc[-1])
            K=len(confmat)
            best_confmat=confmat
            best_annotation = map_species2cluster
            map_class2cluster = clope.transaction  
            codes = InputData
            GT = GroundTruth
            best_accession = Accession
            
        del clope

        # calculo a media e desvio padrão da minima acuracia nos clusters em cada iteração
        min_lst=[]
        for i in range(len(cluster_acc)):
            min_lst.append(np.min(cluster_acc[i]))
        #     print(np.min(cluster_acc[i]))
        mean_min_cluster_acc=np.mean(min_lst)
        std_min_cluster_acc=np.std(min_lst)
        min_min_cluster_acc=np.min(min_lst)
    #     print("mean minimum cluster accuracy ",mean_min_cluster_acc," standard deviation ",std_min_cluster_acc)
    #     print("minimum minimum cluster accuracy ",min_min_cluster_acc,"estimated minimum minimum cluster accuracy ", \
    #           mean_min_cluster_acc-2*std_min_cluster_acc)
    
    # controle de optimalidade
    if min_min_cluster_acc >= ClusterAccThres:
        print("satisfied optimality criteria")
        optimum=True
        break

if optimum:
    model.NmbOfClusters=K
    model.Accuracy=np.mean(Accuracy) # MODEL
    model.MinClusterAcc=min_min_cluster_acc # MODEL
    model.ConfusionMatrix = best_confmat # MODEL
    model.CodeOfClass = codes # origin CBUC but shuffled by AGUA 
    model.GroundTruth = GT # ANNOTATION
    model.TheClusterOfClass = map_class2cluster # CLOPE
    model.TheSpeciesOfCluster = list(best_annotation.values()) # CLOPE + ANNOTATION
    baccession=[]
    for acc in best_accession:
        baccession.append(get_accession(acc,t))
    model.Accession=baccession # CBUC but shuffled by AGUA
    
    print("Mean accuracy of the model ",model.Accuracy," standard deviation of accuracy ",np.std(Accuracy))
    print("Number of Classes :",model.NmbOfClasses)
#     print("CodesOf Classes :\n",model.CodeOfClass)
#     print("Annotation of Classes :\n",model.GroundTruth) 
    print("Number of clusters",model.NmbOfClusters)
    print("Confusion matrix\n",pd.DataFrame(zip(model.ConfusionMatrix,model.TheSpeciesOfCluster)))
else:
    print("optimum not found for repulsion in the interval [",minRep,",",maxRep,"]")
# Out:
# QUEM É O PVEC: 5797
# check: number of transactions = annotations:  5797 = 5797
# Looking for optimal repulsion with  50 random iterations and threshold of minimum cluster accuracy of  1.0
# repulsion 2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# repulsion 3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  2
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# repulsion 4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# repulsion 5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# repulsion 6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# repulsion 7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# repulsion 8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  3
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# repulsion 9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# repulsion 10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# repulsion 11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  4
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# repulsion 12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  5
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# repulsion 13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# repulsion 14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  6
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# repulsion 15
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# repulsion 16
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  7
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# repulsion 17
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  15
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  8
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# repulsion 18
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  15
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# repulsion 19
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  9
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  15
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  10
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  13
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  15
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  17
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  14
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  12
# ITERAÇÃO:  0 . NÚMERO DA ETAPA 1000 . NÚMERO DE CLUSTERS:  11
# optimum not found for repulsion in the interval [ 2 , 20 ]

# %%
# Check
# print(model.TheClusterOfClass)
# target = 1
# for pclass in model.TheClusterOfClass.keys():
#     if model.TheClusterOfClass[pclass]==target:
#         print("classes in cluster ",target," = ",pclass," annot ",model.GroundTruth[pclass])

# %%
print(min_min_cluster_acc)
print(ClusterAccThres)
# Out:
# 0.11382878645343364
# 1.0

# %% [markdown]
# # FASE 3 - ANÁLISE QUALITATIVA

# %%
# calculating distances between pairs of IDs -> put in categorical distance matrix

def categoricaldist(u,v,var,mode=0): # calcula a distancia entre 2 vetores categóricos: numero de entradas distintas / total de entradas
    dist=0
    for i in range(len(u)):
        if u[i]!=v[i]:
            if mode==0:
                dist+=1/var[i] # weighted -> INVERSAMENTE PROPORCIONAL À VARIABILIDADE DO SITE
            else:
                dist+=1 # SEM CONSIDERAR A VARIABILIDADE DO SITE
                
    return dist/len(u)

# -------------------------------------------------------------------

print("FASE2 - CÁLCULO DA MATRIZ DE DISTÂNCIAS ENTRE PARES DE CLASSES PRIMÁRIAS ")

fvec=model.CodeOfClass
print(f'ESTOU AQUI: {model.CodeOfClass}')
start=time.time()
print(len(fvec))
cat_distmatrix=[]
for i in range(P-1):
    cat_distmatrix.append([])
    for j in range(i+1,P):
#         dotdistmatrix[-1].append(np.dot(pvec[i],pvec[j]))
        cat_distmatrix[-1].append(categoricaldist(fvec[i],fvec[j],var,0))
#         print(i,j,np.dot(pvec[i],pvec[j]))
        
# check 
# for distvec in cat_distmatrix:
#     print(distvec)

# gerando matriz de distancias simetrica

# nota: os vetores dists , fst e scd estão alinhados, ou seja dists[k] é a distância entre a classe fst[k] e a scd[k] !!!

DistMat=np.zeros((P,P),dtype=float)
labels=[]
# fst & scd são o par de indexadores de cada distância (as classes primárias que são comparadas)
fst=[]
scd=[]
for i in range(P-1):
    labels.append("class"+str(i)+" annot "+model.GroundTruth[i]+ " cluster "+str(model.TheClusterOfClass[i])+" pred "+\
                  model.TheSpeciesOfCluster[model.TheClusterOfClass[i]])
    for j in range(i+1,P):
        fst.append(i)
        scd.append(j)
        DistMat[i][j]=cat_distmatrix[i][j-i-1]
        DistMat[j][i]=DistMat[i][j] # building a symmetric matrix
        
labels.append("class"+str(P-1)+" annot "+model.GroundTruth[P-1]+ " cluster "+str(model.TheClusterOfClass[P-1])+ " pred "+\
                  model.TheSpeciesOfCluster[model.TheClusterOfClass[P-1]])

print("matriz de distâncias\n", DistMat)

np.savetxt('dist_mat.txt', DistMat)

dists = squareform(DistMat) # saida para a construcao de arvores com dendogram
print("vetor de distancias\n", dists)

print(f"tempo:{time.time()-start} segundos")
# Out:
# FASE2 - CÁLCULO DA MATRIZ DE DISTÂNCIAS ENTRE PARES DE CLASSES PRIMÁRIAS
# ESTOU AQUI: []
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb Célula 35 line 2
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=23'>24</a>     cat_distmatrix.append([])
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=24'>25</a>     for j in range(i+1,P):
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=25'>26</a> #         dotdistmatrix[-1].append(np.dot(pvec[i],pvec[j]))
# ---> <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=26'>27</a>         cat_distmatrix[-1].append(categoricaldist(fvec[i],fvec[j],var,0))
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=27'>28</a> #         print(i,j,np.dot(pvec[i],pvec[j]))
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=28'>29</a>
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=29'>30</a> # check
#    (...)
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=34'>35</a>
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=35'>36</a> # nota: os vetores dists , fst e scd estão alinhados, ou seja dists[k] é a distância entre a classe fst[k] e a scd[k] !!!
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/AGUA_Training_Pipeline.ipynb#X46sZmlsZQ%3D%3D?line=37'>38</a> DistMat=np.zeros((P,P),dtype=float)
#
# IndexError: list index out of range

# %%
#atualizando labels com a especie predita

# print(model.TheClusterOfClass)
# target = 7
# for pclass in model.TheClusterOfClass.keys():
#     labels[pclass]+=" annot "+model.GroundTruth[pclass]+" pred "+model.TheSpeciesOfCluster[model.TheClusterOfClass[pclass]]
# #     if model.TheClusterOfClass[pclass]==target:
# #         print("classes in cluster ",target," = ",pclass," annot ",model.GroundTruth[pclass])

# %% [markdown]
# # visualizando árvore filogenética

# %% [markdown]
# # linkage methods
# The following are methods for calculating the distance between the newly formed cluster  and each .
#
# 1. method=’single’  also known as the Nearest Point Algorithm.
#
# 2. method=’complete’  also known by the Farthest Point Algorithm or Voor Hees Algorithm.
#
# 3. method=’average’ also called the UPGMA algorithm.
#
# 4. method=’weighted’ also called WPGMA.
#
# 5. method=’centroid’  also known as the UPGMC algorithm.
#
# 6. method=’median’  also known as the WPGMC algorithm.
#
# 7. method=’ward’ also known as the incremental algorithm.

# %%
# methods=['single', 'complete','average','weighted','centroid','median','ward']
# methodknownas=['NearestPoint', 'FarthestPoint','UPGMA','WPGMA','UPGMC','WPGMC','Incremental']
methods=['ward']
methodknownas=['Incremental']
nmeth=len(methods)

# %%
# construindo arvores com distintos métodos de linkagem da scipy.cluster.hierarch.linkage
ctr=0
for meth in methods:
    linkage_matrix = linkage(dists, meth)
    fig, ax = plt.subplots(1, 1, figsize=(10, 18))
    fig.set_size_inches(10, 18, forward=True)
    dn= dendrogram(linkage_matrix, ax=ax, labels=labels, show_leaf_counts=True, show_contracted=True, orientation='left',leaf_font_size=10)
    plt.title("SARS2 - Host independent study with linkage method '"+meth+"' ("+methodknownas[ctr]+")")
#     plt.tight_layout()
    #or:
    plt.tight_layout(pad=4)
    plt.show()
    fig.savefig('tree_'+methodknownas[ctr]+'.png', dpi=fig.dpi)
    ctr+=1

# %%
def print_model(model,n):
    print("name:", model.name)
    print("ListOfVarSites:\n",model.ListOfVarSites)
    print("NmbOfClasses:",model.NmbOfClasses)
    print("CodeOfClass[:",n,"]:\n",model.CodeOfClass[:n])
    print("GroundTruth[:",n,"]:\n",model.GroundTruth[:n])
    print("Accession[:",n,"]:\n",model.Accession[:n])
    print("repulsion:",model.repulsion)
    print("NmbOfClusters:",model.NmbOfClusters)
    print("TheSpeciesOfCluster:\n",model.TheSpeciesOfCluster)
    print("MinClusterAcc:",model.MinClusterAcc)
    print("Accuracy:",model.Accuracy)
    print("ConfusionMatrix:\n",model.ConfusionMatrix)
    print("TheClusterOfClass:\n",model.TheClusterOfClass)

# %%
print_model(model,2)

# %% [markdown]
# # CREATING THE GENE VARIANT FILE

# %%
# creating and saving the final GVF file

GVF=pd.DataFrame(model.CodeOfClass)
col_rename_dict = {i:j for i,j in zip(GVF.columns,model.ListOfVarSites)}
GVF.rename(columns=col_rename_dict, inplace=True)

GVF['accession']=model.Accession
GVF['ground_truth']=model.GroundTruth

GVF

GVF.to_csv(model.name+'.gvf')

# %%
print(GVF.columns)

# %%
# saving and loading the  model

# Save the file
model_filename=model.name+".obj"
dill.dump(model, file = open(model_filename, "wb"))

# Reload the file
loaded_model = dill.load(open(model_filename, "rb"))
print_model(loaded_model,2)

# %%
# READY TO USE IN THE PRODUCTION PHASE - 23.10.2022
