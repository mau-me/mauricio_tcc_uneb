# %% [markdown]
# # AGUA : Ad hoc Genotyping with Unsupervised
# # Algorithm / Analysis / Approach / Advisor
# ## training pipeline Python script
# ### Diego Frias, 23.10.2022

# %%
# %pip install seaborn

# %%
#import our three important packages
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import os
import sys
import Bio as Bio
from Bio import SeqIO
from Bio import AlignIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio import Phylo
import seaborn as sns
import time as time
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import squareform

import pandas as pd
import random 

import dill
from decimal import Decimal, getcontext

# Defina a precisão desejada (por exemplo, 50 dígitos)
getcontext().prec = 50

# import re

# %% [markdown]
# # FASE 1 - PREPROCESSAMENTO
# ## LEITURA DO DATASET DE TREINAMENTO & IDENTIFICAÇÃO/CODIFICAÇÃO DE CLASSES PRIMÁRIAS

# %%
base = [16, 4, 1]

nucleotides = {
"A": 0,
"G": 1,
"C": 2,
"T": 3,
"a": 0,
"g": 1,
"c": 2,
"t": 3,
}
    
stops=["TAA","TAG","TGA"]
    
stopnmb=[]

for triplet in stops:
    codonNumber = 0 # 0 to 63
    for p in range(3):
          codonNumber += base[p] * nucleotides[triplet[p]]
    stopnmb.append(codonNumber)

print("stop codon ordinals ",stopnmb)
# Out:
# stop codon ordinals  [48, 49, 52]

# %%
#import the sequences we will use. These are 16s sequences from GenBank
#example: https://www.ncbi.nlm.nih.gov/nuccore/FJ039971.1?report=genbank 
fname = "/home/m_souza/tcc/dataset/dataset_agua/sequencias_treinamento.fasta"
# fname = "/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/spike_alignment.fas"
# t1 = SeqIO.read("sequence1.fasta", "fasta")
# t2 = SeqIO.read("sequence2.fasta", "fasta")
# t3 = SeqIO.read("sequence3.fasta", "fasta")
# t4 = SeqIO.read("sequence4.fasta", "fasta")
# t5 = SeqIO.read("sequence5.fasta", "fasta")
# t6 = SeqIO.read("sequence6.fasta", "fasta")
# t7 = SeqIO.read("sequence7.fasta", "fasta")

t=[]
with open(fname) as handle:
    for values in SeqIO.FastaIO.SimpleFastaParser(handle):
        t.append(values)
        print(t[-1][0])
        
Nseq=len(t)

print("number of sequences in file ",fname," = ",Nseq)
# Out:
# spike(pos.ini:21562 pos.fin:25384)accn|MT628234
# spike(pos.ini:21562 pos.fin:25384)accn|MT628235
# spike(pos.ini:21562 pos.fin:25384)accn|MT628237
# spike(pos.ini:21562 pos.fin:25384)accn|MW053744
# spike(pos.ini:21562 pos.fin:25384)accn|MT628238
# spike(pos.ini:21562 pos.fin:25384)accn|MT628247
# spike(pos.ini:21562 pos.fin:25384)accn|MT628251
# spike(pos.ini:21562 pos.fin:25384)accn|MT628253
# spike(pos.ini:21562 pos.fin:25384)accn|MT628254
# spike(pos.ini:21562 pos.fin:25384)accn|MT628255
# spike(pos.ini:21562 pos.fin:25384)accn|OU348132
# spike(pos.ini:21562 pos.fin:25384)accn|OU340519
# spike(pos.ini:21562 pos.fin:25384)accn|OU290602
# spike(pos.ini:21562 pos.fin:25384)accn|OU286689
# spike(pos.ini:21562 pos.fin:25384)accn|OU287044
# spike(pos.ini:21562 pos.fin:25384)accn|OU298008
# spike(pos.ini:21562 pos.fin:25384)accn|OU314138
# spike(pos.ini:21562 pos.fin:25384)accn|OU288618
# spike(pos.ini:21562 pos.fin:25384)accn|OU292159
# spike(pos.ini:21562 pos.fin:25384)accn|OU299530
# spike(pos.ini:21562 pos.fin:25384)accn|MW341443
# spike(pos.ini:21562 pos.fin:25384)accn|ON870954
# spike(pos.ini:21562 pos.fin:25384)accn|ON878765
# spike(pos.ini:21562 pos.fin:25384)accn|ON878781
# spike(pos.ini:21562 pos.fin:25384)accn|ON878782
# spike(pos.ini:21562 pos.fin:25384)accn|ON878788
# spike(pos.ini:21562 pos.fin:25384)accn|ON878787
# spike(pos.ini:21562 pos.fin:25384)accn|ON878797
# spike(pos.ini:21562 pos.fin:25384)accn|ON878795
# spike(pos.ini:21562 pos.fin:25384)accn|ON878796
# spike(pos.ini:21562 pos.fin:25384)accn|MZ372711
# spike(pos.ini:21562 pos.fin:25384)accn|MZ372712
# spike(pos.ini:21562 pos.fin:25384)accn|OU075229
# spike(pos.ini:21562 pos.fin:25384)accn|MZ591007
# spike(pos.ini:21562 pos.fin:25384)accn|MZ593669
# spike(pos.ini:21562 pos.fin:25384)accn|MZ591877
# spike(pos.ini:21562 pos.fin:25384)accn|MZ647317
# spike(pos.ini:21562 pos.fin:25384)accn|MZ647385
# spike(pos.ini:21562 pos.fin:25384)accn|MZ784304
# spike(pos.ini:21562 pos.fin:25384)accn|MZ850490
# spike(pos.ini:21562 pos.fin:25384)accn|MZ877201
# spike(pos.ini:21562 pos.fin:25384)accn|MZ879302
# spike(pos.ini:21562 pos.fin:25384)accn|MZ877252
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882519
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882582
# spike(pos.ini:21562 pos.fin:25384)accn|MZ886640
# spike(pos.ini:21562 pos.fin:25384)accn|MZ888660
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882633
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882638
# spike(pos.ini:21562 pos.fin:25384)accn|MZ882658
# spike(pos.ini:21562 pos.fin:25384)accn|OM019981
# spike(pos.ini:21562 pos.fin:25384)accn|OM173384
# spike(pos.ini:21562 pos.fin:25384)accn|OM104437
# spike(pos.ini:21562 pos.fin:25384)accn|OM019996
# spike(pos.ini:21562 pos.fin:25384)accn|OM104457
# spike(pos.ini:21562 pos.fin:25384)accn|OM020011
# spike(pos.ini:21562 pos.fin:25384)accn|OM020036
# spike(pos.ini:21562 pos.fin:25384)accn|OM104494
# spike(pos.ini:21562 pos.fin:25384)accn|OM173452
# spike(pos.ini:21562 pos.fin:25384)accn|OM104522
# spike(pos.ini:21562 pos.fin:25384)accn|OU412175
# spike(pos.ini:21562 pos.fin:25384)accn|OU408246
# spike(pos.ini:21562 pos.fin:25384)accn|OU408835
# spike(pos.ini:21562 pos.fin:25384)accn|OU375016
# spike(pos.ini:21562 pos.fin:25384)accn|OU429497
# spike(pos.ini:21562 pos.fin:25384)accn|OU383643
# spike(pos.ini:21562 pos.fin:25384)accn|OU379844
# spike(pos.ini:21562 pos.fin:25384)accn|OU379862
# spike(pos.ini:21562 pos.fin:25384)accn|OU417957
# spike(pos.ini:21562 pos.fin:25384)accn|OU379961
# spike(pos.ini:21562 pos.fin:25384)accn|LR883974
# spike(pos.ini:21562 pos.fin:25384)accn|LR883995
# spike(pos.ini:21562 pos.fin:25384)accn|LR883996
# spike(pos.ini:21562 pos.fin:25384)accn|LR884009
# spike(pos.ini:21562 pos.fin:25384)accn|LR884020
# spike(pos.ini:21562 pos.fin:25384)accn|LR884033
# spike(pos.ini:21562 pos.fin:25384)accn|LR884054
# spike(pos.ini:21562 pos.fin:25384)accn|LR884063
# spike(pos.ini:21562 pos.fin:25384)accn|LR884065
# spike(pos.ini:21562 pos.fin:25384)accn|LR884078
# spike(pos.ini:21562 pos.fin:25384)accn|OU329975
# spike(pos.ini:21562 pos.fin:25384)accn|OU428228
# spike(pos.ini:21562 pos.fin:25384)accn|OU509703
# spike(pos.ini:21562 pos.fin:25384)accn|OU480847
# spike(pos.ini:21562 pos.fin:25384)accn|OU534438
# spike(pos.ini:21562 pos.fin:25384)accn|OU540618
# spike(pos.ini:21562 pos.fin:25384)accn|OU534072
# spike(pos.ini:21562 pos.fin:25384)accn|OU550290
# spike(pos.ini:21562 pos.fin:25384)accn|OU556646
# spike(pos.ini:21562 pos.fin:25384)accn|OU557230
# spike(pos.ini:21562 pos.fin:25384)accn|OK239246
# spike(pos.ini:21562 pos.fin:25384)accn|OK277733
# spike(pos.ini:21562 pos.fin:25384)accn|OK353751
# spike(pos.ini:21562 pos.fin:25384)accn|OK455315
# spike(pos.ini:21562 pos.fin:25384)accn|OK461771
# spike(pos.ini:21562 pos.fin:25384)accn|OK355161
# spike(pos.ini:21562 pos.fin:25384)accn|OL306995
# spike(pos.ini:21562 pos.fin:25384)accn|OL310889
# spike(pos.ini:21562 pos.fin:25384)accn|OL304706
# spike(pos.ini:21562 pos.fin:25384)accn|OL304744
# spike(pos.ini:21562 pos.fin:25384)accn|MZ386404
# spike(pos.ini:21562 pos.fin:25384)accn|MZ372328
# spike(pos.ini:21562 pos.fin:25384)accn|MZ450369
# spike(pos.ini:21562 pos.fin:25384)accn|MZ450527
# spike(pos.ini:21562 pos.fin:25384)accn|MZ375923
# spike(pos.ini:21562 pos.fin:25384)accn|MZ436591
# spike(pos.ini:21562 pos.fin:25384)accn|MZ436854
# spike(pos.ini:21562 pos.fin:25384)accn|MZ613487
# spike(pos.ini:21562 pos.fin:25384)accn|MZ613488
# spike(pos.ini:21562 pos.fin:25384)accn|MZ592567
# spike(pos.ini:21562 pos.fin:25384)accn|OU290269
# spike(pos.ini:21562 pos.fin:25384)accn|OU066261
# spike(pos.ini:21562 pos.fin:25384)accn|MZ434560
# spike(pos.ini:21562 pos.fin:25384)accn|MW571125
# spike(pos.ini:21562 pos.fin:25384)accn|OU305686
# spike(pos.ini:21562 pos.fin:25384)accn|MZ636223
# spike(pos.ini:21562 pos.fin:25384)accn|MZ619648
# spike(pos.ini:21562 pos.fin:25384)accn|MZ798926
# spike(pos.ini:21562 pos.fin:25384)accn|MZ798937
# spike(pos.ini:21562 pos.fin:25384)accn|OK433688
# spike(pos.ini:21562 pos.fin:25384)accn|OV373183
# spike(pos.ini:21562 pos.fin:25384)accn|OV392333
# spike(pos.ini:21562 pos.fin:25384)accn|OV333235
# spike(pos.ini:21562 pos.fin:25384)accn|OV333236
# spike(pos.ini:21562 pos.fin:25384)accn|OV392340
# spike(pos.ini:21562 pos.fin:25384)accn|OV333267
# spike(pos.ini:21562 pos.fin:25384)accn|OV333271
# spike(pos.ini:21562 pos.fin:25384)accn|OV333295
# spike(pos.ini:21562 pos.fin:25384)accn|OV333304
# spike(pos.ini:21562 pos.fin:25384)accn|OV333321
# spike(pos.ini:21562 pos.fin:25384)accn|OU958954
# spike(pos.ini:21562 pos.fin:25384)accn|OU952784
# spike(pos.ini:21562 pos.fin:25384)accn|OV002530
# spike(pos.ini:21562 pos.fin:25384)accn|OU983369
# spike(pos.ini:21562 pos.fin:25384)accn|OV025329
# spike(pos.ini:21562 pos.fin:25384)accn|OV026607
# spike(pos.ini:21562 pos.fin:25384)accn|OV016844
# spike(pos.ini:21562 pos.fin:25384)accn|OV027166
# spike(pos.ini:21562 pos.fin:25384)accn|OV028184
# spike(pos.ini:21562 pos.fin:25384)accn|OV008565
# spike(pos.ini:21562 pos.fin:25384)accn|OU080288
# spike(pos.ini:21562 pos.fin:25384)accn|OU095060
# spike(pos.ini:21562 pos.fin:25384)accn|OU051033
# spike(pos.ini:21562 pos.fin:25384)accn|OU077198
# spike(pos.ini:21562 pos.fin:25384)accn|OU073035
# spike(pos.ini:21562 pos.fin:25384)accn|OU077776
# spike(pos.ini:21562 pos.fin:25384)accn|OU088216
# spike(pos.ini:21562 pos.fin:25384)accn|OU073545
# spike(pos.ini:21562 pos.fin:25384)accn|OU075689
# spike(pos.ini:21562 pos.fin:25384)accn|OU075748
# spike(pos.ini:21562 pos.fin:25384)accn|OU436439
# spike(pos.ini:21562 pos.fin:25384)accn|OU454807
# spike(pos.ini:21562 pos.fin:25384)accn|OU450407
# spike(pos.ini:21562 pos.fin:25384)accn|OU505849
# spike(pos.ini:21562 pos.fin:25384)accn|OU503144
# spike(pos.ini:21562 pos.fin:25384)accn|OU513010
# spike(pos.ini:21562 pos.fin:25384)accn|OU513253
# spike(pos.ini:21562 pos.fin:25384)accn|OU485895
# spike(pos.ini:21562 pos.fin:25384)accn|OU775903
# spike(pos.ini:21562 pos.fin:25384)accn|OU783908
# spike(pos.ini:21562 pos.fin:25384)accn|OU954434
# spike(pos.ini:21562 pos.fin:25384)accn|OV012915
# spike(pos.ini:21562 pos.fin:25384)accn|OV032526
# spike(pos.ini:21562 pos.fin:25384)accn|OV084700
# spike(pos.ini:21562 pos.fin:25384)accn|OV094717
# spike(pos.ini:21562 pos.fin:25384)accn|OV097649
# spike(pos.ini:21562 pos.fin:25384)accn|OV078492
# spike(pos.ini:21562 pos.fin:25384)accn|OV121541
# spike(pos.ini:21562 pos.fin:25384)accn|OV050689
# spike(pos.ini:21562 pos.fin:25384)accn|OV053647
# spike(pos.ini:21562 pos.fin:25384)accn|OV569279
# spike(pos.ini:21562 pos.fin:25384)accn|OV549309
# spike(pos.ini:21562 pos.fin:25384)accn|OV569302
# spike(pos.ini:21562 pos.fin:25384)accn|OV549316
# spike(pos.ini:21562 pos.fin:25384)accn|OV569320
# spike(pos.ini:21562 pos.fin:25384)accn|OV549345
# spike(pos.ini:21562 pos.fin:25384)accn|OV549347
# spike(pos.ini:21562 pos.fin:25384)accn|OV569347
# spike(pos.ini:21562 pos.fin:25384)accn|OV569356
# spike(pos.ini:21562 pos.fin:25384)accn|OV569381
# spike(pos.ini:21562 pos.fin:25384)accn|OV216824
# spike(pos.ini:21562 pos.fin:25384)accn|OL902748
# spike(pos.ini:21562 pos.fin:25384)accn|OV270049
# spike(pos.ini:21562 pos.fin:25384)accn|OL995810
# spike(pos.ini:21562 pos.fin:25384)accn|OV311497
# spike(pos.ini:21562 pos.fin:25384)accn|OV399026
# spike(pos.ini:21562 pos.fin:25384)accn|OV448199
# spike(pos.ini:21562 pos.fin:25384)accn|OV418435
# spike(pos.ini:21562 pos.fin:25384)accn|OV491816
# spike(pos.ini:21562 pos.fin:25384)accn|OV806310
# spike(pos.ini:21562 pos.fin:25384)accn|MZ592121
# spike(pos.ini:21562 pos.fin:25384)accn|MZ592139
# spike(pos.ini:21562 pos.fin:25384)accn|MZ592182
# spike(pos.ini:21562 pos.fin:25384)accn|MZ710659
# spike(pos.ini:21562 pos.fin:25384)accn|MZ648149
# spike(pos.ini:21562 pos.fin:25384)accn|MZ649850
# spike(pos.ini:21562 pos.fin:25384)accn|MZ649881
# spike(pos.ini:21562 pos.fin:25384)accn|MZ706048
# spike(pos.ini:21562 pos.fin:25384)accn|MZ650746
# spike(pos.ini:21562 pos.fin:25384)accn|MZ786349
# spike(pos.ini:21562 pos.fin:25384)accn|OV848085
# spike(pos.ini:21562 pos.fin:25384)accn|OV848090
# spike(pos.ini:21562 pos.fin:25384)accn|OV848092
# spike(pos.ini:21562 pos.fin:25384)accn|OV858090
# spike(pos.ini:21562 pos.fin:25384)accn|OV848109
# spike(pos.ini:21562 pos.fin:25384)accn|OV848116
# spike(pos.ini:21562 pos.fin:25384)accn|OV848120
# spike(pos.ini:21562 pos.fin:25384)accn|OV858119
# spike(pos.ini:21562 pos.fin:25384)accn|OV848124
# spike(pos.ini:21562 pos.fin:25384)accn|OV858121
# spike(pos.ini:21562 pos.fin:25384)accn|MW571124
# spike(pos.ini:21562 pos.fin:25384)accn|OU165623
# spike(pos.ini:21562 pos.fin:25384)accn|MW583372
# spike(pos.ini:21562 pos.fin:25384)accn|OK188630
# spike(pos.ini:21562 pos.fin:25384)accn|OL448870
# spike(pos.ini:21562 pos.fin:25384)accn|OL698796
# spike(pos.ini:21562 pos.fin:25384)accn|OL698818
# spike(pos.ini:21562 pos.fin:25384)accn|FR992666
# spike(pos.ini:21562 pos.fin:25384)accn|MW693648
# spike(pos.ini:21562 pos.fin:25384)accn|MW888191
# spike(pos.ini:21562 pos.fin:25384)accn|OU352074
# spike(pos.ini:21562 pos.fin:25384)accn|OU352077
# spike(pos.ini:21562 pos.fin:25384)accn|OU352079
# spike(pos.ini:21562 pos.fin:25384)accn|OU352086
# spike(pos.ini:21562 pos.fin:25384)accn|OU352095
# spike(pos.ini:21562 pos.fin:25384)accn|OU352097
# spike(pos.ini:21562 pos.fin:25384)accn|OU285761
# spike(pos.ini:21562 pos.fin:25384)accn|OU327122
# spike(pos.ini:21562 pos.fin:25384)accn|OU294355
# spike(pos.ini:21562 pos.fin:25384)accn|OU297296
# spike(pos.ini:21562 pos.fin:25384)accn|OU355389
# spike(pos.ini:21562 pos.fin:25384)accn|OU406986
# spike(pos.ini:21562 pos.fin:25384)accn|OU409362
# spike(pos.ini:21562 pos.fin:25384)accn|OU412269
# spike(pos.ini:21562 pos.fin:25384)accn|OU408654
# spike(pos.ini:21562 pos.fin:25384)accn|OU376695
# spike(pos.ini:21562 pos.fin:25384)accn|OU379042
# spike(pos.ini:21562 pos.fin:25384)accn|OU429599
# spike(pos.ini:21562 pos.fin:25384)accn|OU376346
# spike(pos.ini:21562 pos.fin:25384)accn|OU376379
# spike(pos.ini:21562 pos.fin:25384)accn|MT628240
# spike(pos.ini:21562 pos.fin:25384)accn|MT628241
# spike(pos.ini:21562 pos.fin:25384)accn|MT641749
# spike(pos.ini:21562 pos.fin:25384)accn|MT641753
# spike(pos.ini:21562 pos.fin:25384)accn|MT745668
# spike(pos.ini:21562 pos.fin:25384)accn|MZ332024
# spike(pos.ini:21562 pos.fin:25384)accn|MZ332144
# spike(pos.ini:21562 pos.fin:25384)accn|MT451131
# spike(pos.ini:21562 pos.fin:25384)accn|MT451141
# spike(pos.ini:21562 pos.fin:25384)accn|MT451152
# spike(pos.ini:21562 pos.fin:25384)accn|LR883991
# spike(pos.ini:21562 pos.fin:25384)accn|LR884000
# spike(pos.ini:21562 pos.fin:25384)accn|LR884011
# spike(pos.ini:21562 pos.fin:25384)accn|LR884060
# spike(pos.ini:21562 pos.fin:25384)accn|LR884067
# spike(pos.ini:21562 pos.fin:25384)accn|LR884096
# spike(pos.ini:21562 pos.fin:25384)accn|LR884127
# spike(pos.ini:21562 pos.fin:25384)accn|LR884133
# spike(pos.ini:21562 pos.fin:25384)accn|LR884169
# spike(pos.ini:21562 pos.fin:25384)accn|LR884179
# spike(pos.ini:21562 pos.fin:25384)accn|OU557296
# spike(pos.ini:21562 pos.fin:25384)accn|OU567398
# spike(pos.ini:21562 pos.fin:25384)accn|OU567408
# spike(pos.ini:21562 pos.fin:25384)accn|OU575123
# spike(pos.ini:21562 pos.fin:25384)accn|OU577089
# spike(pos.ini:21562 pos.fin:25384)accn|OU572056
# spike(pos.ini:21562 pos.fin:25384)accn|OU573850
# spike(pos.ini:21562 pos.fin:25384)accn|OU585451
# spike(pos.ini:21562 pos.fin:25384)accn|OK197691
# spike(pos.ini:21562 pos.fin:25384)accn|OK227839
# spike(pos.ini:21562 pos.fin:25384)accn|OU166830
# spike(pos.ini:21562 pos.fin:25384)accn|OU168147
# spike(pos.ini:21562 pos.fin:25384)accn|OU168155
# spike(pos.ini:21562 pos.fin:25384)accn|OA999552
# spike(pos.ini:21562 pos.fin:25384)accn|OB987339
# spike(pos.ini:21562 pos.fin:25384)accn|OB990305
# spike(pos.ini:21562 pos.fin:25384)accn|OB991015
# spike(pos.ini:21562 pos.fin:25384)accn|OD906284
# spike(pos.ini:21562 pos.fin:25384)accn|OU032282
# spike(pos.ini:21562 pos.fin:25384)accn|OA969558
# spike(pos.ini:21562 pos.fin:25384)accn|OW606598
# spike(pos.ini:21562 pos.fin:25384)accn|OW606600
# spike(pos.ini:21562 pos.fin:25384)accn|OW606603
# spike(pos.ini:21562 pos.fin:25384)accn|OW606604
# spike(pos.ini:21562 pos.fin:25384)accn|OW606605
# spike(pos.ini:21562 pos.fin:25384)accn|OW606608
# spike(pos.ini:21562 pos.fin:25384)accn|OW606610
# spike(pos.ini:21562 pos.fin:25384)accn|OW606615
# spike(pos.ini:21562 pos.fin:25384)accn|OW606617
# spike(pos.ini:21562 pos.fin:25384)accn|OW606621
# spike(pos.ini:21562 pos.fin:25384)accn|OU057822
# spike(pos.ini:21562 pos.fin:25384)accn|OU098020
# spike(pos.ini:21562 pos.fin:25384)accn|OU423624
# spike(pos.ini:21562 pos.fin:25384)accn|OU392001
# spike(pos.ini:21562 pos.fin:25384)accn|OU393991
# spike(pos.ini:21562 pos.fin:25384)accn|MW938154
# spike(pos.ini:21562 pos.fin:25384)accn|ON041635
# spike(pos.ini:21562 pos.fin:25384)accn|OU094621
# spike(pos.ini:21562 pos.fin:25384)accn|OU097255
# spike(pos.ini:21562 pos.fin:25384)accn|OU107903
# spike(pos.ini:21562 pos.fin:25384)accn|MZ385570
# spike(pos.ini:21562 pos.fin:25384)accn|MZ371185
# spike(pos.ini:21562 pos.fin:25384)accn|MZ405695
# spike(pos.ini:21562 pos.fin:25384)accn|MZ405702
# spike(pos.ini:21562 pos.fin:25384)accn|MZ405705
# spike(pos.ini:21562 pos.fin:25384)accn|MZ405706
# spike(pos.ini:21562 pos.fin:25384)accn|MZ349302
# spike(pos.ini:21562 pos.fin:25384)accn|MZ434017
# spike(pos.ini:21562 pos.fin:25384)accn|MZ328696
# spike(pos.ini:21562 pos.fin:25384)accn|MZ411951
# spike(pos.ini:21562 pos.fin:25384)accn|OU139532
# spike(pos.ini:21562 pos.fin:25384)accn|OU139553
# spike(pos.ini:21562 pos.fin:25384)accn|OU139558
# spike(pos.ini:21562 pos.fin:25384)accn|MW547503
# spike(pos.ini:21562 pos.fin:25384)accn|MW548224
# spike(pos.ini:21562 pos.fin:25384)accn|OU154336
# spike(pos.ini:21562 pos.fin:25384)accn|OU365358
# spike(pos.ini:21562 pos.fin:25384)accn|OU365442
# spike(pos.ini:21562 pos.fin:25384)accn|MZ895674
# spike(pos.ini:21562 pos.fin:25384)accn|MZ895681
# spike(pos.ini:21562 pos.fin:25384)accn|OU577019
# spike(pos.ini:21562 pos.fin:25384)accn|OU572110
# spike(pos.ini:21562 pos.fin:25384)accn|OU572143
# spike(pos.ini:21562 pos.fin:25384)accn|OU578380
# spike(pos.ini:21562 pos.fin:25384)accn|OU592551
# spike(pos.ini:21562 pos.fin:25384)accn|OU686412
# spike(pos.ini:21562 pos.fin:25384)accn|OU703166
# spike(pos.ini:21562 pos.fin:25384)accn|OU702549
# spike(pos.ini:21562 pos.fin:25384)accn|OU702860
# spike(pos.ini:21562 pos.fin:25384)accn|OU702903
# spike(pos.ini:21562 pos.fin:25384)accn|OU451772
# spike(pos.ini:21562 pos.fin:25384)accn|OU451842
# spike(pos.ini:21562 pos.fin:25384)accn|OU451861
# spike(pos.ini:21562 pos.fin:25384)accn|OU451908
# spike(pos.ini:21562 pos.fin:25384)accn|OU451911
# spike(pos.ini:21562 pos.fin:25384)accn|OU451925
# spike(pos.ini:21562 pos.fin:25384)accn|OU452068
# spike(pos.ini:21562 pos.fin:25384)accn|OU450980
# spike(pos.ini:21562 pos.fin:25384)accn|OU492628
# spike(pos.ini:21562 pos.fin:25384)accn|OU544771
# spike(pos.ini:21562 pos.fin:25384)accn|OL487830
# spike(pos.ini:21562 pos.fin:25384)accn|OU974789
# spike(pos.ini:21562 pos.fin:25384)accn|OV015816
# spike(pos.ini:21562 pos.fin:25384)accn|OV035487
# spike(pos.ini:21562 pos.fin:25384)accn|OV084397
# spike(pos.ini:21562 pos.fin:25384)accn|OV117217
# spike(pos.ini:21562 pos.fin:25384)accn|OV107262
# spike(pos.ini:21562 pos.fin:25384)accn|OV120188
# spike(pos.ini:21562 pos.fin:25384)accn|OV078501
# spike(pos.ini:21562 pos.fin:25384)accn|OV111623
# spike(pos.ini:21562 pos.fin:25384)accn|OU449664
# spike(pos.ini:21562 pos.fin:25384)accn|OU450818
# spike(pos.ini:21562 pos.fin:25384)accn|OU506205
# spike(pos.ini:21562 pos.fin:25384)accn|OU501596
# spike(pos.ini:21562 pos.fin:25384)accn|OU546950
# spike(pos.ini:21562 pos.fin:25384)accn|OU537155
# spike(pos.ini:21562 pos.fin:25384)accn|OU534039
# spike(pos.ini:21562 pos.fin:25384)accn|OU547407
# spike(pos.ini:21562 pos.fin:25384)accn|OU547589
# spike(pos.ini:21562 pos.fin:25384)accn|OU541735
# spike(pos.ini:21562 pos.fin:25384)accn|OK237665
# spike(pos.ini:21562 pos.fin:25384)accn|OK228626
# spike(pos.ini:21562 pos.fin:25384)accn|OK339002
# spike(pos.ini:21562 pos.fin:25384)accn|OK458947
# spike(pos.ini:21562 pos.fin:25384)accn|MZ967843
# spike(pos.ini:21562 pos.fin:25384)accn|MZ967993
# spike(pos.ini:21562 pos.fin:25384)accn|MZ977130
# spike(pos.ini:21562 pos.fin:25384)accn|OK008198
# spike(pos.ini:21562 pos.fin:25384)accn|MZ980986
# spike(pos.ini:21562 pos.fin:25384)accn|OK013271
# spike(pos.ini:21562 pos.fin:25384)accn|OL710970
# spike(pos.ini:21562 pos.fin:25384)accn|OL687692
# spike(pos.ini:21562 pos.fin:25384)accn|OL666009
# spike(pos.ini:21562 pos.fin:25384)accn|OL696793
# spike(pos.ini:21562 pos.fin:25384)accn|OL679329
# spike(pos.ini:21562 pos.fin:25384)accn|OL680083
# spike(pos.ini:21562 pos.fin:25384)accn|OL680147
# spike(pos.ini:21562 pos.fin:25384)accn|OL703966
# spike(pos.ini:21562 pos.fin:25384)accn|OL705511
# spike(pos.ini:21562 pos.fin:25384)accn|OL681194
# spike(pos.ini:21562 pos.fin:25384)accn|MW054101
# spike(pos.ini:21562 pos.fin:25384)accn|MW054103
# spike(pos.ini:21562 pos.fin:25384)accn|MW064469
# spike(pos.ini:21562 pos.fin:25384)accn|MW064584
# spike(pos.ini:21562 pos.fin:25384)accn|MW064587
# spike(pos.ini:21562 pos.fin:25384)accn|MW064591
# spike(pos.ini:21562 pos.fin:25384)accn|MW064592
# spike(pos.ini:21562 pos.fin:25384)accn|MW064593
# spike(pos.ini:21562 pos.fin:25384)accn|MW064826
# spike(pos.ini:21562 pos.fin:25384)accn|MW064896
# spike(pos.ini:21562 pos.fin:25384)accn|OU050106
# spike(pos.ini:21562 pos.fin:25384)accn|OU075736
# spike(pos.ini:21562 pos.fin:25384)accn|OU102541
# spike(pos.ini:21562 pos.fin:25384)accn|OU164701
# spike(pos.ini:21562 pos.fin:25384)accn|OU179404
# spike(pos.ini:21562 pos.fin:25384)accn|OU057395
# spike(pos.ini:21562 pos.fin:25384)accn|OU366479
# spike(pos.ini:21562 pos.fin:25384)accn|OU366489
# spike(pos.ini:21562 pos.fin:25384)accn|OU366852
# spike(pos.ini:21562 pos.fin:25384)accn|OU367108
# spike(pos.ini:21562 pos.fin:25384)accn|MT630423
# spike(pos.ini:21562 pos.fin:25384)accn|MW309830
# spike(pos.ini:21562 pos.fin:25384)accn|MT632776
# spike(pos.ini:21562 pos.fin:25384)accn|MW056081
# spike(pos.ini:21562 pos.fin:25384)accn|MW064329
# spike(pos.ini:21562 pos.fin:25384)accn|MW064332
# spike(pos.ini:21562 pos.fin:25384)accn|MW064338
# spike(pos.ini:21562 pos.fin:25384)accn|MW064351
# spike(pos.ini:21562 pos.fin:25384)accn|MW064354
# spike(pos.ini:21562 pos.fin:25384)accn|MT635409
# spike(pos.ini:21562 pos.fin:25384)accn|OU411147
# spike(pos.ini:21562 pos.fin:25384)accn|OU403063
# spike(pos.ini:21562 pos.fin:25384)accn|OU405138
# spike(pos.ini:21562 pos.fin:25384)accn|OU409371
# spike(pos.ini:21562 pos.fin:25384)accn|OU403248
# spike(pos.ini:21562 pos.fin:25384)accn|OU403338
# spike(pos.ini:21562 pos.fin:25384)accn|OU405294
# spike(pos.ini:21562 pos.fin:25384)accn|OU405365
# spike(pos.ini:21562 pos.fin:25384)accn|OU403527
# spike(pos.ini:21562 pos.fin:25384)accn|OU405556
# spike(pos.ini:21562 pos.fin:25384)accn|OU565933
# spike(pos.ini:21562 pos.fin:25384)accn|OU565956
# spike(pos.ini:21562 pos.fin:25384)accn|OU670399
# spike(pos.ini:21562 pos.fin:25384)accn|OU673770
# spike(pos.ini:21562 pos.fin:25384)accn|OU773391
# spike(pos.ini:21562 pos.fin:25384)accn|OU757792
# spike(pos.ini:21562 pos.fin:25384)accn|OU758872
# spike(pos.ini:21562 pos.fin:25384)accn|OU901660
# spike(pos.ini:21562 pos.fin:25384)accn|OU902427
# spike(pos.ini:21562 pos.fin:25384)accn|OU892765
# spike(pos.ini:21562 pos.fin:25384)accn|OV082023
# spike(pos.ini:21562 pos.fin:25384)accn|OV106369
# spike(pos.ini:21562 pos.fin:25384)accn|OV066232
# spike(pos.ini:21562 pos.fin:25384)accn|OV066233
# spike(pos.ini:21562 pos.fin:25384)accn|OV082038
# spike(pos.ini:21562 pos.fin:25384)accn|OV066240
# spike(pos.ini:21562 pos.fin:25384)accn|OV082050
# spike(pos.ini:21562 pos.fin:25384)accn|OV066347
# spike(pos.ini:21562 pos.fin:25384)accn|OV106533
# spike(pos.ini:21562 pos.fin:25384)accn|OV106545
# spike(pos.ini:21562 pos.fin:25384)accn|MZ713883
# spike(pos.ini:21562 pos.fin:25384)accn|MZ713959
# spike(pos.ini:21562 pos.fin:25384)accn|OU473233
# spike(pos.ini:21562 pos.fin:25384)accn|OU451604
# spike(pos.ini:21562 pos.fin:25384)accn|OU451744
# spike(pos.ini:21562 pos.fin:25384)accn|OU451747
# spike(pos.ini:21562 pos.fin:25384)accn|OU451756
# spike(pos.ini:21562 pos.fin:25384)accn|OU451896
# spike(pos.ini:21562 pos.fin:25384)accn|OU451914
# spike(pos.ini:21562 pos.fin:25384)accn|OU451985
# number of sequences in file  /home/m_souza/tcc/dataset/dataset_agua/sequencias_treinamento.fasta  =  450

# %%
# t[-1][1]

# %%
# # Open the alignment file as a MultipleSeqAlignment object 

# idlst = []
# sequences = []
# labels = []
# ctr = 0

# # Abra o arquivo de alinhamento e leia as sequências como objetos SeqRecord
# with open(fname, "r") as aln:
#     for seq_record in SeqIO.parse(aln, "fasta"):
#         sequences.append(seq_record)

# Nseqs = len(sequences)
# print("Número de sequências no alinhamento:", Nseqs)


# Open the alignment file as a MultipleSeqAlignment object 
fname = "/home/m_souza/tcc/dataset/dataset_agua/sequencias_treinamento.fasta"

with open(fname,"r") as aln: 
    alignment = AlignIO.read(aln,"fasta")

idlst=[]
sequences=[]
labels=[]
ctr=0
for strain in alignment:
#     print(strain.description)
    accn = strain.description.split("accn|")[1]
    if accn not in idlst:
        idlst.append(accn)
    else:
        print(ctr, "duplicated description ",accn)
        
    labels.append("strain"+str(ctr)) # strain.description # o id só saia cortado e acahava depois que itnha sequncias repetidas
    sequences.append(alignment[ctr].seq)
    ctr+=1
    
Nseqs=len(sequences)
print("number of seqs in the alignment", Nseqs)
# Out:
# number of seqs in the alignment 450

# %%
idlst
# Out:
# ['MT628234',
#  'MT628235',
#  'MT628237',
#  'MW053744',
#  'MT628238',
#  'MT628247',
#  'MT628251',
#  'MT628253',
#  'MT628254',
#  'MT628255',
#  'OU348132',
#  'OU340519',
#  'OU290602',
#  'OU286689',
#  'OU287044',
#  'OU298008',
#  'OU314138',
#  'OU288618',
#  'OU292159',
#  'OU299530',
#  'MW341443',
#  'ON870954',
#  'ON878765',
#  'ON878781',
#  'ON878782',
#  'ON878788',
#  'ON878787',
#  'ON878797',
#  'ON878795',
#  'ON878796',
#  'MZ372711',
#  'MZ372712',
#  'OU075229',
#  'MZ591007',
#  'MZ593669',
#  'MZ591877',
#  'MZ647317',
#  'MZ647385',
#  'MZ784304',
#  'MZ850490',
#  'MZ877201',
#  'MZ879302',
#  'MZ877252',
#  'MZ882519',
#  'MZ882582',
#  'MZ886640',
#  'MZ888660',
#  'MZ882633',
#  'MZ882638',
#  'MZ882658',
#  'OM019981',
#  'OM173384',
#  'OM104437',
#  'OM019996',
#  'OM104457',
#  'OM020011',
#  'OM020036',
#  'OM104494',
#  'OM173452',
#  'OM104522',
#  'OU412175',
#  'OU408246',
#  'OU408835',
#  'OU375016',
#  'OU429497',
#  'OU383643',
#  'OU379844',
#  'OU379862',
#  'OU417957',
#  'OU379961',
#  'LR883974',
#  'LR883995',
#  'LR883996',
#  'LR884009',
#  'LR884020',
#  'LR884033',
#  'LR884054',
#  'LR884063',
#  'LR884065',
#  'LR884078',
#  'OU329975',
#  'OU428228',
#  'OU509703',
#  'OU480847',
#  'OU534438',
#  'OU540618',
#  'OU534072',
#  'OU550290',
#  'OU556646',
#  'OU557230',
#  'OK239246',
#  'OK277733',
#  'OK353751',
#  'OK455315',
#  'OK461771',
#  'OK355161',
#  'OL306995',
#  'OL310889',
#  'OL304706',
#  'OL304744',
#  'MZ386404',
#  'MZ372328',
#  'MZ450369',
#  'MZ450527',
#  'MZ375923',
#  'MZ436591',
#  'MZ436854',
#  'MZ613487',
#  'MZ613488',
#  'MZ592567',
#  'OU290269',
#  'OU066261',
#  'MZ434560',
#  'MW571125',
#  'OU305686',
#  'MZ636223',
#  'MZ619648',
#  'MZ798926',
#  'MZ798937',
#  'OK433688',
#  'OV373183',
#  'OV392333',
#  'OV333235',
#  'OV333236',
#  'OV392340',
#  'OV333267',
#  'OV333271',
#  'OV333295',
#  'OV333304',
#  'OV333321',
#  'OU958954',
#  'OU952784',
#  'OV002530',
#  'OU983369',
#  'OV025329',
#  'OV026607',
#  'OV016844',
#  'OV027166',
#  'OV028184',
#  'OV008565',
#  'OU080288',
#  'OU095060',
#  'OU051033',
#  'OU077198',
#  'OU073035',
#  'OU077776',
#  'OU088216',
#  'OU073545',
#  'OU075689',
#  'OU075748',
#  'OU436439',
#  'OU454807',
#  'OU450407',
#  'OU505849',
#  'OU503144',
#  'OU513010',
#  'OU513253',
#  'OU485895',
#  'OU775903',
#  'OU783908',
#  'OU954434',
#  'OV012915',
#  'OV032526',
#  'OV084700',
#  'OV094717',
#  'OV097649',
#  'OV078492',
#  'OV121541',
#  'OV050689',
#  'OV053647',
#  'OV569279',
#  'OV549309',
#  'OV569302',
#  'OV549316',
#  'OV569320',
#  'OV549345',
#  'OV549347',
#  'OV569347',
#  'OV569356',
#  'OV569381',
#  'OV216824',
#  'OL902748',
#  'OV270049',
#  'OL995810',
#  'OV311497',
#  'OV399026',
#  'OV448199',
#  'OV418435',
#  'OV491816',
#  'OV806310',
#  'MZ592121',
#  'MZ592139',
#  'MZ592182',
#  'MZ710659',
#  'MZ648149',
#  'MZ649850',
#  'MZ649881',
#  'MZ706048',
#  'MZ650746',
#  'MZ786349',
#  'OV848085',
#  'OV848090',
#  'OV848092',
#  'OV858090',
#  'OV848109',
#  'OV848116',
#  'OV848120',
#  'OV858119',
#  'OV848124',
#  'OV858121',
#  'MW571124',
#  'OU165623',
#  'MW583372',
#  'OK188630',
#  'OL448870',
#  'OL698796',
#  'OL698818',
#  'FR992666',
#  'MW693648',
#  'MW888191',
#  'OU352074',
#  'OU352077',
#  'OU352079',
#  'OU352086',
#  'OU352095',
#  'OU352097',
#  'OU285761',
#  'OU327122',
#  'OU294355',
#  'OU297296',
#  'OU355389',
#  'OU406986',
#  'OU409362',
#  'OU412269',
#  'OU408654',
#  'OU376695',
#  'OU379042',
#  'OU429599',
#  'OU376346',
#  'OU376379',
#  'MT628240',
#  'MT628241',
#  'MT641749',
#  'MT641753',
#  'MT745668',
#  'MZ332024',
#  'MZ332144',
#  'MT451131',
#  'MT451141',
#  'MT451152',
#  'LR883991',
#  'LR884000',
#  'LR884011',
#  'LR884060',
#  'LR884067',
#  'LR884096',
#  'LR884127',
#  'LR884133',
#  'LR884169',
#  'LR884179',
#  'OU557296',
#  'OU567398',
#  'OU567408',
#  'OU575123',
#  'OU577089',
#  'OU572056',
#  'OU573850',
#  'OU585451',
#  'OK197691',
#  'OK227839',
#  'OU166830',
#  'OU168147',
#  'OU168155',
#  'OA999552',
#  'OB987339',
#  'OB990305',
#  'OB991015',
#  'OD906284',
#  'OU032282',
#  'OA969558',
#  'OW606598',
#  'OW606600',
#  'OW606603',
#  'OW606604',
#  'OW606605',
#  'OW606608',
#  'OW606610',
#  'OW606615',
#  'OW606617',
#  'OW606621',
#  'OU057822',
#  'OU098020',
#  'OU423624',
#  'OU392001',
#  'OU393991',
#  'MW938154',
#  'ON041635',
#  'OU094621',
#  'OU097255',
#  'OU107903',
#  'MZ385570',
#  'MZ371185',
#  'MZ405695',
#  'MZ405702',
#  'MZ405705',
#  'MZ405706',
#  'MZ349302',
#  'MZ434017',
#  'MZ328696',
#  'MZ411951',
#  'OU139532',
#  'OU139553',
#  'OU139558',
#  'MW547503',
#  'MW548224',
#  'OU154336',
#  'OU365358',
#  'OU365442',
#  'MZ895674',
#  'MZ895681',
#  'OU577019',
#  'OU572110',
#  'OU572143',
#  'OU578380',
#  'OU592551',
#  'OU686412',
#  'OU703166',
#  'OU702549',
#  'OU702860',
#  'OU702903',
#  'OU451772',
#  'OU451842',
#  'OU451861',
#  'OU451908',
#  'OU451911',
#  'OU451925',
#  'OU452068',
#  'OU450980',
#  'OU492628',
#  'OU544771',
#  'OL487830',
#  'OU974789',
#  'OV015816',
#  'OV035487',
#  'OV084397',
#  'OV117217',
#  'OV107262',
#  'OV120188',
#  'OV078501',
#  'OV111623',
#  'OU449664',
#  'OU450818',
#  'OU506205',
#  'OU501596',
#  'OU546950',
#  'OU537155',
#  'OU534039',
#  'OU547407',
#  'OU547589',
#  'OU541735',
#  'OK237665',
#  'OK228626',
#  'OK339002',
#  'OK458947',
#  'MZ967843',
#  'MZ967993',
#  'MZ977130',
#  'OK008198',
#  'MZ980986',
#  'OK013271',
#  'OL710970',
#  'OL687692',
#  'OL666009',
#  'OL696793',
#  'OL679329',
#  'OL680083',
#  'OL680147',
#  'OL703966',
#  'OL705511',
#  'OL681194',
#  'MW054101',
#  'MW054103',
#  'MW064469',
#  'MW064584',
#  'MW064587',
#  'MW064591',
#  'MW064592',
#  'MW064593',
#  'MW064826',
#  'MW064896',
#  'OU050106',
#  'OU075736',
#  'OU102541',
#  'OU164701',
#  'OU179404',
#  'OU057395',
#  'OU366479',
#  'OU366489',
#  'OU366852',
#  'OU367108',
#  'MT630423',
#  'MW309830',
#  'MT632776',
#  'MW056081',
#  'MW064329',
#  'MW064332',
#  'MW064338',
#  'MW064351',
#  'MW064354',
#  'MT635409',
#  'OU411147',
#  'OU403063',
#  'OU405138',
#  'OU409371',
#  'OU403248',
#  'OU403338',
#  'OU405294',
#  'OU405365',
#  'OU403527',
#  'OU405556',
#  'OU565933',
#  'OU565956',
#  'OU670399',
#  'OU673770',
#  'OU773391',
#  'OU757792',
#  'OU758872',
#  'OU901660',
#  'OU902427',
#  'OU892765',
#  'OV082023',
#  'OV106369',
#  'OV066232',
#  'OV066233',
#  'OV082038',
#  'OV066240',
#  'OV082050',
#  'OV066347',
#  'OV106533',
#  'OV106545',
#  'MZ713883',
#  'MZ713959',
#  'OU473233',
#  'OU451604',
#  'OU451744',
#  'OU451747',
#  'OU451756',
#  'OU451896',
#  'OU451914',
#  'OU451985']

# %%
def nucleotideToCodon(tripleNucleotides):
    
    codonNumber = 0 # 0 to 63

    for p in range(3):
        if ("AGCTagct".find(tripleNucleotides[p]) != -1):
            codonNumber += base[p] * nucleotides[tripleNucleotides[p]]
        else:
            codonNumber = 64 if tripleNucleotides[p] == "-" else 65
            break
    
    #debb
#     if codonNumber in stopnmb:
#         print("codon ",codonNumber," found in sequence")
        
    return codonNumber

def nucleotideSequenceToCodons(sequence):
    tripleNucleotidesList = [sequence[i:i + 3] for i in range(0, len(sequence), 3)]
    return list(map(lambda triple: nucleotideToCodon(triple), tripleNucleotidesList))

# %%
# transformando sequencias de nucleotideos a codons 
sequenceLength = len(sequences[0])
print("sequence length in nucleotides: ",sequenceLength)

if (sequenceLength % 3 != 0):
    print(sequenceLength)
    print("ERRO: tamanho não Múltiplo de 3")
    exit(1)
elif (next((True for seq in sequences if len(seq) > sequenceLength), False)):
    print("ERRO: as sequências não tem o mesmo tamanho")
else:
    nprm = int(sequenceLength / 3) # comprimento das seqs em codons

print(f"O dataset contem {Nseqs} sequências com accession distintos com {nprm} codons.")
print("Transformação das sequências de nucleotídeos em sequências númericas de códons.")

start = time.time()

codonSequences = list(map(lambda seq: nucleotideSequenceToCodons(seq), sequences))

print(f"Transformação concluída em {(time.time() - start) / 60} minutos");
# Out:
# sequence length in nucleotides:  3822
# O dataset contem 450 sequências com accession distintos com 1274 codons.
# Transformação das sequências de nucleotídeos em sequências númericas de códons.
# Transformação concluída em 0.024959929784139 minutos

# %%
print(np.min(codonSequences),np.max(codonSequences))
# Out:
# 0 65

# %%
# filtrando sequências com stop codons TGA,TAG,TAA in frame
filtered_codonSeqs=[]
filtered_SeqID=[]
ctr=0
laststop=0
for seq in codonSequences:
    stopfound=False
    for stp in stopnmb:
        stoppos=np.where(np.array(seq)==stp)[0]
        if len(stoppos)>0:
            if len(stoppos)==1 and (stoppos[0]==nprm-1): # last stop found
                laststop=1
            else:
                print(" stop codon ",stp," found in frame in sequence ",alignment[ctr].id," at positions ",stoppos[0])  
                stopfound=True
                break
            
    if not stopfound:
        filtered_codonSeqs.append(seq[:-laststop]) #excluindo o ultimo stop se existir
#         print(alignment[ctr].description.split("accn|")[1])
        filtered_SeqID.append(alignment[ctr].description.split("accn|")[1]) # new 05.10.2023
   
    ctr+=1

# %%
print(len(codonSequences[0]),len(filtered_codonSeqs[0]))
# Out:
# 1274 1273

# %%
# transformando o dataset em matriz de codons

cdnseq=np.array(filtered_codonSeqs)
print(cdnseq.shape)

# contando número de codons distintos por coluna (sítios)
cdns=[]
V=[]

for pos in range(cdnseq.shape[1]):
    cdnlst=list(set(list(cdnseq[:,pos])))
    V.append(len(cdnlst))
    cdns.append(cdnlst)
# Out:
# (450, 1273)

# %%
V=np.array(V)

# ordeno as colunas de maior a menor variabilidade
# Idx=np.argsort(-V)
# print("Idx",Idx)
# print("V[Idx]",V[Idx])

# seleciono as colunas com variabilidade > 1
var_sites=np.argwhere(V > 1)
Var_Sites=[]
for site in var_sites:
    Var_Sites.append(int(site))
    
var=V[var_sites]

# print("var",var)

IDsz=len(var_sites)
print("ID size ",IDsz,f" % of informative codons: {100*IDsz/nprm:.2f}")

# gero os IDs com os codons de cada seq (lista de listas)

ID=cdnseq[:,var_sites].tolist() # vetor coluna de IDs como vetores linha

strID=[] # lista de IDs como strings
for lst in ID:
    strID.append(str(lst).replace('[','').replace(']',''))
# Out:
# ID size  256  % of informative codons: 20.09
# /tmp/ipykernel_239477/3013221995.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   Var_Sites.append(int(site))

# %%
# check 
# print(len(strID),"=",Nseqs)

# %%
# ALTEREI

# gero a lista de string IDs das classes primárias - unique
start=time.time()
p=[] # vetor com string das IDs das classes primárias
pvec=[]

for Id in strID:
    p.append(Id)
    pvec.append(np.array(p[-1].split(", ")))

# for Id in strID:
#     if Id not in p:
#         p.append(Id)
#         pvec.append(np.array(p[-1].split(", ")))

print("check string and vector of chars")
print(p[0])
print(pvec[0])

# numero de classes primarias
P=len(p)
print("there were found ",P," primary classes in the dataset with ",Nseqs," sequences in ",time.time()-start," segundos")
# Out:
# check string and vector of chars
# 47, 60, 7, 47, 8, 4, 11, 43, 11, 62, 31, 50, 62, 35, 62, 58, 3, 27, 12, 35, 30, 21, 19, 30, 63, 51, 11, 59, 12, 12, 4, 22, 63, 23, 11, 11, 60, 19, 11, 31, 19, 63, 61, 23, 31, 51, 50, 34, 2, 2, 0, 7, 53, 13, 16, 7, 17, 62, 4, 25, 43, 63, 47, 13, 18, 20, 33, 62, 5, 15, 59, 43, 15, 3, 60, 29, 27, 2, 14, 11, 5, 63, 32, 11, 60, 47, 27, 35, 53, 27, 51, 51, 29, 23, 51, 47, 32, 5, 11, 63, 44, 60, 0, 16, 3, 20, 10, 47, 18, 43, 46, 56, 16, 8, 1, 55, 9, 58, 62, 16, 0, 20, 14, 51, 32, 11, 63, 4, 30, 32, 15, 2, 24, 2, 30, 58, 43, 56, 32, 1, 15, 22, 2, 23, 51, 45, 56, 23, 6, 8, 31, 16, 63, 56, 32, 42, 11, 3, 23, 31, 23, 24, 43, 0, 3, 17, 2, 0, 1, 63, 62, 63, 19, 17, 15, 31, 33, 19, 31, 24, 27, 35, 33, 3, 59, 43, 37, 27, 58, 14, 27, 8, 10, 2, 20, 19, 40, 40, 2, 47, 24, 14, 54, 23, 27, 27, 15, 1, 22, 11, 46, 25, 27, 26, 7, 56, 58, 24, 47, 19, 47, 6, 58, 60, 14, 27, 56, 20, 1, 47, 62, 29, 62, 27, 26, 24, 14, 8, 18, 29, 23, 12, 19, 43, 60, 19, 19, 53, 50, 23, 29, 13, 1, 0, 18, 29
# ['47' '60' '7' '47' '8' '4' '11' '43' '11' '62' '31' '50' '62' '35' '62'
#  '58' '3' '27' '12' '35' '30' '21' '19' '30' '63' '51' '11' '59' '12' '12'
#  '4' '22' '63' '23' '11' '11' '60' '19' '11' '31' '19' '63' '61' '23' '31'
#  '51' '50' '34' '2' '2' '0' '7' '53' '13' '16' '7' '17' '62' '4' '25' '43'
#  '63' '47' '13' '18' '20' '33' '62' '5' '15' '59' '43' '15' '3' '60' '29'
#  '27' '2' '14' '11' '5' '63' '32' '11' '60' '47' '27' '35' '53' '27' '51'
#  '51' '29' '23' '51' '47' '32' '5' '11' '63' '44' '60' '0' '16' '3' '20'
#  '10' '47' '18' '43' '46' '56' '16' '8' '1' '55' '9' '58' '62' '16' '0'
#  '20' '14' '51' '32' '11' '63' '4' '30' '32' '15' '2' '24' '2' '30' '58'
#  '43' '56' '32' '1' '15' '22' '2' '23' '51' '45' '56' '23' '6' '8' '31'
#  '16' '63' '56' '32' '42' '11' '3' '23' '31' '23' '24' '43' '0' '3' '17'
#  '2' '0' '1' '63' '62' '63' '19' '17' '15' '31' '33' '19' '31' '24' '27'
#  '35' '33' '3' '59' '43' '37' '27' '58' '14' '27' '8' '10' '2' '20' '19'
#  '40' '40' '2' '47' '24' '14' '54' '23' '27' '27' '15' '1' '22' '11' '46'
#  '25' '27' '26' '7' '56' '58' '24' '47' '19' '47' '6' '58' '60' '14' '27'
#  '56' '20' '1' '47' '62' '29' '62' '27' '26' '24' '14' '8' '18' '29' '23'
#  '12' '19' '43' '60' '19' '19' '53' '50' '23' '29' '13' '1' '0' '18' '29']
# there were found  450  primary classes in the dataset with  450  sequences in  0.010447978973388672  segundos

# %%
# salvando os códigos de cada classe primária para agrupamento com CLOPE - ## Entender e colocar na referência ##

# # print to test 
# print(p[:5])

# with open(r'SARS2.txt', 'w') as fp:
#     for item in p:
#         fp.write("{}\n".format(item))

# %%
# check
# print(len(pvec),"=",P)

# %%
# etiqueto as sequencias com a classe primária correspondente e conto o numero de sequencias em cada classe primária
pClass=[]
for Id in strID:
    pClass.append(p.index(Id))

# %%
# criando datafram com o Gene Variant File  

UniqueSeqs=[]
UniqueLabs=[]
UniqueClass=[]

unq, idxunq = np.unique(pClass, return_index=True)

# print(idxunq)

for i, idx in enumerate(idxunq):
    UniqueSeqs.append(sequences[idx])
    UniqueLabs.append(filtered_SeqID[idx])
    UniqueClass.append(unq[i])
#     print(">"+UniqueLabs[-1])
#     print(UniqueSeqs[-1])
#     print(UniqueClass[-1])

gvf = pd.DataFrame({'class':pd.Series(UniqueClass),'accession':pd.Series(UniqueLabs),'fasta_aln':pd.Series(UniqueSeqs)}) #,index=0)

gvf
# Out:
#      class accession                                          fasta_aln
# 0        0  MT628234  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 1        3  MW053744  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 2       10  OU348132  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 3       17  OU288618  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 4       20  MW341443  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# ..     ...       ...                                                ...
# 190    437  OV066347  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 191    440  MZ713883  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 192    441  MZ713959  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 193    443  OU451604  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
# 194    445  OU451747  (A, T, G, T, T, T, G, T, T, T, T, T, C, T, T, ...
#
# [195 rows x 3 columns]

# %%
# histograma de frequencia das classes primárias - depende do ordenamento
plt.hist(pClass,P)
plt.show()

# %%
class Model:
    def __init__(self, name = "", rep=2, nmbofclasses=0, nmbofclusters=0):
        
        self.name = name
        self.ListOfVarSites =[] #CBUC
        self.NmbOfClasses = nmbofclasses # CBUC
        self.CodeOfClass = [] # CBUC
        self.GroundTruth = [] # ANNOTATION
        self.NmbOfClusters =  nmbofclusters # CLOPE 
        self.TheClusterOfClass = {} # CLOPE
        self.TheSpeciesOfCluster = {} # CLOPE + ANNOTATION
        self.repulsion = rep # CLOPE 
        self.MinClusterAcc = 0 #  MODEL
        self.Accuracy = 0 # MODEL
        self.ConfusionMatrix =[] # MODEL 
        self.Accession = [] # DATA - GVF -> Tipo de Arquivo Gene Variant File - Importante Variant Call Format VCF

# %%
model = Model("SARS2-spike",nmbofclasses=P)
model.ListOfVarSites = Var_Sites #CBUC

# %% [markdown]
# # FASE 2 - ANÁLISE QUANTITATIVA
#
# ## AGRUPAMENTO
# ## ANOTAÇÃO DAS CLASSES PRIMÁRIAS
# ## CÁLCULO DA ACURÁCIA

# %%
# classes e funções da clusterização com CLOPE

class Cluster:

    def __init__(self, history_count):
       # Histórico do número de transações em clusters
        self.history_count_transact = [0] * history_count
        # Área do histograma
        self.area = 0.0
        # A altura do histograma (no sentido de H=S/W). Esse valor não é calculado explicitamente em nenhum lugar.
         # Armazenado na classe para completar a descrição da classe e nada mais.
        self.height = 0.0
        # Largura do histograma (em termos de número de elementos)
        self.width = 0.0
        # Gradiente (no sentido de G=H/W). Esse valor não é calculado explicitamente em nenhum lugar. 
        # Armazenado na classe para completar a descrição da classe e nada mais.
        self.gradient = 0.0
        # Número de transações
        self.count_transactions = 0
        # Histograma
        self.histogram = {}

    '''
    Adicione uma transação ao cluster. Iterar sobre todos os elementos do histograma, completar o histograma
     parâmetros de entrada:
     transação -- fatia com objetos (transação)
    '''
    def add_transaction(self, transaction):
        # Iterar por todos os elementos do histograma um por um e adicionar à coluna correspondente do histograma. 
        # Se não há elemento em questão, então adicione uma nova coluna ao histograma
        for item in transaction:
            if not (item in self.histogram):
                self.histogram[item] = 1 # adiciona novo elelento ao histograma
            else:
                self.histogram[item] += 1 # incrementa o numero do elemento existente no histograma
        # Calculamos a área total do histograma no sentido de CLOPE (número de transações)
        self.area += float(len(transaction))
        # Calcular a largura do histograma (o número de objetos diferentes)
        self.width = float(len(self.histogram))
        # incrementa o número de transações no cluster
        self.count_transactions += 1

    '''
    Excluir transação do cluster. Passamos por todos os elementos do histograma, removemos todos os elementos da transação de
     histogramas
    
     parâmetros de entrada:
     transação -- fatia com objetos (transação)
     valores retornados:
     valor gradiente G (transação) # sem sentido 
    
     Dentro da classe, não há rastreamento de quais transações são adicionadas, quais são excluídas, portanto, se em
     o processo de modificação excluirá uma transação que não foi adicionada ao cluster correspondente, o algoritmo
     vai dar resultado errado    
     '''
    
    def remove_transaction(self, transaction):
            for item in transaction:
                if self.histogram[item] > 0: # new
                    self.histogram[item] -=1 # new
                if self.histogram[item] == 0:
                    del self.histogram[item]
            self.area -= float(len(transaction))
            self.width = float(len(self.histogram))
            self.count_transactions -= 1
            return # self.gradient # rare 


class CLOPE:

    def __init__(self, print_step=1000, random_seed=None): 
        
        if random_seed is not None:
            self.random_seed = random_seed
        else:
            self.random_seed = random.randint(0, 65536 + 1)
        
        # Lista de clusters
        self.clusters = {}  # CCluster
        # Números de clusters de ruído
        # Este objeto é necessário para não levar em consideração aqueles objetos que foram classificados como ruído
        self.noise_clusters = {}
        # Número de transações adicionadas
        self.count_transactions = 0
        # Número da iteração
        self.iteration = 0
        # inicializa dicionário: número da transação/número do cluster
        self.transaction = {}
        # Número máximo do cluster
        self.max_cluster_number = 0
        self.print_step = print_step

    '''
    A mudança de meta que a função objetivo receberá ao adicionar uma transação ao cluster clusterNumber é calculada.
     O cluster que entrega o valor máximo da função será o cluster desejado (ao qual se deve adicionar a transação)
     parâmetros de entrada:
     transação -- transação (lista de objetos)
     clusterNumber -- número do cluster cujo incremento está sendo calculado
     r -- repulsão no sentido de CLOPE
     valor retornado:
     Retorna o valor de alteração da função objetivo quando uma transação é adicionada ao cluster clusterNumber
    '''
    def get_delta(self, transaction, cluster_number, r):
        
        old_area = Decimal(self.clusters[cluster_number].area)
        old_width = Decimal(self.clusters[cluster_number].width)
        nmb_trans = Decimal(self.clusters[cluster_number].count_transactions)
        
        area = old_area + Decimal(len(transaction)) # calcula a área adicionando os objetos da transação
                                                                    # em análise
        # cálculo da largura do cluster
        width = old_width 
        for item in transaction:
            if not (item in self.clusters[cluster_number].histogram): # histogram tem a lista de objetos no cluster
                width += Decimal(1)
        
        # calcula delta (variação da função objetivo com a adição da transação ao cluster cluster_number)
        new_delta_value = Decimal(0)
        if width != Decimal(0):
            new_delta_value = area * (nmb_trans + 1) / (width ** Decimal(r))
            
        # calcula o valor de delta sem a transação
        if old_width != Decimal(0):
            old_delta_value = old_area * nmb_trans / (old_width ** Decimal(r))
        else:
            old_delta_value = Decimal(0)
            
        return new_delta_value - old_delta_value

    '''
    Função de remoção de ruído. Todos os clusters maiores que o limite permanecem ativos.
     parâmetros de entrada:
     limite -- nível de ruído do cluster
    '''
    def noise_reduction(self, limit):
        # Remova todos os clusters vazios e barulhentos
        new_clusters = {}
        for item in self.clusters:
            if self.clusters[item].count_transactions > limit:# se o cluster é maior que o limite permanece na lista de clusters ativos
                new_clusters[item] = self.clusters[item]
            else: # clusters pequenos são considerados ruidosos e saem da lista de clusters ativo - 
                  # passam para alista de clusters com ruido
                self.noise_clusters[item] = True
        self.clusters = new_clusters

    '''
    Cálculo da função objetivo para todos os clusters já formados
     Usado ao modificar clusters ou inicializá-los
     parâmetros de entrada:
     r -- número real denotando repulsão de cluster no sentido de CLOPE
     valor retornado:
     Retorna o valor da função objetivo
    '''
    def get_goal_function(self, r):
        measure = 0.0
        # Percorremos todos os clusters e para cada um calculamos seu peso. 
        # Todos os pesos são resumidos em uma métrica comum
        for item in self.clusters:
            if item.width == 0:
                # print "test"
                pass
            else:
                # # Tentando encontrar uma métrica diferente
                # measure += (r ** 2 * math.log(item.Area ** (1 / r) / item.Width) ** 2) *
                # item.CountTransactions / self.CountTransactions
                measure += item.area / (item.width ** r) * item.count_transactions 
        return measure / self.count_transactions

    '''
     Adicionando uma nova transação
     Estamos tentando redistribuir a transação com o número de id em outra classe para que a função de custo tenha
     valor máximo
     parâmetros de entrada:
     transação -- transação (fatia com objetos)
     id -- número da transação
     repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
     isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
     parâmetro retornado:
     Retorna o número do cluster ao qual a transação atual foi adicionada
    '''
    def move_transaction(self, transaction, id, repulsion=2, max_count_clusters=None):
        
        r = repulsion
        max_value = None
        max_value_index = None
        self.count_transactions += 1
        
        # Estamos procurando um cluster no qual o valor máximo da mudança na função objetivo seja alcançado
        for cluster_number in self.clusters:
            delta = self.get_delta(transaction, cluster_number, r)
            if (delta > 0 or max_count_clusters is not None) and (max_value is None or delta > max_value):
                max_value_index = cluster_number
                max_value = delta

        # Adicione uma transação a um novo cluster e veja o resultado - registre o cluster com maior valor
        if max_count_clusters is None or len(self.clusters) < max_count_clusters:
            self.clusters[self.max_cluster_number] = Cluster(self.count_transactions)
            if max_value is None or self.get_delta(transaction, self.max_cluster_number, r) > max_value:
                max_value_index = self.max_cluster_number
                self.max_cluster_number += 1
            else:
                del self.clusters[self.max_cluster_number]

        # Lembramos em qual cluster está a transação atual
        self.transaction[id] = max_value_index

        #Adicionando uma transação ao cluster necessário
        self.clusters[max_value_index].add_transaction(transaction)

        return max_value_index

    '''
    Cálculo de limiar de ruído adaptativo. O limite é limpo em relação à mediana dos tamanhos de cluster (incluindo
     transações). Pegue 3/4 da mediana
    '''
    def get_noise_limit(self, percentile=0.75):
        size_clusters = []
        for item in self.clusters:
            size_clusters.append(self.clusters[item].count_transactions)
        sorted(size_clusters)
        median_element = int(len(size_clusters) * percentile) + 1
        if len(size_clusters) < 5:
            limit = 10
        else:
            limit = size_clusters[median_element]
        return limit

    '''
    Inicialização do cluster
    parâmetros de entrada:
    dados -- fatia com transações
    isPrint -- se deve imprimir informações de progresso (0 -- não é necessário, se > 0 -- imprimir a cada isPrint time)
    repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
    isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
    isNoiseReduction -- redução de ruído (limiar corresponde ao número de elementos no cluster no qual ele é destruído).
                        Se isNoiseReduction == -1, então o limite é selecionado de forma adaptativa (tudo que for maior que a mediana
                        restos)
    '''
    def init_clusters(self, data, repulsion=2, is_noise_reduction=-1, noise_median_threshold=0.75,
                      max_count_clusters=None):
        index = 0
        keys = sorted(data.keys())
        np.random.seed(self.random_seed)
        np.random.shuffle(keys)
        for item in keys:
            self.move_transaction(data[item], item, repulsion, max_count_clusters)
            index += 1
            if self.print_step > 0 and index % self.print_step == 0:
                print("ITERAÇÃO: ", self.iteration, ". NÚMERO DA ETAPA", index, ". NÚMERO DE CLUSTERS: ", len(self.clusters))
                pass

        # Obtendo o limite de ruído ideal
        if is_noise_reduction < 0:
            is_noise_reduction = self.get_noise_limit(noise_median_threshold)
        # Remova todos os clusters de ruído 
        # (após a inicialização, não há classes vazias, portanto, o sinal é estritamente maior)
        if is_noise_reduction > 0:
            self.noise_reduction(is_noise_reduction)

        self.iteration = 1

    '''
    Execução do algoritmo. Dando o próximo passo
    parâmetros de entrada:
    dados -- fatia com transações
    isPrint -- se deve imprimir informações de progresso (0 -- não é necessário, se > 0 -- imprimir a cada isPrint time)
    repulsão -- número real, denotando repulsão de clusters no sentido de CLOPE
    isSaveHistory -- sinalizador definido se for necessário registrar o histórico do número de transações
    isNoiseReduction -- redução de ruído (limiar corresponde ao número de elementos no cluster no qual ele é destruído).
                        Se isNoiseReduction == -1, então o limite é selecionado de forma adaptativa (tudo que for maior que a mediana
                        restos)
    parâmetro retornado:
    Retorna o número de operações para transferir uma transação de cluster para cluster
    '''
    def next_step(self, data, repulsion=2, is_noise_reduction=-1, noise_median_threshold=0.75, max_count_clusters=None):

        # Remova todos os clusters vazios (ou ruído, se isNoiseReduction > 0)
        if is_noise_reduction < 0:
            is_noise_reduction = self.get_noise_limit(noise_median_threshold)
        self.noise_reduction(is_noise_reduction)

        index = 0
        # O número de transações que foram transferidas
        moves = 0
        keys = sorted(data.keys())
        np.random.seed(self.random_seed)
        np.random.shuffle(keys)
        for id in keys:
            # Nós olhamos onde esta transação está agora
            cluster_number = self.transaction[id]
            transaction = data[id]
            # Se a transação pertencer a um cluster de ruído, não tentaremos alterá-la
#             if cluster_number in self.noise_clusters:
#                 eps += 0
#             else:
            # Recuperar uma transação do cluster atual
            self.clusters[cluster_number].remove_transaction(transaction)
            # Consideramos a transação como recém-chegada e a adicionamos ao cluster onde o valor do destino
            # máximiza a função custo
            moves += int(self.move_transaction(transaction, id, repulsion, max_count_clusters) != cluster_number)
                
            index += 1
            if self.print_step is not None and self.print_step > 0 and index % self.print_step == 0:
#                 print("Итерация: ", self.iteration, ". Номер шага", index, ". Число кластеров: ", len(self.clusters))
#                 print("ITERAÇÃO: ", self.iteration, ". NÚMERO DA ETAPA", index, ". NÚMERO DE CLUSTERS: ", len(self.clusters))
                pass

        self.iteration += 1

        self.noise_reduction(is_noise_reduction)
        
        return moves

    '''
    Desenhamos um gráfico mostrando o número de transações em diferentes classes
    
    '''
    def print_history_count(self, repulsion, seed):
        pass

# %%
# funções que constroem a matriz de confusão e calculam o erro usando o ground truth 

def CompareResultAndAnnotation(accession, annot, clope, verbose=False):
    
    # pegamos a lista de genotipos distintos
    species=list(set(annot)) # colunas
    if verbose:
        print("list of genotypes in dataset:\n",species)# numeramos os genótipos segundo a ordem na lista
    species_nmb={} # dict 
    ctr=0
    for sp in species:
        species_nmb[sp]=ctr
        ctr+=1
    
    # calculamos o numero de transacoes de cada espécie (soma das colunas da matriz)
    colsum=np.zeros(len(species),dtype=int)
    for sp in annot:
        colsum[species_nmb[sp]]+=1
    if verbose:
        print("number of strain by genotype\n",colsum)
    
    # inicializa a matriz de confusão
    conf_matrix = np.zeros((clope.max_cluster_number,len(species)),dtype=int)
    # varre dict transaction {trans_id:cluster}
    for trans_id in range(len(clope.transaction)):
        cluster = clope.transaction[trans_id]
        conf_matrix[cluster,species_nmb[annot[trans_id]]]+=1
           
    # attributing most probable genotype to each cluster and eliminating empty clusters
    new_confmat=[]
    annotation={}
    for item in range(clope.max_cluster_number):
        if np.sum(conf_matrix[item])>0:
            new_confmat.append(conf_matrix[item])
            # anotando cada cluster com a especie mais provável
            sort=-np.sort(-conf_matrix[item])
            if sort[1]==sort[0]: # tem mais de um máximo
                annotation[accession[item]]="UNKNOWN"
            else:
                annotation[accession[item]]=species[np.argmax(conf_matrix[item])]
        
    return np.array(new_confmat), annotation

def GetClusteringError(confmat):
    
    # cálculo da métrica de erro relativo por cluster : numero de seqs - max
    acc = []
    n = np.sum(confmat)
    tot_error = 0
    for cluster in range(confmat.shape[0]):
        aux0 = np.sum(confmat[cluster])
        aux = aux0 - np.max(confmat[cluster])
        tot_error += aux
        if aux0 > 0:
            acc.append(1-aux/aux0)
        else: 
            acc.append(0)

    return np.array(acc), 1-tot_error/n

# %% [markdown]
# # acessando à anotação de cada classe primária

# %%
# ALTEREI

# Caminho do arquivo de anotações
arquivo_anotacoes = '/home/m_souza/tcc/dataset/dataset_agua/anotacoes.txt'

# Dicionário para armazenar as anotações
annot = {}

# Ler o arquivo de anotações
with open(arquivo_anotacoes, 'r') as anotacoes_file:
    for linha in anotacoes_file:
        # Dividir a linha usando a vírgula como separador
        partes = linha.strip().split(',') # primeira parte ID longo terminando en ACCN, 
                                            # segunda parte o tipo Pangolin
        
        # Verificar se a linha tem o formato correto
        if len(partes) == 2:
            cabecalho, anotacao = partes
            annot[cabecalho.split("accn|")[1]] = anotacao # new 05.10.2023
        else:
            print(f"A linha '{linha}' não possui o formato esperado.")

# Exibir o dicionário de anotações
print(annot)
# Out:
# {'MT628234': 'A.1', 'MT628235': 'A.1', 'MT628237': 'A.1', 'MW053744': 'A.1', 'MT628238': 'A.1', 'MT628247': 'A.1', 'MT628251': 'A.1', 'MT628253': 'A.1', 'MT628254': 'A.1', 'MT628255': 'A.1', 'OU348132': 'AV.1', 'OU340519': 'AV.1', 'OU290602': 'AV.1', 'OU286689': 'AV.1', 'OU287044': 'AV.1', 'OU298008': 'AV.1', 'OU314138': 'AV.1', 'OU288618': 'AV.1', 'OU292159': 'AV.1', 'OU299530': 'AV.1', 'MW341443': 'A.6', 'ON870954': 'A.6', 'ON878765': 'A.6', 'ON878781': 'A.6', 'ON878782': 'A.6', 'ON878788': 'A.6', 'ON878787': 'A.6', 'ON878797': 'A.6', 'ON878795': 'A.6', 'ON878796': 'A.6', 'MZ372711': 'A.2.5.2', 'MZ372712': 'A.2.5.2', 'OU075229': 'A.2.5.2', 'MZ591007': 'A.2.5.2', 'MZ593669': 'A.2.5.2', 'MZ591877': 'A.2.5.2', 'MZ647317': 'A.2.5.2', 'MZ647385': 'A.2.5.2', 'MZ784304': 'A.2.5.2', 'MZ850490': 'A.2.5.2', 'MZ877201': 'AY.3.1', 'MZ879302': 'AY.3.1', 'MZ877252': 'AY.3.1', 'MZ882519': 'AY.3.1', 'MZ882582': 'AY.3.1', 'MZ886640': 'AY.3.1', 'MZ888660': 'AY.3.1', 'MZ882633': 'AY.3.1', 'MZ882638': 'AY.3.1', 'MZ882658': 'AY.3.1', 'OM019981': 'AY.3', 'OM173384': 'AY.3', 'OM104437': 'AY.3', 'OM019996': 'AY.3', 'OM104457': 'AY.3', 'OM020011': 'AY.3', 'OM020036': 'AY.3', 'OM104494': 'AY.3', 'OM173452': 'AY.3', 'OM104522': 'AY.3', 'OU412175': 'AY.4.3', 'OU408246': 'AY.4.3', 'OU408835': 'AY.4.3', 'OU375016': 'AY.4.3', 'OU429497': 'AY.4.3', 'OU383643': 'AY.4.3', 'OU379844': 'AY.4.3', 'OU379862': 'AY.4.3', 'OU417957': 'AY.4.3', 'OU379961': 'AY.4.3', 'LR883974': 'A.5', 'LR883995': 'A.5', 'LR883996': 'A.5', 'LR884009': 'A.5', 'LR884020': 'A.5', 'LR884033': 'A.5', 'LR884054': 'A.5', 'LR884063': 'A.5', 'LR884065': 'A.5', 'LR884078': 'A.5', 'OU329975': 'AY.4.9', 'OU428228': 'AY.4.9', 'OU509703': 'AY.4.9', 'OU480847': 'AY.4.9', 'OU534438': 'AY.4.9', 'OU540618': 'AY.4.9', 'OU534072': 'AY.4.9', 'OU550290': 'AY.4.9', 'OU556646': 'AY.4.9', 'OU557230': 'AY.4.9', 'OK239246': 'AY.3.3', 'OK277733': 'AY.3.3', 'OK353751': 'AY.3.3', 'OK455315': 'AY.3.3', 'OK461771': 'AY.3.3', 'OK355161': 'AY.3.3', 'OL306995': 'AY.3.3', 'OL310889': 'AY.3.3', 'OL304706': 'AY.3.3', 'OL304744': 'AY.3.3', 'MZ386404': 'AY.2', 'MZ372328': 'AY.2', 'MZ450369': 'AY.2', 'MZ450527': 'AY.2', 'MZ375923': 'AY.2', 'MZ436591': 'AY.2', 'MZ436854': 'AY.2', 'MZ613487': 'AY.2', 'MZ613488': 'AY.2', 'MZ592567': 'AY.2', 'OU290269': 'A.23.1', 'OU066261': 'A.23.1', 'MZ434560': 'A.23.1', 'MW571125': 'A.23.1', 'OU305686': 'A.23.1', 'MZ636223': 'A.23.1', 'MZ619648': 'A.23.1', 'MZ798926': 'A.23.1', 'MZ798937': 'A.23.1', 'OK433688': 'A.23.1', 'OV373183': 'AY.4.2.2', 'OV392333': 'AY.4.2.2', 'OV333235': 'AY.4.2.2', 'OV333236': 'AY.4.2.2', 'OV392340': 'AY.4.2.2', 'OV333267': 'AY.4.2.2', 'OV333271': 'AY.4.2.2', 'OV333295': 'AY.4.2.2', 'OV333304': 'AY.4.2.2', 'OV333321': 'AY.4.2.2', 'OU958954': 'AY.4.10', 'OU952784': 'AY.4.10', 'OV002530': 'AY.4.10', 'OU983369': 'AY.4.10', 'OV025329': 'AY.4.10', 'OV026607': 'AY.4.10', 'OV016844': 'AY.4.10', 'OV027166': 'AY.4.10', 'OV028184': 'AY.4.10', 'OV008565': 'AY.4.10', 'OU080288': 'AA.1', 'OU095060': 'AA.1', 'OU051033': 'AA.1', 'OU077198': 'AA.1', 'OU073035': 'AA.1', 'OU077776': 'AA.1', 'OU088216': 'AA.1', 'OU073545': 'AA.1', 'OU075689': 'AA.1', 'OU075748': 'AA.1', 'OU436439': 'AY.4.11', 'OU454807': 'AY.4.11', 'OU450407': 'AY.4.11', 'OU505849': 'AY.4.11', 'OU503144': 'AY.4.11', 'OU513010': 'AY.4.11', 'OU513253': 'AY.4.11', 'OU485895': 'AY.4.11', 'OU775903': 'AY.4.11', 'OU783908': 'AY.4.11', 'OU954434': 'AY.4.2.5', 'OV012915': 'AY.4.2.5', 'OV032526': 'AY.4.2.5', 'OV084700': 'AY.4.2.5', 'OV094717': 'AY.4.2.5', 'OV097649': 'AY.4.2.5', 'OV078492': 'AY.4.2.5', 'OV121541': 'AY.4.2.5', 'OV050689': 'AY.4.2.5', 'OV053647': 'AY.4.2.5', 'OV569279': 'AY.4.2', 'OV549309': 'AY.4.2', 'OV569302': 'AY.4.2', 'OV549316': 'AY.4.2', 'OV569320': 'AY.4.2', 'OV549345': 'AY.4.2', 'OV549347': 'AY.4.2', 'OV569347': 'AY.4.2', 'OV569356': 'AY.4.2', 'OV569381': 'AY.4.2', 'OV216824': 'AY.4.15', 'OL902748': 'AY.4.15', 'OV270049': 'AY.4.15', 'OL995810': 'AY.4.15', 'OV311497': 'AY.4.15', 'OV399026': 'AY.4.15', ' ...

# %%
# ALTEREI

# pegando as espécies virais anotadas
# species=list(set(annot.values()))
species = list(annot.values())
print(species)
# Out:
# ['A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'A.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'AV.1', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.6', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'A.2.5.2', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3.1', 'AY.3', 'AY.3', 'AY.3', 'AY.3', 'AY.3', 'AY.3', 'AY.3', 'AY.3', 'AY.3', 'AY.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'AY.4.3', 'A.5', 'A.5', 'A.5', 'A.5', 'A.5', 'A.5', 'A.5', 'A.5', 'A.5', 'A.5', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.4.9', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.3.3', 'AY.2', 'AY.2', 'AY.2', 'AY.2', 'AY.2', 'AY.2', 'AY.2', 'AY.2', 'AY.2', 'AY.2', 'A.23.1', 'A.23.1', 'A.23.1', 'A.23.1', 'A.23.1', 'A.23.1', 'A.23.1', 'A.23.1', 'A.23.1', 'A.23.1', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.2.2', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AY.4.10', 'AA.1', 'AA.1', 'AA.1', 'AA.1', 'AA.1', 'AA.1', 'AA.1', 'AA.1', 'AA.1', 'AA.1', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.11', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2.5', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.2', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.4.15', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.5.3', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'AY.4.6', 'A.21', 'A.21', 'A.21', 'A.21', 'A.21', 'A.21', 'A.21', 'A.21', 'A.21', 'A.21', 'AY.1', 'AY.1', 'AY.1', 'AY.1', 'AY.1', 'AY.1', 'AY.1', 'AY.1', 'AY.1', 'AY.1', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'AY.4.5', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2.2', 'A.2', 'A.2', 'A.2', 'A.2', 'A.2', 'A.2', 'A.2', 'A.2', 'A.2', 'A.2', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AY.4.4', 'AD.2', 'AD.2', 'AD.2', 'AD.2', 'AD.2', 'AD.2', 'AD.2', 'AD.2', 'AD.2', 'AD.2', 'AY.4', 'AY.4', 'AY.4', 'AY.4', 'AY.4', 'AY.4', 'AY.4', 'AY.4', 'AY.4', 'AY.4', 'A.29', 'A.29', 'A.29', 'A.29', 'A.29', 'A.29', 'A.29', 'A.29', 'A.29', 'A.29', 'A.2.5', 'A.2.5', 'A.2.5', 'A.2.5', 'A.2.5', 'A.2.5', 'A.2.5', 'A.2.5', 'A.2.5', 'A.2.5', 'A.28', 'A.28', 'A.28', 'A.28', 'A.28', 'A.28', 'A.28', 'A.28', 'A.28', 'A.28', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.4.14', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.5.4', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.13', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.4.8', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.3.4', 'AY.5', 'AY.5', 'AY.5', 'AY.5', 'AY.5', 'AY.5', 'AY.5', 'AY.5', 'AY.5', 'AY.5', 'A.3', 'A.3', 'A.3', 'A.3', 'A.3', 'A.3', 'A.3', 'A.3', 'A.3', 'A.3', 'A.27', 'A.27', 'A.27', 'A.27', 'A.27', 'A.27', 'A.27', 'A.27', 'A.27', 'A.27', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.1', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.3', 'AY.4.2.1', 'AY.4.2.1', 'AY.4.2.1', 'AY ...

# %%
def get_accession(new_accession, transactions):
    for j in range(len(transactions)):
#         print(new_accession,"=?",transactions[j][0].replace("/",""))
        if new_accession in transactions[j][0].replace("/",""):
            return transactions[j][0]
    return "unknown"

# %% [markdown]
# # random iterations:
# ## varying repulsion in a given search interval
# ## for each repulsion value:
# ### > finding clusters with different sorting of input
# ### > calculating minimum accuracies of clusters to control achievement of quality criteria
# ### > finishing random iterations  it check if repulsion satisfies the quality threshold:
# ### >> if OK exit the repulsion loop and build model data

# %%
# MAIN -----------------------------------------------------

# pegando a lista de accession
Acc = gvf['accession']
# tirando barras para match com annot
Accession0=[]
for acc in Acc:
    Accession0.append(acc.replace("/",""))
# print(Accession0[:3])

# pegando o groundthruth da anotação
GroundTruth0 = list(annot.values())
# print(GroundTruth0[:3])

# pegando os vetores de chars dos códigos das classes primárias como transações
InputData0 = pvec
nmb_trans=len(pvec)
nmb_annot=len(GroundTruth0)
print('check: number of transactions = annotations: ',nmb_trans,'=',nmb_annot)

if nmb_trans!=nmb_annot:
    print("DATASET NOT FULLY OR WRONGLY ANNOTATED .....\nRESULTS MAY BE CONFUSING....")
    
noiseLimit = 0.0 # dummy

nRandIterations=50 #50
ClusterAccThres=1.00

print("Looking for optimal repulsion with ",nRandIterations,"random iterations and threshold of minimum cluster accuracy of ",ClusterAccThres)

optimum=False
minRep=100 # new 05.10.2023
maxRep=200
stpRep=10

for repulsion in range(minRep,maxRep,stpRep): #>= 11 da 1005 acc de clusters com 200 iteracoes randomicas

    print("repulsion", repulsion)
    
    cluster_acc=[]
    Accuracy=[]

    K = nmb_trans
    best_cluster_acc=0

    codes = InputData0
    GT = GroundTruth0
        
    for i in range(nRandIterations):

#         print("RANDOM ITERATION ",i+1)

        seed = None #150 <<<<<<<<<<<<<<<<<<<<<<<< ORDENAÇÂO ALEATORIA
        np.random.seed(seed)

    #     InputData=InputData0.copy()
        list_zipped = list(zip(Accession0,InputData0,GroundTruth0))
        np.random.shuffle(list_zipped)
        Accession, InputData, GroundTruth = zip(*list_zipped) #unzipping

        # print('first transactions:\n',InputData[:3])
        # print('first annotations:\n',GroundTruth[:3])

        trans_len=len(InputData[0])

        Data = {} # usamos um dicionario para os dados com as features indexadas por posição

        for trans_nmb in range(0, len(InputData)):
            Data[trans_nmb] = [''] * trans_len # inicializa a transação efetiva 
            fst=0 # for SARS2
            for index in range(fst, len(InputData[trans_nmb])):
                # adicionando a posição (coluna) da feature se não for missing & counting missings
                if InputData[trans_nmb][index] != '?':
                    Data[trans_nmb][index] = str(index) + ":"+InputData[trans_nmb][index].replace(" ","")  # add feature position

        clope = CLOPE(print_step=1000, random_seed=seed) 
        # Dados iniciais

        # Inicializamos o algoritmo
        clope.init_clusters(Data, repulsion, noiseLimit)

            # Nós iteramos
        while clope.next_step(Data, repulsion, noiseLimit ) > 0:
            clope.print_history_count(repulsion, seed)

#         print("CLOPE number of clusters ",clope.max_cluster_number)
        # print(clope.transaction.values())
        # print("annot",list(GroundTruth))

        # cálculo do erro da classificação

        confmat, map_species2cluster = CompareResultAndAnnotation(Accession, GroundTruth, clope)
#         print("non-empty cluster number ",len(confmat))

#         print("matriz de confusão - quantas seqs pertencem a cada genótipo (colunas) em cada cluster (linha):\n",confmat)
#         print(map_species_cluster)

        # cálculo da métrica de erro por cluster : numero de seqs - max
        acc_lst, tot_acc = GetClusteringError(confmat) 

        cluster_acc.append(acc_lst)
        Accuracy.append(tot_acc)

#         print("erro relativo por cluster: \n",100*acc_lst," %")
#         print("acurácia total",100*tot_acc," %")

        # condition to choose the best clustering during iterations
        if (np.min(cluster_acc[-1]) > best_cluster_acc) and (len(confmat) < K): 
            best_cluster_acc=np.min(cluster_acc[-1])
            K = len(confmat)
            best_confmat=confmat
            best_annotation = map_species2cluster
            map_class2cluster = clope.transaction  
            codes = InputData
            GT = GroundTruth
            best_accession = Accession
            print(" ------------- best found")
            
        del clope

        # calculo a media e desvio padrão da minima acuracia nos clusters em cada iteração
        min_lst=[]
        for i in range(len(cluster_acc)):
            min_lst.append(np.min(cluster_acc[i]))
        #     print(np.min(cluster_acc[i]))
        mean_min_cluster_acc=np.mean(min_lst)
        std_min_cluster_acc=np.std(min_lst)
        min_min_cluster_acc=np.min(min_lst)
    #     print("mean minimum cluster accuracy ",mean_min_cluster_acc," standard deviation ",std_min_cluster_acc)
    #     print("minimum minimum cluster accuracy ",min_min_cluster_acc,"estimated minimum minimum cluster accuracy ", \
    #           mean_min_cluster_acc-2*std_min_cluster_acc)
    
    # controle de optimalidade
    
    print(min_min_cluster_acc)
    if min_min_cluster_acc >= ClusterAccThres:
        print("satisfied optimality criteria")
        optimum=True
        break
        
if optimum:
    model.NmbOfClusters=K
    model.Accuracy=np.mean(Accuracy) # MODEL
    model.MinClusterAcc=min_min_cluster_acc # MODEL
    model.ConfusionMatrix = best_confmat # MODEL
    model.CodeOfClass = codes # origin CBUC but shuffled by AGUA 
    model.GroundTruth = GT # ANNOTATION
    model.TheClusterOfClass = map_class2cluster # CLOPE
    model.TheSpeciesOfCluster = list(best_annotation.values()) # CLOPE + ANNOTATION
    baccession=[]
    for acc in best_accession:
        baccession.append(get_accession(acc,t))
    model.Accession=baccession # CBUC but shuffled by AGUA
    
    print("Mean accuracy of the model ",model.Accuracy," standard deviation of accuracy ",np.std(Accuracy))
    print("Number of Classes :",model.NmbOfClasses)
#     print("CodesOf Classes :\n",model.CodeOfClass)
#     print("Annotation of Classes :\n",model.GroundTruth) 
    print("Number of clusters",model.NmbOfClusters)
    print("Confusion matrix\n",pd.DataFrame(zip(model.ConfusionMatrix,model.TheSpeciesOfCluster)))
else:
    print("optimum not found for repulsion in the interval [",minRep,",",maxRep,"]")
# Out:
# check: number of transactions = annotations:  450 = 450
# Looking for optimal repulsion with  50 random iterations and threshold of minimum cluster accuracy of  1.0
# repulsion 100
#  ------------- best found
# 0.30000000000000004
# repulsion 110
#  ------------- best found
#  ------------- best found
# 0.30000000000000004
# repulsion 120
#  ------------- best found
#  ------------- best found
# 0.30000000000000004
# repulsion 130
#  ------------- best found
#  ------------- best found
# 0.375
# repulsion 140
#  ------------- best found
#  ------------- best found
#  ------------- best found
# 0.375
# repulsion 150
#  ------------- best found
# 0.375
# repulsion 160
#  ------------- best found
# 0.375
# repulsion 170
#  ------------- best found
# 0.375
# repulsion 180
#  ------------- best found
# 0.5625
# repulsion 190
#  ------------- best found
# 0.5625
# optimum not found for repulsion in the interval [ 100 , 200 ]

# %%
# Check
# print(model.TheClusterOfClass)
# target = 1
# for pclass in model.TheClusterOfClass.keys():
#     if model.TheClusterOfClass[pclass]==target:
#         print("classes in cluster ",target," = ",pclass," annot ",model.GroundTruth[pclass])

# %%
print(min_min_cluster_acc)
print(ClusterAccThres)
# Out:
# 0.5625
# 1.0

# %% [markdown]
# # FASE 3 - ANÁLISE QUALITATIVA

# %%
# calculating distances between pairs of IDs -> put in categorical distance matrix

def categoricaldist(u,v,var,mode=0): # calcula a distancia entre 2 vetores categóricos: numero de entradas distintas / total de entradas
    dist=0
    for i in range(len(u)):
        if u[i]!=v[i]:
            if mode==0:
                dist+=1/var[i] # weighted -> INVERSAMENTE PROPORCIONAL À VARIABILIDADE DO SITE
            else:
                dist+=1 # SEM CONSIDERAR A VARIABILIDADE DO SITE
                
    return dist/len(u)

# -------------------------------------------------------------------

print("FASE2 - CÁLCULO DA MATRIZ DE DISTÂNCIAS ENTRE PARES DE CLASSES PRIMÁRIAS ")

fvec=model.CodeOfClass
start=time.time()
print(len(fvec))
cat_distmatrix=[]
for i in range(P-1):
    cat_distmatrix.append([])
    for j in range(i+1,P):
#         dotdistmatrix[-1].append(np.dot(pvec[i],pvec[j]))
        cat_distmatrix[-1].append(categoricaldist(fvec[i],fvec[j],var,0))
#         print(i,j,np.dot(pvec[i],pvec[j]))
        
# check 
# for distvec in cat_distmatrix:
#     print(distvec)

# gerando matriz de distancias simetrica

# nota: os vetores dists , fst e scd estão alinhados, ou seja dists[k] é a distância entre a classe fst[k] e a scd[k] !!!

DistMat=np.zeros((P,P),dtype=float)
labels=[]
# fst & scd são o par de indexadores de cada distância (as classes primárias que são comparadas)
fst=[]
scd=[]
for i in range(P-1):
    labels.append("class"+str(i)+" annot "+model.GroundTruth[i]+ " cluster "+str(model.TheClusterOfClass[i])+" pred "+\
                  model.TheSpeciesOfCluster[model.TheClusterOfClass[i]])
    for j in range(i+1,P):
        fst.append(i)
        scd.append(j)
        DistMat[i][j]=cat_distmatrix[i][j-i-1]
        DistMat[j][i]=DistMat[i][j] # building a symmetric matrix
        
labels.append("class"+str(P-1)+" annot "+model.GroundTruth[P-1]+ " cluster "+str(model.TheClusterOfClass[P-1])+ " pred "+\
                  model.TheSpeciesOfCluster[model.TheClusterOfClass[P-1]])

print("matriz de distâncias\n", DistMat)

np.savetxt('dist_mat.txt', DistMat)

dists = squareform(DistMat) # saida para a construcao de arvores com dendogram
print("vetor de distancias\n", dists)

print(f"tempo:{time.time()-start} segundos")
# Out:
# FASE2 - CÁLCULO DA MATRIZ DE DISTÂNCIAS ENTRE PARES DE CLASSES PRIMÁRIAS
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb Célula 38 line 2
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=22'>23</a>     cat_distmatrix.append([])
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=23'>24</a>     for j in range(i+1,P):
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=24'>25</a> #         dotdistmatrix[-1].append(np.dot(pvec[i],pvec[j]))
# ---> <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=25'>26</a>         cat_distmatrix[-1].append(categoricaldist(fvec[i],fvec[j],var,0))
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=26'>27</a> #         print(i,j,np.dot(pvec[i],pvec[j]))
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=27'>28</a>
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=28'>29</a> # check
#    (...)
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=33'>34</a>
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=34'>35</a> # nota: os vetores dists , fst e scd estão alinhados, ou seja dists[k] é a distância entre a classe fst[k] e a scd[k] !!!
#      <a href='vscode-notebook-cell:/home/m_souza/tcc/Tcc_Implementacao/Mauricio_TCC_UnEB/pipeline_AGUA/Diego_AGUA_Training_Pipeline.ipynb#X52sZmlsZQ%3D%3D?line=36'>37</a> DistMat=np.zeros((P,P),dtype=float)
#
# IndexError: list index out of range

# %%
#atualizando labels com a especie predita

# print(model.TheClusterOfClass)
# target = 7
# for pclass in model.TheClusterOfClass.keys():
#     labels[pclass]+=" annot "+model.GroundTruth[pclass]+" pred "+model.TheSpeciesOfCluster[model.TheClusterOfClass[pclass]]
# #     if model.TheClusterOfClass[pclass]==target:
# #         print("classes in cluster ",target," = ",pclass," annot ",model.GroundTruth[pclass])

# %% [markdown]
# # visualizando árvore filogenética

# %% [markdown]
# # linkage methods
# The following are methods for calculating the distance between the newly formed cluster  and each .
#
# 1. method=’single’  also known as the Nearest Point Algorithm.
#
# 2. method=’complete’  also known by the Farthest Point Algorithm or Voor Hees Algorithm.
#
# 3. method=’average’ also called the UPGMA algorithm.
#
# 4. method=’weighted’ also called WPGMA.
#
# 5. method=’centroid’  also known as the UPGMC algorithm.
#
# 6. method=’median’  also known as the WPGMC algorithm.
#
# 7. method=’ward’ also known as the incremental algorithm.

# %%
# methods=['single', 'complete','average','weighted','centroid','median','ward']
# methodknownas=['NearestPoint', 'FarthestPoint','UPGMA','WPGMA','UPGMC','WPGMC','Incremental']
methods=['ward']
methodknownas=['Incremental']
nmeth=len(methods)

# %%
# construindo arvores com distintos métodos de linkagem da scipy.cluster.hierarch.linkage
ctr=0
for meth in methods:
    linkage_matrix = linkage(dists, meth)
    fig, ax = plt.subplots(1, 1, figsize=(10, 18))
    fig.set_size_inches(10, 18, forward=True)
    dn= dendrogram(linkage_matrix, ax=ax, labels=labels, show_leaf_counts=True, show_contracted=True, orientation='left',leaf_font_size=10)
    plt.title("SARS2 - Host independent study with linkage method '"+meth+"' ("+methodknownas[ctr]+")")
#     plt.tight_layout()
    #or:
    plt.tight_layout(pad=4)
    plt.show()
    fig.savefig('tree_'+methodknownas[ctr]+'.png', dpi=fig.dpi)
    ctr+=1

# %%
def print_model(model,n):
    print("name:", model.name)
    print("ListOfVarSites:\n",model.ListOfVarSites)
    print("NmbOfClasses:",model.NmbOfClasses)
    print("CodeOfClass[:",n,"]:\n",model.CodeOfClass[:n])
    print("GroundTruth[:",n,"]:\n",model.GroundTruth[:n])
    print("Accession[:",n,"]:\n",model.Accession[:n])
    print("repulsion:",model.repulsion)
    print("NmbOfClusters:",model.NmbOfClusters)
    print("TheSpeciesOfCluster:\n",model.TheSpeciesOfCluster)
    print("MinClusterAcc:",model.MinClusterAcc)
    print("Accuracy:",model.Accuracy)
    print("ConfusionMatrix:\n",model.ConfusionMatrix)
    print("TheClusterOfClass:\n",model.TheClusterOfClass)

# %%
print_model(model,2)

# %% [markdown]
# # CREATING THE GENE VARIANT FILE

# %%
# creating and saving the final GVF file

GVF=pd.DataFrame(model.CodeOfClass)
col_rename_dict = {i:j for i,j in zip(GVF.columns,model.ListOfVarSites)}
GVF.rename(columns=col_rename_dict, inplace=True)

GVF['accession']=model.Accession
GVF['ground_truth']=model.GroundTruth

GVF

GVF.to_csv(model.name+'.gvf')

# %%
print(GVF.columns)

# %%
# saving and loading the  model

# Save the file
model_filename=model.name+".obj"
dill.dump(model, file = open(model_filename, "wb"))

# Reload the file
loaded_model = dill.load(open(model_filename, "rb"))
print_model(loaded_model,2)

# %%
# READY TO USE IN THE PRODUCTION PHASE - 23.10.2022
