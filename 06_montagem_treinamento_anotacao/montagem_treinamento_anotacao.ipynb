# %%
import os
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

# %%
def read_gene_sequences(file_genome_sequences):
    multiple_genomes = []
    with open(file_genome_sequences) as handle:
        for values in SeqIO.FastaIO.SimpleFastaParser(handle):
            sequence_id, sequence = values
            multiple_genomes.append((sequence_id, sequence))

    return multiple_genomes

# %%
# Diretório principal onde você possui várias pastas
diretorio_principal = '/home/m_souza/tcc/dataset/teste'

# Diretório de saída
diretorio_saida = '/home/m_souza/tcc/dataset/dataset_agua'

# Número de sequências extraídas por Lineage
quantidade_sequencias = 10

# Nome do arquivo de treinamento
arquivo_treinamento = os.path.join(diretorio_saida, 'sequencias_treinamento.fasta')

# Nome do arquivo de anotações
arquivo_anotacoes = os.path.join(diretorio_saida, 'anotacoes.txt')

# Lista para armazenar as informações de anotações
anotacoes = []

# Iterar sobre as pastas no diretório principal
for pasta in os.listdir(diretorio_principal):
    pasta_path = os.path.join(diretorio_principal, pasta)

    # Verificar se é um diretório
    if os.path.isdir(pasta_path):
        # Procurar pelo arquivo sequencias_cortadas.fasta na pasta
        arquivo_sequencias = os.path.join(pasta_path, 'sequencias_spike_filtradas.fasta')

        # Verificar se o arquivo existe
        if os.path.exists(arquivo_sequencias):
            print(f'Analisando sequências em {pasta}')

            # Ler as sequências do arquivo usando a Biopython
            sequencias = read_gene_sequences(arquivo_sequencias)

            # Salvar as primeiras 'quantidade_sequencias' sequências em sequencias_treinamento.fasta
            with open(arquivo_treinamento, 'a') as treinamento_file:
                for seq_id, seq in sequencias[:quantidade_sequencias]:
                    SeqIO.write(SeqRecord(Seq(seq), id=seq_id, description=''), treinamento_file, 'fasta')
                    anotacao = f'{seq_id},{pasta}'
                    anotacoes.append(anotacao)

# Salvar as anotações em anotacoes.txt
with open(arquivo_anotacoes, 'w') as anotacoes_file:
    anotacoes_file.write('\n'.join(anotacoes))

print('Concluído!')
# Out:
# Analisando sequências em A.1
# Analisando sequências em AV.1
# Analisando sequências em A.6
# Analisando sequências em A.2.5.2
# Analisando sequências em AY.3.1
# Analisando sequências em AY.3
# Analisando sequências em AY.4.3
# Analisando sequências em A.5
# Analisando sequências em AY.4.9
# Analisando sequências em AY.3.3
# Analisando sequências em AY.2
# Analisando sequências em A.23.1
# Analisando sequências em AY.4.2.2
# Analisando sequências em AY.4.10
# Analisando sequências em AA.1
# Analisando sequências em AY.4.11
# Analisando sequências em AY.4.2.5
# Analisando sequências em AY.4.2
# Analisando sequências em AY.4.15
# Analisando sequências em AY.5.3
# Analisando sequências em AY.4.6
# Analisando sequências em A.21
# Analisando sequências em AY.1
# Analisando sequências em AY.4.5
# Analisando sequências em A.2.2
# Analisando sequências em A.2
# Analisando sequências em AY.4.4
# Analisando sequências em AD.2
# Analisando sequências em AY.4
# Analisando sequências em A.29
# Analisando sequências em A.2.5
# Analisando sequências em A.28
# Analisando sequências em AY.4.14
# Analisando sequências em AY.5.4
# Analisando sequências em AY.4.13
# Analisando sequências em AY.4.8
# Analisando sequências em AY.3.4
# Analisando sequências em AY.5
# Analisando sequências em A.3
# Analisando sequências em A.27
# Analisando sequências em A
# Analisando sequências em AY.4.1
# Analisando sequências em AY.4.2.3
# Analisando sequências em AY.4.2.1
# Analisando sequências em AY.4.7
# Concluído!
